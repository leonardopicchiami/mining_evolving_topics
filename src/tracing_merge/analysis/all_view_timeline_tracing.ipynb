# %% [markdown]
# ### Auhtor: Leonardo Picchiami
#
#
# # Tracing Over Timeline View

# %% [markdown]
# This file shows the tracking of topics along the timeline for each value of k. In this way it is possible to evaluate and observe the method of tracing adopted and the metric of tracing chosen.

# %%
import warnings
warnings.filterwarnings("ignore")

import sys 

sys.path.append("..")
sys.path.append("../../graph")
sys.path.append("../../metrics")
sys.path.append("../../spread_influence")
sys.path.append("../../overlaps_topics")

import graph as gr
import metrics as me
import spread_of_influence as sp
import overlap_topics as ov
import tracing_merge as tr

import pandas as pd
import numpy as np

ds1_path = "../../../dataset_src/ds-1.tsv"
ds2_path = "../../../dataset_src/ds-2.tsv"

# %%
timeline = [str(year) for year in range(2000, 2019)]
print(timeline)

timeline_topics = dict()
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

# %% [markdown]
# The sequence of operations is:
# - a graph for each year of timeline
# - build a ds1 graph with fraction of co-citations weights calculation strategy
# - application of the pagerank metric for each graph created
# - spread of influence object for graph and metric result as seed for each year to apply the models
# - application of the clique percolation method to get all the topics of the year

# %%
def T1(ds1_path, ds2_path, year, k):
    year_graph = gr.YearGraph(ds1_path, ds2_path, year)
    year_graph.read()
    year_graph.weights_fraction_cocitations()
    year_graph.build_ds1_graph()

    metrics = me.Metrics(year_graph)
    metrics.metrics_preprocessing()
    metrics.pagerank(k)

    models = sp.SpreadOfInfluenceModels(year_graph, metrics.get_top_k_nodes())
    models.spread_preprocessing()
    models.threshold_deg()
    models.tipping_model()
    
    ov_top = ov.OverlapTopics(year_graph, models.get_influenced_nodes(), k)
    ov_top.overlap_preprocessing()
    ov_top.clique_percolation_method()
    ov_top.check_number_topics()
    ov_top.check_spread_topics()

    return ov_top.get_topics()

# %% [markdown]
# Apply the previously defined function along the entire timeline with a fixed k.

# %%
#Timeline topic identification
def timeline_identification(k):
    for year in timeline:
            timeline_topics[year] = T1(ds1_path, ds2_path, year, k)

# %% [markdown]
# Function that tracks all the topics obtained on the timeline and outputs the result.

# %%
def timeline_tracing():
    print("TOPIC CHAINS TRACED ALONG THE TIMELINE\n\n\n")
    timeline_tracer = tr.TraceMergeTimeline(timeline_topics)
    timeline_tracer.trace_timeline(mode = 0)

# %% [markdown]
# ### Tracing over timline with K = 5

# %%
timeline_identification(k = 5)

# %%
timeline_tracing()
# Out:
# TOPIC CHAINS TRACED ALONG THE TIMELINE
#
#
#
# The target topic:
#
# year: 2000
# ['nonlinear system', 'motion estimation\xa0', 'simulation']
#
#
# The traced topics are:
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['experiment', 'support vector machine', 'feature vector']
#
#
# The traced topics are:
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2001
# ['filtering', 'linear systems', 'filtering algorithms', 'signal processing', 'smoothing methods', 'fading', 'mathematics', 'state estimation', 'signal processing algorithms', 'bayesian methods', 'laboratories', 'particle filters', 'stochastic processes', 'computer simulation', 'state-space methods', 'deconvolution', 'monte carlo methods']
#
#
# The traced topics are:
#
#
# year : 2002
# ['state estimation', 'filtering algorithms']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2002
# ['state estimation', 'filtering algorithms']
#
#
# The traced topics are:
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2002
# ['speech processing', 'bayesian methods', 'signal processing', 'monte carlo methods']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2002
# ['blind source separation', 'overcomplete situation', 'important method', 'unsupervised learning', 'independent component analysis']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2003
# ['recurrent neural networks', 'global asymptotic stability', 'lyapunov functional', '87.10.+e', 'neural networks', 'global exponential stability', 'periodic solution', '43.80.+p', 'sufficient conditions', 'young inequality', '87.18.sn', '85.40.ls']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2003
# ['algorithm', 'real life', 'really simple discovery', 'pattern recognition', 'scalability', 'dimensionality reduction', 'singular value decomposition', 'heuristic', 'first-order predicate', 'feature vector']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2003
# ['scheduling (computing)', 'monte carlo method', 'computation', 'random number generation', 'grid computing']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2004
# ['biasing', 'apriori algorithm', 'subgroup a nepoviruses', 'algorithm', 'roc curve', 'reinforcement learning', 'stochastic process', 'class', 'apache ant (another neat tool)', 'heuristic', 'consortium', 'large', 'ant colony optimization algorithms', 'rule (guideline)', 'real life']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2004
# ['linear discriminant analysis', 'particle swarm optimization', 'experiment', 'benchmark (computing)', 'mathematical optimization']
#
#
# The traced topics are:
#
#
# year : 2006
# ['lyapunov fractal', 'distributed delays', 'variational principle', 'experiment', 'hopfield neural networks', 'computation', 'quantum', 'stochastic systems', 'neural networks', 'global exponential stability', 'time-varying delays', 'time delays', 'linear discriminant analysis', 'particle swarm optimization', 'discrete and distributed delays', 'machine learning', 'lyapunov–krasovskii functional', 'algorithm', 'global asymptotic stability', 'uncertain systems', 'linear matrix inequality', 'periodic solution', 'computationally efficient', 'numerical analysis', 'cohen–grossberg neural network', 'hessian', 'sufficient conditions', 'discrete delays', 'gradient', 'optimization problem', 'artificial neural network']
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2012
# ['cognition', 'fuzzy control system', 'computation', 'software deployment', 'class', 'data mining', 'inference engine', 'premature convergence', 'benchmark (computing)', 'cognitive radio', 'receiver operating characteristic', 'knapsack problem', 'cyclostationary process', 'gradient', 'expectation–maximization algorithm', 'optimization problem', 'radio frequency', 'experiment', 'supervised learning', 'missing data', 'mathematical optimization', 'deep learning', 'q-learning', 'particle swarm optimization', 'genetic algorithm', 'preprocessor', 'evolutionary algorithm', 'machine learning', 'fuzzy logic', 'interference (communication)', 'transmitter', 'algorithm', 'trees (plant)', 'reinforcement learning', 'simulation', 'signal-to-interference-plus-noise ratio', 'telecommunications link', 'frequency band', 'genetic operator', 'coexist (image)', 'sparse matrix', 'cross-validation (statistics)', 'combinatorial optimization', 'autonomous robot']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['node attributes', 'link prediction', 'proposed framework', 'dimensional vector representations', 'network embedding', 'vast majority']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************

# %% [markdown]
# ### Tracing over timline with K = 10

# %%
timeline_identification(k = 10)

# %%
timeline_tracing()
# Out:
# TOPIC CHAINS TRACED ALONG THE TIMELINE
#
#
#
# The target topic:
#
# year: 2000
# ['neural network simulation', 'artificial neural network']
#
#
# The traced topics are:
#
#
# year : 2001
# ['algorithm', 'cluster analysis', 'real life', 'feedforward neural network', 'artificial neural network']
#
#
# year : 2005
# ['neural network simulation', 'lyapunov fractal', 'social inequality', 'activation function', 'recurrent neural network', 'artificial neural network']
#
#
# year : 2006
# ['lyapunov fractal', 'distributed delays', 'variational principle', 'experiment', 'hopfield neural networks', 'computation', 'quantum', 'stochastic systems', 'neural networks', 'global exponential stability', 'time-varying delays', 'time delays', 'linear discriminant analysis', 'particle swarm optimization', 'discrete and distributed delays', 'machine learning', 'lyapunov–krasovskii functional', 'algorithm', 'global asymptotic stability', 'uncertain systems', 'linear matrix inequality', 'periodic solution', 'computationally efficient', 'numerical analysis', 'cohen–grossberg neural network', 'hessian', 'sufficient conditions', 'discrete delays', 'gradient', 'optimization problem', 'artificial neural network']
#
#
# year : 2007
# ['neural network simulation', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'distributed delays', 'linear matrix inequality', 'lyapunov functional', 'cohen–grossberg neural networks', 'synchronization', 'time-varying delays', 'bidirectional associative memory', 'chaos', 'content-addressable memory', 'bidirectional associative memory neural networks', 'rate of convergence', 'lag synchronization', 'artificial neural network']
#
#
# year : 2008
# ['lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'exponential', 'global asymptotic stability', 'exponential stability', 'linear matrix inequality', 'numerical analysis', 'neural networks', 'mathematical optimization', 'varying delays', 'global optimization', 'lyapunov method', 'unbounded distributed delays', 'rate of convergence', 'biological neural networks', 'artificial neural network']
#
#
# year : 2010
# ['neutral type', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'gene regulatory network', 'time complexity', 'systems biology', 'global asymptotic stability', 'linear matrix inequality', 'lyapunov functional', 'neural networks', 'global exponential stability', 'genetic regulatory networks', 'multistability', 'complex network', 'analysis technique', 'artificial neural network']
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2012
# ['neural network simulation', 'overfitting', 'social inequality', 'time complexity', 'test data', 'sampling - surgical action', 'linear matrix inequality', 'numerical analysis', 'recurrent neural network', 'synchronization (computer science)', 'sampling (signal processing)', 'dropout (neural networks)', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['experiment', 'support vector machine', 'feature vector']
#
#
# The traced topics are:
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['nonlinear system', 'motion estimation\xa0', 'simulation']
#
#
# The traced topics are:
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2013
# ['single solution does', 'objective optimisation problems', 'dynamic multi', 'objective optimisation']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['node attributes', 'link prediction', 'proposed framework', 'dimensional vector representations', 'network embedding', 'vast majority']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************

# %% [markdown]
# ### Tracing over timline with K = 20

# %%
timeline_identification(k = 20)

# %%
timeline_tracing()
# Out:
# TOPIC CHAINS TRACED ALONG THE TIMELINE
#
#
#
# The target topic:
#
# year: 2000
# ['neural network simulation', 'artificial neural network']
#
#
# The traced topics are:
#
#
# year : 2001
# ['algorithm', 'cluster analysis', 'real life', 'feedforward neural network', 'artificial neural network']
#
#
# year : 2005
# ['neural network simulation', 'lyapunov fractal', 'social inequality', 'activation function', 'recurrent neural network', 'artificial neural network']
#
#
# year : 2006
# ['lyapunov fractal', 'distributed delays', 'variational principle', 'experiment', 'hopfield neural networks', 'computation', 'quantum', 'stochastic systems', 'neural networks', 'global exponential stability', 'time-varying delays', 'time delays', 'linear discriminant analysis', 'particle swarm optimization', 'discrete and distributed delays', 'machine learning', 'lyapunov–krasovskii functional', 'algorithm', 'global asymptotic stability', 'uncertain systems', 'linear matrix inequality', 'periodic solution', 'computationally efficient', 'numerical analysis', 'cohen–grossberg neural network', 'hessian', 'sufficient conditions', 'discrete delays', 'gradient', 'optimization problem', 'artificial neural network']
#
#
# year : 2007
# ['neural network simulation', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'distributed delays', 'linear matrix inequality', 'lyapunov functional', 'cohen–grossberg neural networks', 'synchronization', 'time-varying delays', 'bidirectional associative memory', 'chaos', 'content-addressable memory', 'bidirectional associative memory neural networks', 'rate of convergence', 'lag synchronization', 'artificial neural network']
#
#
# year : 2008
# ['lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'exponential', 'global asymptotic stability', 'exponential stability', 'linear matrix inequality', 'numerical analysis', 'neural networks', 'mathematical optimization', 'varying delays', 'global optimization', 'lyapunov method', 'unbounded distributed delays', 'rate of convergence', 'biological neural networks', 'artificial neural network']
#
#
# year : 2010
# ['neutral type', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'gene regulatory network', 'time complexity', 'systems biology', 'global asymptotic stability', 'linear matrix inequality', 'lyapunov functional', 'neural networks', 'global exponential stability', 'genetic regulatory networks', 'multistability', 'complex network', 'analysis technique', 'artificial neural network']
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2012
# ['neural network simulation', 'overfitting', 'social inequality', 'time complexity', 'test data', 'sampling - surgical action', 'linear matrix inequality', 'numerical analysis', 'recurrent neural network', 'synchronization (computer science)', 'sampling (signal processing)', 'dropout (neural networks)', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['experiment', 'support vector machine', 'feature vector']
#
#
# The traced topics are:
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['nonlinear system', 'motion estimation\xa0', 'simulation']
#
#
# The traced topics are:
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'multitier architecture', 'approximation algorithm', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2013
# ['single solution does', 'objective optimisation problems', 'dynamic multi', 'objective optimisation']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'mathematical induction', 'optimization problem', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['retrieval efficiency hashing', 'widely applied', 'scale multimedia retrieval', 'separate quantization step', 'sense clustering', 'semantic similarity', 'data pairs', 'image retrieval', 'hash coding']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'open problem', 'feedback', 'approximation', 'wireless sensor networks\xa0', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['carefully reviewed', 'refereed proceedings', 'topical sections named', 'book constitutes', 'fukuoka japan']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['node attributes', 'link prediction', 'proposed framework', 'dimensional vector representations', 'network embedding', 'vast majority']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['significantly outperform', 'diverse ranking model', 'art baselines', 'alternating direction method', 'search result diversification']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************

# %% [markdown]
# ### Tracing over timline with K = 100

# %%
timeline_identification(k = 100)

# %%
timeline_tracing()
# Out:
# TOPIC CHAINS TRACED ALONG THE TIMELINE
#
#
#
# The target topic:
#
# year: 2000
# ['neural network simulation', 'artificial neural network']
#
#
# The traced topics are:
#
#
# year : 2001
# ['algorithm', 'cluster analysis', 'real life', 'feedforward neural network', 'artificial neural network']
#
#
# year : 2005
# ['neural network simulation', 'lyapunov fractal', 'social inequality', 'activation function', 'recurrent neural network', 'artificial neural network']
#
#
# year : 2006
# ['lyapunov fractal', 'distributed delays', 'variational principle', 'experiment', 'hopfield neural networks', 'computation', 'quantum', 'stochastic systems', 'neural networks', 'global exponential stability', 'time-varying delays', 'time delays', 'linear discriminant analysis', 'particle swarm optimization', 'discrete and distributed delays', 'machine learning', 'lyapunov–krasovskii functional', 'algorithm', 'global asymptotic stability', 'uncertain systems', 'linear matrix inequality', 'periodic solution', 'computationally efficient', 'numerical analysis', 'cohen–grossberg neural network', 'hessian', 'sufficient conditions', 'discrete delays', 'gradient', 'optimization problem', 'artificial neural network']
#
#
# year : 2007
# ['neural network simulation', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'distributed delays', 'linear matrix inequality', 'lyapunov functional', 'cohen–grossberg neural networks', 'synchronization', 'time-varying delays', 'bidirectional associative memory', 'chaos', 'content-addressable memory', 'bidirectional associative memory neural networks', 'rate of convergence', 'lag synchronization', 'artificial neural network']
#
#
# year : 2008
# ['lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'exponential', 'global asymptotic stability', 'exponential stability', 'linear matrix inequality', 'numerical analysis', 'neural networks', 'mathematical optimization', 'varying delays', 'global optimization', 'lyapunov method', 'unbounded distributed delays', 'rate of convergence', 'biological neural networks', 'artificial neural network']
#
#
# year : 2009
# ['biological neural networks', 'artificial neural network']
#
#
# year : 2010
# ['neutral type', 'lyapunov fractal', 'lyapunov–krasovskii functional', 'social inequality', 'gene regulatory network', 'time complexity', 'systems biology', 'global asymptotic stability', 'linear matrix inequality', 'lyapunov functional', 'neural networks', 'global exponential stability', 'genetic regulatory networks', 'multistability', 'complex network', 'analysis technique', 'artificial neural network']
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'approximation algorithm', 'multitier architecture', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2012
# ['neural network simulation', 'overfitting', 'social inequality', 'time complexity', 'test data', 'sampling - surgical action', 'linear matrix inequality', 'numerical analysis', 'recurrent neural network', 'synchronization (computer science)', 'sampling (signal processing)', 'dropout (neural networks)', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'optimization problem', 'mathematical induction', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'wireless sensor networks\xa0', 'feedback', 'approximation', 'open problem', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['experiment', 'support vector machine', 'feature vector']
#
#
# The traced topics are:
#
#
# year : 2011
# ['model selection', 'support vector machine']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2018
# ['lyapunov fractal', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'telecommunications network', 'bands', 'embedded system', 'word lists by frequency', 'prime-factor fft algorithm', 'approximation algorithm', 'anatomical layer', 'benchmark (computing)', 'multi-user', 'autoencoder', 'active learning (machine learning)', 'fixed-point theorem', 'bit error rate', 'optimization problem', 'hopfield network', 'analysis of algorithms', 'radio frequency', '37b25\xa0', 'hearing loss high-frequency', 'social inequality', 'training data', 'biologic preservation', 'mimo', 'experimental results', 'privacy', 'approximation', 'system dynamics', 'neural network simulation', 'interaction', 'entropy maximization', 'reinforcement learning', 'linear matrix inequality', 'end-to-end principle', 'existing approaches', 'semiconductor industry', 'scheduling (computing)', 'iterative method', 'loss function', 'artificial neural network', 'memristor-based switching networks\xa0', 'network packet', 'computational complexity theory', 'data compression', 'evolutionary algorithms', 'support vector machine', 'smart battery system', 'new data', 'computer simulation', 'impulse\xa0', 'converge', 'biological neural networks', 'memristor', 'spectral leakage', 'multitier architecture', 'driven programming paradigm', 'differential evolution', 'time complexity', 'spectral density', 'numerical analysis', 'correctness (computer science)', 'cognitive radio', 'expectation propagation', 'optimal control', 'anomaly detection', 'experiment', 'closed-circuit television', 'mathematical optimization', 'deep learning', 'numerous', 'particle swarm optimization', 'nonlinear system', '92c20\xa0', 'detection tasks', 'machine learning', '34c27\xa0', 'pid', 'particle swarm optimization\xa0', 'predictive failure analysis', 'interference (communication)', 'algorithm', 'crafted neuron network', 'simulation', 'convolutional neural network', 'telecommunications link', 'frequency band', 'throughput', 'critical scenarios', 'direct method in the calculus of variations']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2000
# ['nonlinear system', 'motion estimation\xa0', 'simulation']
#
#
# The traced topics are:
#
#
# year : 2011
# ['lyapunov fractal', 'plasmon', 'software deployment', 'fairness measure', 'ising model', 'quality of service', 'spectral leakage', 'approximation algorithm', 'multitier architecture', 'differential evolution', 'convex function', 'time complexity', 'numerical analysis', 'cognitive radio', 'parameter adaptation', 'hopfield network', 'low-power broadcasting', 'distributed delays', 'social inequality', 'exponential', 'experiment', 'resonance', 'hopfield-type neural networks', 'mathematical optimization', 'broadcast delay', 'stochastic neural network', 'particle swarm optimization', 'nonlinear system', 'evolutionary algorithm', 'machine learning', 'tree rearrangement', 'neural network simulation', 'interference (communication)', 'interaction', 'algorithm', 'channel capacity', 'impulses', 'reinforcement learning', 'linear matrix inequality', 'simulation', 'signal-to-interference-plus-noise ratio', 'checking (action)', 'telecommunications link', 'synchronization (computer science)', 'population diversity', 'centralized computing', 's ability', 'autonomous robot', 'artificial neural network']
#
#
# year : 2013
# ['lyapunov fractal', 'bernoulli polynomials', 'mean squared error', 'neural networks', 'navier–stokes equations', 'artificial bee colony algorithm', 'lessons learned', 'knowledge base', 'quintic function', 'approximation algorithm', 'vertex', 'convex optimization', 'benchmark (computing)', 'switches', 'synchronization', "jensen's inequality", 'optimization problem', 'backhaul (telecommunications)', 'recurrent neural networks', 'social inequality', 'q-learning', 'performance', 'gauss–kronrod quadrature formula', 'nearest neighbor classifier', 'neural network simulation', 'newton–cotes formulas', 'iteration', 'hybrid optimization', 'reinforcement learning', 'linear matrix inequality', 'synchronization (computer science)', 'collocation method', 'block cipher mode of operation', 'sampling (signal processing)', 'central processing unit', 'matrix regularization', 'artificial neural network', 'algebraic equation', 'state estimation', 'cell (microprocessor)', 'dynamic programming', 'stochastic process', 'b-spline', 'biological neural networks', 'data synchronization', 'spectral leakage', 'numerical method', 'differential evolution', 'organizing (structure)', 'sampling - surgical action', 'word embedding', 'programming paradigm', 'numerical analysis', 'randomness', 'stability', 'text corpus', 'cognitive radio', 'coefficient', 'error analysis (mathematics)', 'complex networks', 'complex network', 'taguchi method', 'experiment', 'mathematical optimization', 'deep learning', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'taguchi methods', 'machine learning', 'couplings', 'interference (communication)', 'self-organization', 'algorithm', 'probability', 'simulation', 'convolutional neural network', 'telecommunications link', 'manufacturing', 'throughput', 'frank–wolfe algorithm', 'stochastic processes', 'dropout (neural networks)', 'duality gap']
#
#
# year : 2014
# ['computers', 'mathematical model', 'lyapunov fractal', 'particle swarm optimization (pso)', 'phil blunsom', 'metaheuristic search (ms)', 'fuzzy control system', 'mean squared error', 'computation', 'neighborhood search (ns) operator', 'velocity (software development)', 'neural networks', 'partition function (mathematics)', 'scalability', 'cuckoo search\xa0', 'random neural network', 'state space', 'kyunghyun cho', 'finite-time stabilization', 'imagenet', 'ilya sutskever', 'approximation algorithm', 'hamilton–jacobi–bellman equation', 'encoder', 'constraint algorithm', 'premature convergence', 'yang', 'benchmark (computing)', 'convex optimization', 'noise reduction', 'periodic solution', 'autoencoder', 'global optimization problem\xa0', 'shadowing (histology)', 'bag-of-words model', 'search algorithm', 'in-place algorithm', 'computer vision', 'cuckoo search', 'bit error rate', 'richard m. schwartz', 'optimization problem', 'mathematical induction', 'social inequality', 'exponential', 'krill herd (kh)\xa0', 'rayleigh fading', 'computer performance', 'mimo', 'n-gram', 'feasible region', 'freebase', 'john makhoul', 'generative model', 'topology', 'rate of convergence', 'formal system', 'abdel-rahman mohamed', 'neural network simulation', 'transmitter', 'iteration', 'baseline (configuration management)', 'uncertainty', 'reinforcement learning', 'linear matrix inequality', 'bil herd', 'analytical models', 'electronic mail', 'neural network software', 'data stream mining', 'quoc v. le', 'xiang zhang', 'calculus of variations', 'sampling (signal processing)', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical machine translation', 'knowledge graph', 'x.690', 'recursive neural network', 'fault tolerance', 'point of view (computer hardware company)', 'skip list', 'dynamic programming', 'constrained optimization', 'navdeep jaitly', 'quality of service', 'jacobi method', 'stochastic gradient descent', 'matthew d. zeiler', 'global optimization', 'control theory', 'entity', 'biological neural networks', 'multitier architecture', 'neural machine translation', 'lyapunov–krasovskii functional', 'time complexity', 'mathematics', 'sampling - surgical action', 'word embedding', 'numerical analysis', 'language model', 'feature selection', 'cognitive radio', 'mimo-ofdm', 'nal kalchbrenner', 'optimal control', 'heuristic', 'coefficient', 'information retrieval', 'complex network', 'metaheuristic', 'pixel', 'oriol vinyals', 'experiment', 'bellman equation', 'mathematical optimization', 'geoffrey e. hinton', 'deep learning', 'recurrent neural network', 'neural network', 'particle swarm optimization', 'nonlinear system', 'nicolas boulanger-lewandowski', 'genetic algorithm', 'usb on-the-go', 'yoshua bengio', 'machine learning', 'markov decision process', 'evolutionary algorithm', 'alex krizhevsky', 'fuzzy logic', 'ant colony optimization algorithms', 'bart van merrienboer', 'interference (communication)', 'algorithm', 'deep learning papers review at neurotechnology: attention mechanisms neurotechnology mar 15 2017', 'simulation', 'convolutional neural network', 'yang liu', 'throughput', 'alex graves', 'multimodal interaction', 'zhongqiang huang', 'jacob devlin', 'activation function']
#
#
# year : 2015
# ['lyapunov fractal', 'doina precup', 'fuzzy control system', 'swarm intelligence', 'neural networks', 'artificial bee colony algorithm', 'emanuel todorov', 'tom erez', 'novel automatic classification', 'database', 'wavelet analysis', 'principal component analysis', 'yuval tassa', 'auto regressive integrated moving average', 'imagenet', 'multi-agent system', 'back-stepping\xa0', 'hamilton–jacobi–bellman equation', 'cross reactions', 'encoder', '82301', 'link prediction\xa0', 'benchmark (computing)', 'aided diagnosis', 'ar auto regressive', 'trust region', 'feature learning', 'optimization problem', 'dynamic network\xa0', 'riemann–liouville', 'optimization', 'fine tune', 'bayesian optimization', 'adaptive systems', 'resonance', 'd2d communication\xa0', 'novelty detection', 'magnetic resonance imaging', 'well-posed problem', 'learning disorders', 'empirical mode decomposition', 'feedback', 'approximation', 'formal system', 'system dynamics', '11101', 'controllers', 'channel capacity', 'signal processing', '????\xa0', 'artificial bee colony', 'power semiconductor device', 'feature representation\xa0', 'markov chain', 'imagenet dataset', 'continuous optimization', 'http public key pinning', 'artificial neural network', 'loss function', 'stabilization', 'observers', 'nonlinear systems', 'mri scanning', 'elm', '???\xa0', 'extreme learning machine\xa0', 'pca principal component analysis', 'maxima and minima', 'dynamic programming', 'computer simulation', 'medical analysis', 'stochastic gradient descent', 'normal brains', 'map', 'input-output linearization\xa0', 'spectral efficiency', 'memristor', 'converge', 'adaptive algorithm', 'learning model\xa0', 'weibull distribution function', 'convex function', 'time complexity', 'language model', 'numerical analysis', 'honglak lee', 'unsupervised learning', 'stability', 'control system', 'compaq lte', 'low-power broadcasting', '70201', 'linear matrix inequality (lmi)', 'power control\xa0', 'bellman equation', 'mathematical optimization', 'deep learning', 'social network\xa0', 'real-time transcription', 'machine learning', 'arima auto regressive integrated moving average', 'fuzzy logic', 'speech recognition', 'algorithm', 'accurate classification', 'simulation', 'emd empirical mode decomposition', 'convolutional neural network', 'non-minimum phase\xa0', 'extract features', 'memory intensive making', 'activation function', 'linearizing at the trim state\xa0', 'long short-term memory', 'online and offline', 'robot', 'ga genetic algorithm', 'prediction', 'unscented kalman filter', 'ilya sutskever', 'approximation algorithm', 'distinguish abnormal brains', 'computer assisted diagnosis', 'convex optimization', 'noise reduction', 'synchronization', 'autoencoder', 'decision tree learning', 'bt bayesian theory', 'computer vision', 'satinder p. singh', 'acoustic cryptanalysis', 'social inequality', 'tcp global synchronization', 'tbr ??\xa0', 'performance', 'mr brain images', 'artificial intelligence', 'remaining connections', 'neural network simulation', 'interaction', 'firefly algorithm', 'interference management\xa0', 'cluster analysis', 'iteration', 'interval time-varying delay', 'reinforcement learning', 'theory', '???????\xa0', 'pattern recognition', 'linear matrix inequality', 'unit commitment', 'synchronization (computer science)', 'block cipher mode of operation', 'coexist (image)', 'large-scale computing\xa0', 'embedded systems', 'crucially importance', 'network topology', 'feedforward neural network', 'similarity metric\xa0', 'support vector machine', 'hypersonic flight vehicle\xa0', 'constrained optimization', 'sergey levine', 'memristor-based neural networks', 'statistical classification', 'fractional-order', '?????\xa0', 'increment', 'control theory', 'global optimization', 'structural break modeling', 'cellular multicast\xa0', 'correctness (computer science)', 'output feedback', 'optimal control', 'parsing', 'categorization', 'experiment', 'supervised learning', 'radial (radio)', 'geoffre ...
#
#
# year : 2016
# ['code', 'lyapunov fractal', 'variational principle', 'fuzzy control system', 'neural networks', 'embedded system', 'search space effectively', 'minimizes overall costs', 'ben parr', 'imagenet', 'volodymyr mnih', 'multi-agent system', 'hamilton–jacobi–bellman equation', 'encoder', 'benchmark (computing)', 'generalization (psychology)', 'finite-time synchronization', 'decision makers', 'search algorithm', 'optimization problem', 'koray kavukcuoglu', 'hysteresis', 'optimization', 'mark rowland', 'feature extraction', 'time-varying delay', 'adaptive systems', 'recommending treatments', 'adaptive coding', 'personalization', 'magnetic resonance imaging', 'learning disorders', 'data pre-processing', 'feedback', 'approximation', 'formal system', 'sensor', 'recommender system', 'open-source software', 'agent-based model', 'genetic programming', 'fuzzy rule', 'identifier', 'http public key pinning', 'artificial neural network', 'iterative method', 'statistical model', 'upper confidence bound', 'computational complexity theory', 'nonlinear systems', 'demis hassabis', 'knowledge graph', 'dynamic programming', 'computer simulation', 'potential benefits', 'stochastic gradient descent', 'mnist database', 'swarm intelligence\xa0', 'converge', 'memristor', 'convex function', 'language model', 'numerical analysis', 'computer data storage', 'coupling constant', 'big data', 'control system', 'network architecture', 'bellman equation', 'mathematical optimization', 'deep learning', 'benchmark\xa0', 'hado van hasselt', 'one-class classification', 'usb on-the-go', 'costs involved', 'machine learning', 'lymph nodes', 'exploit (computer security)', 'fuzzy logic', 'particle swarm optimization\xa0', 'algorithm', 'training', 'distribution (mathematics)', 'brute-force search', 'simulation', 'convolutional neural network', 'centralized computing', 'medical imaging', 'nonlinearity', 'adversary (cryptography)', 'quantization (signal processing)', 'mapreduce', 'long short-term memory', 'mathematical model', 'computer science', 'computation', 'robot', 'asthma patients demonstrate', 'weight', 'coordinate descent', 'diagnostic test results', 'approximation algorithm', 'maximizes outcomes', 'autoencoder', 'sample complexity', 'real-time clock', 'settling time', 'black bag operation', 'apriori algorithm', 'social inequality', 'marc g. bellemare', 'q-learning', 'experimental results', 'high- and low-level', 'artificial intelligence', 'neural network simulation', 'computer-aided design', 'iteration', 'subnetwork', 'reinforcement learning', 'linear matrix inequality', 'bayesian network', 'atari', 'interval arithmetic', 'end-to-end principle', 'fuzzy set', 'maps characteristics', 'requirement', 'will dabney', 'network topology', 'novel objective', 'time delay', 'genetic algorithm\xa0', 'feedforward neural network', 'state estimation', 'time delays', 'support vector machine', 'constrained optimization', 'ibm systems network architecture', 'granting bails', 'quality of service', 'vocabulary', 'data mining', 'control theory', 'global optimization', 'biological neural networks', 'data model', 'effective interpretable', 'leverages customized checks', 'channel state information', 'hypernymy relations', 'approximation error', 'cognitive radio', 'rémi munos', 'optimal control', 'decision list', 'coefficient', 'neuron', 'experiment', 'open research', 'natural language processing', 'recurrent neural network', 'test set', 'particle swarm optimization', 'nonlinear system', 'genetic algorithm', 'preprocessor', 'markov decision process', 'daily basis', 'optimization\xa0', 'interference (communication)', 'numerical linear algebra', 'super robot monkey team hyperforce go!', 'biogeography-based optimization\xa0', 'telecommunications link', 'frequency band', 'throughput', 'sparse matrix', 'dropout (neural networks)', 'apache spark']
#
#
# year : 2017
# ...
#
#
# The traced topics are:
#
#
# year : 2017
# ['mnist database', 'imagenet']
#
#
# year : 2018
# ['optimization\xa0', 'metaheuristic\xa0', 'exploration and exploitation\xa0', 'swarm intelligence\xa0']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['linguistic scale functions', 'criteria decision', 'criterion values', 'criterion weights']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['semantic web ecosystem', 'dense vector representations', 'easily embedded', 'contextual information', 'human readable', 'distributional models']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['opinion mining', 'sentiment analysis']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['new type', 'paper investigates']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['retrieval efficiency hashing', 'widely applied', 'scale multimedia retrieval', 'separate quantization step', 'sense clustering', 'semantic similarity', 'data pairs', 'image retrieval', 'hash coding']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['massive online classes', 'online classes']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['language text', 'mapping ambiguous terms', 'entity disambiguation', 'resource description framework', 'citation networks', 'knowledge base', 'structured data', 'textual documents']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['methods includes receiving', 'apparatus including', 'programs encoded', 'methods systems', 'input comprising', 'storage media', 'deep network']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['linear multi', 'agent systems']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2016
# ['computer vision', 'object detection']
#
#
# The traced topics are:
#
#
# year : 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'wireless sensor networks\xa0', 'feedback', 'approximation', 'open problem', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['long short-term memory', 'lyapunov fractal', 'fuzzy control system', 'firefly algorithm (fa)\xa0', 'swarm intelligence', 'initial condition', 'computation', 'input lag', 'binary code', 'adversarial examples', 'two-factors second-order fuzzy-trend logical relationship groups', 'baxter (robot)', 'approximation algorithm', 'gradient descent', 'encoder', 'premature convergence', 'benchmark (computing)', 'inverted pendulum', "jensen's inequality", 'autoencoder', 'inference', 'adversarial inputs', 'random forest', 'association rule learning', 'computer vision', 'optimization problem', 'hopfield network', 'social inequality', 'british informatics olympiad', 'force misclassification', 'dynamical system', 'routing', 'high- and low-level', 'wireless sensor networks\xa0', 'feedback', 'approximation', 'open problem', 'sensor', 'neural network simulation', 'firefly algorithm', 'next-generation network', 'cluster analysis', 'samuel j leffler', 'controllers', 'reinforcement learning', 'linear matrix inequality', 'estimated', 'triangular matrix', 'sampling (signal processing)', 'semiconductor industry', 'scheduling (computing)', 'artificial neural network', 'network packet', 'global exponential stability', 'quality of service', 'control theory', 'converge', 'memristor', 'swarm intelligence\xa0', 'data synchronization', 'statistical cluster', 'spectral leakage', 'numerical method', 'differential evolution', 'time complexity', 'sampling - surgical action', 'numerical analysis', 'feature selection', 'global optimization\xa0', 'cognitive radio', 'outline of object recognition', 'heuristic', 'control system', 'big data', 'sawtooth (cellular automaton)', 'sensitivity and specificity', 'experiment', 'recursion', 'natural language processing', 'convolution', 'deep learning', 'mathematical optimization', 'recurrent neural network', 'particle swarm optimization', 'nonlinear system', 'firefly (cache coherence protocol)', 'dual', 'genetic algorithm', 'machine learning', 'interference (communication)', 'algorithm', 'simulation', 'convolutional neural network', 'cloud computing', 'multi-objective optimization', 'throughput', 'neural coding', 'sparse matrix', 'polynomial', 'anatomy regional']
#
#
# The traced topics are:
#
#
# year : 2018
# ['binary image', 'computation']
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['generative adversarial networks', 'instability', 'generative model', 'discriminative model']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['mobile network operators', 'radio access network']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['significantly outperform', 'diverse ranking model', 'art baselines', 'alternating direction method', 'search result diversification']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['paper presents', 'http url']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['exponential family embeddings', 'word embeddings', 'powerful approach']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['critical operation', 'dynamic artifacts', 'semantic web technologies', 'application relying']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['mnist database', 'imagenet']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['intermittent control', 'derived analytically', 'aperiodically intermittent control', 'useful criteria']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['strategy elegantly solves', 'single channel', 'automatic speech recognition', 'target assignment pick']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['mnist cifar10', 'deep neural networks', 'experimental results']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['node attributes', 'link prediction', 'proposed framework', 'dimensional vector representations', 'network embedding', 'vast majority']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['game engine', 'server message block', 'agent architecture', 'interaction']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['algorithm design and analysis', 'prediction algorithms']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['refereed proceedings', 'carefully reviewed', 'book constitutes', 'topical sections named', 'fukuoka japan']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['markov process', 'actuator faults', 'sugeno fuzzy', 'affine model', 'paper proposes', 'nonlinear plant', 'parametric uncertainties']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['noncanonical communication', 'electronic communications']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['stan', 'statistical model']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['shape features', 'extracted based']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['temporal information', 'skeleton sequence']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['order feature interactions', 'factorization machines']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['human language understanding', 'word sense disambiguation']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['level process', 'related questions', 'step high']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['babelnet\xa0', 'microblogs\xa0', 'sentiment analysis\xa0', 'frame semantics\xa0']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************
#
#
#
# The target topic:
#
# year: 2017
# ['search engines', 'knowledge graphs']
#
#
# This topic have not traced any topics.
#
#
# ********************* END THIS TOPIC TRACING ***************************************

# %% [markdown]
# From the results obtained it is possible to notice that not all the topics are able to trace or there is the possibility that they trace, but not necessarily creating a complete chain from one's year to 2018. More reflections are reported on the report.
