# %% [markdown]
# ### Author: Leonardo Picchiami
#
#
# # Metrics Analysis View

# %% [markdown]
# This file shows the application of all ranking metrics on each graph of the ds-1 dataset. For the pagerank metric, both the calculation strategies of the weights are taken into account, while for the node between centrality and the degree centrality weights are not taken into consideration. In this file it is possible to have a general picture of the efficiency of these metrics.

# %%
import warnings
warnings.filterwarnings("ignore")

import sys 

sys.path.append("../../graph")
sys.path.append("..")

import graph as gr
import metrics as me

import pandas as pd
import numpy as np

ds1_path = "../../../dataset_src/ds-1.tsv"
ds2_path = "../../../dataset_src/ds-2.tsv"

# %%
timeline = [str(year) for year in range(2000, 2019)]
print(timeline)

k = 100
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

# %% [markdown]
# Three YearGraph objects are created for each year of the timeline:
#
#  - one with unweigthed ntworkx graph for degree centrality and node betweenness centrality metrics
#  - one with weigthed graph with number of co-citations weights strategy for pagerank metric
#  - one with weigthed graph with fraction of co-citations by authors who have all worked together for pagerank metric

# %%
graphs_timeline = dict()

for year in timeline:
    graphs_timeline[year] = []
    graph = gr.YearGraph(ds1_path, ds2_path, year)
    graph.read()
    graph.build_ds1_graph()
    graphs_timeline[year].append(graph)
    
    graph_frac = gr.YearGraph(ds1_path, ds2_path, year)
    graph_frac.read()
    graph_frac.weights_fraction_cocitations()
    graph_frac.build_ds1_graph()
    graphs_timeline[year].append(graph_frac)
    
    graph_num = gr.YearGraph(ds1_path, ds2_path, year)
    graph_num.read()
    graph_num.weights_number_cocitations()
    graph_num.build_ds1_graph()
    graphs_timeline[year].append(graph_num)

# %% [markdown]
# Function that calculates, for a given year, all the ranks for the analyzed metrics, creates the two tables and if it is active the flag also writes a latex file relative to the two tables.

# %%
def tables_metrics_view(year, latex = False):
    print("Year: {0}{1}".format(year, '\n'))
    
    #Pagerank metric with fraction weights strategy 
    metrics = me.Metrics(graphs_timeline[str(year)][1])
    metrics.metrics_preprocessing()
    metrics.pagerank(k)
    nodes_pagerank_frac = metrics.get_top_k_nodes()
    
    #Pagerank metric with number weights strategy
    metrics = me.Metrics(graphs_timeline[str(year)][2])
    metrics.metrics_preprocessing()
    metrics.pagerank(k)
    nodes_pagerank_num = metrics.get_top_k_nodes()
    
    #Node betweenness metric
    metrics = me.Metrics(graphs_timeline[str(year)][0])
    metrics.metrics_preprocessing()
    metrics.node_betweenness(k)
    nodes_between = metrics.get_top_k_nodes()
    
    #degree centrality metric
    metrics.degree_centrality(k)
    nodes_degree = metrics.get_top_k_nodes()
    
    ranks = [i for i in range(1, len(nodes_pagerank_frac) + 1)]

    data_others = pd.DataFrame(data = {'Rank' : ranks, 'Node Betweenness' : nodes_between, 'Degree Centrality' : nodes_degree})
    data_others = data_others[['Rank', 'Node Betweenness', 'Degree Centrality']]
    
    if latex:
        tables_path = "../../../report/tables/year_{0}/tables_{1}.tex".format(year, year)
        with open(tables_path, "w") as f:
            f.write("{0}{1}{2}".format('\\tab{\\\}', '\n', '\\begin{center}\n'))
            f.write(data_others.to_latex(column_format = '|c|c|c|', index = False, bold_rows = True))
            f.write("{0}".format('\\end{center}\n'))
        
    print(data_others.to_string(index = False))

    print("{0}{1}".format('\n', '\n'))
    data_pagerank = pd.DataFrame(data = {'Rank' : ranks, 'Pagerank_fraction_weigthed' : nodes_pagerank_frac, 'Pagerank_number_weighted' : nodes_pagerank_num})
    data_pagerank = data_pagerank[['Rank', 'Pagerank_fraction_weigthed', 'Pagerank_number_weighted']]
    
    if latex:
        with open(tables_path, "a") as f:
            f.write("{0}{1}{2}".format('\\tab{\\\}', '\n', '\\begin{center}\n'))
            f.write(data_pagerank.to_latex(column_format = '|c|c|c|', index = False, bold_rows = True))
            f.write("{0}".format('\\end{center}\n'))
    
    print(data_pagerank.to_string(index = False))

# %% [markdown]
# ## Year 2000

# %%
#View tables for year 2000
tables_metrics_view(2000, latex = True)
# Out:
# Year: 2000
#
# Rank                  Node Betweenness                                 Degree Centrality
#    1  (artificial neural network, 0.0)           (periodic solution, 0.2727272727272727)
#    2           (nonlinear system, 0.0)                    (43.80.+p, 0.2727272727272727)
#    3                 (simulation, 0.0)                       (delay, 0.2727272727272727)
#    4     (support vector machine, 0.0)         (lyapunov functional, 0.2727272727272727)
#    5             (feature vector, 0.0)           (nonlinear system, 0.18181818181818182)
#    6          (periodic solution, 0.0)                 (simulation, 0.18181818181818182)
#    7                   (43.80.+p, 0.0)     (support vector machine, 0.18181818181818182)
#    8                      (delay, 0.0)             (feature vector, 0.18181818181818182)
#    9  (neural network simulation, 0.0)         (motion estimation , 0.18181818181818182)
#   10         (motion estimation , 0.0)                 (experiment, 0.18181818181818182)
#   11                 (experiment, 0.0)  (artificial neural network, 0.09090909090909091)
#   12        (lyapunov functional, 0.0)  (neural network simulation, 0.09090909090909091)
#
#
#
# Rank                        Pagerank_fraction_weigthed                          Pagerank_number_weighted
#    1            (nonlinear system, 0.1449271498783759)  (artificial neural network, 0.08333333333333333)
#    2                  (simulation, 0.1449271498783759)           (nonlinear system, 0.08333333333333333)
#    3      (support vector machine, 0.1449271498783759)                 (simulation, 0.08333333333333333)
#    4              (feature vector, 0.1449271498783759)     (support vector machine, 0.08333333333333333)
#    5          (motion estimation , 0.1449271498783759)             (feature vector, 0.08333333333333333)
#    6                  (experiment, 0.1449271498783759)          (periodic solution, 0.08333333333333333)
#    7  (artificial neural network, 0.02173951678829072)                   (43.80.+p, 0.08333333333333333)
#    8          (periodic solution, 0.02173951678829072)                      (delay, 0.08333333333333333)
#    9                   (43.80.+p, 0.02173951678829072)  (neural network simulation, 0.08333333333333333)
#   10                      (delay, 0.02173951678829072)         (motion estimation , 0.08333333333333333)
#   11  (neural network simulation, 0.02173951678829072)                 (experiment, 0.08333333333333333)
#   12        (lyapunov functional, 0.02173951678829072)        (lyapunov functional, 0.08333333333333333)

# %% [markdown]
# ## Year 2001

# %%
#View tables for year 2001
tables_metrics_view(2001)
# Out:
# Year: 2001
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1           (signal processing, 0.08994708994708994)            (signal processing, 0.2777777777777778)
#    2            (state estimation, 0.06812169312169311)             (state estimation, 0.2222222222222222)
#    3        (filtering algorithms, 0.03293650793650794)          (state-space methods, 0.1388888888888889)
#    4               (deconvolution, 0.02619047619047619)         (filtering algorithms, 0.1388888888888889)
#    5       (stochastic processes, 0.016798941798941796)         (stochastic processes, 0.1388888888888889)
#    6        (state-space methods, 0.007804232804232805)                (deconvolution, 0.1388888888888889)
#    7  (artificial neural network, 0.006349206349206349)  (multilayer feedforward neural networks, 0.138...
#    8                  (filtering, 0.002645502645502646)                    (increment, 0.1388888888888889)
#    9                (signal processing algorithms, 0.0)          (projection learning, 0.1388888888888889)
#   10                                 (mathematics, 0.0)    (generalization capability, 0.1388888888888889)
#   11                  (feedforward neural network, 0.0)  (generalization (psychology), 0.1388888888888889)
#   12                           (formal ontologies, 0.0)  (reproducing kernel hilbert space, 0.138888888...
#   13                                (laboratories, 0.0)    (artificial neural network, 0.1111111111111111)
#   14                                      (fading, 0.0)                    (filtering, 0.1111111111111111)
#   15                         (computer simulation, 0.0)         (computer simulation, 0.08333333333333333)
#   16                              (linear systems, 0.0)              (linear systems, 0.08333333333333333)
#   17                            (cluster analysis, 0.0)  (signal processing algorithms, 0.0555555555555...
#   18                            (bayesian methods, 0.0)                 (mathematics, 0.05555555555555555)
#   19                   (markov chain monte carlo , 0.0)  (feedforward neural network, 0.05555555555555555)
#   20      (multilayer feedforward neural networks, 0.0)                (laboratories, 0.05555555555555555)
#   21                                   (increment, 0.0)                      (fading, 0.05555555555555555)
#   22                         (projection learning, 0.0)            (cluster analysis, 0.05555555555555555)
#   23                   (generalization capability, 0.0)            (bayesian methods, 0.05555555555555555)
#   24                 (generalization (psychology), 0.0)         (widely acknowledged, 0.05555555555555555)
#   25                                  (s function, 0.0)           (domain ontologies, 0.05555555555555555)
#   26                         (widely acknowledged, 0.0)         (monte carlo methods, 0.05555555555555555)
#   27                           (domain ontologies, 0.0)                   (algorithm, 0.05555555555555555)
#   28                         (monte carlo methods, 0.0)                   (real life, 0.05555555555555555)
#   29                                   (algorithm, 0.0)                (useful tools, 0.05555555555555555)
#   30         (transportable machine understanding, 0.0)          (formal ontologies, 0.027777777777777776)
#   31                                   (real life, 0.0)  (markov chain monte carlo , 0.027777777777777776)
#   32                        (importance sampling , 0.0)                 (s function, 0.027777777777777776)
#   33                            (particle filters, 0.0)  (transportable machine understanding, 0.027777...
#   34            (reproducing kernel hilbert space, 0.0)       (importance sampling , 0.027777777777777776)
#   35                              (passage method, 0.0)           (particle filters, 0.027777777777777776)
#   36                           (smoothing methods, 0.0)             (passage method, 0.027777777777777776)
#   37                                (useful tools, 0.0)          (smoothing methods, 0.027777777777777776)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1            (signal processing, 0.0845129494983329)           (signal processing, 0.08370120291936121)
#    2            (state estimation, 0.06613390758652847)            (state estimation, 0.04831996601954529)
#    3        (filtering algorithms, 0.04734091338323223)        (state-space methods, 0.043241098610303216)
#    4                (deconvolution, 0.0453800023781118)   (artificial neural network, 0.04314845454648318)
#    5         (state-space methods, 0.04172344860375214)        (stochastic processes, 0.03803220778262897)
#    6       (stochastic processes, 0.041327790904923556)                   (filtering, 0.03291959739225151)
#    7                   (filtering, 0.03455336270715766)       (filtering algorithms, 0.032546323806015375)
#    8  (feedforward neural network, 0.03311258278115174)              (deconvolution, 0.030360560796237425)
#    9   (artificial neural network, 0.03311258278115174)  (multilayer feedforward neural networks, 0.027...
#   10         (widely acknowledged, 0.03311258278115174)                  (increment, 0.027027027027027035)
#   11           (domain ontologies, 0.03311258278115174)        (projection learning, 0.027027027027027035)
#   12                   (algorithm, 0.03311258278115174)  (generalization capability, 0.027027027027027035)
#   13                (useful tools, 0.03311258278115174)  (generalization (psychology), 0.02702702702702...
#   14          (formal ontologies, 0.033112582781151735)  (reproducing kernel hilbert space, 0.027027027...
#   15  (markov chain monte carlo , 0.033112582781151735)           (formal ontologies, 0.02702702702702703)
#   16                 (s function, 0.033112582781151735)   (markov chain monte carlo , 0.02702702702702703)
#   17  (transportable machine understanding, 0.033112...                  (s function, 0.02702702702702703)
#   18       (importance sampling , 0.033112582781151735)         (widely acknowledged, 0.02702702702702703)
#   19             (passage method, 0.033112582781151735)           (domain ontologies, 0.02702702702702703)
#   20              (linear systems, 0.02749984612927935)  (transportable machine understanding, 0.027027...
#   21        (computer simulation, 0.027499846129279346)        (importance sampling , 0.02702702702702703)
#   22                (laboratories, 0.02113149403510915)              (passage method, 0.02702702702702703)
#   23                      (fading, 0.02113149403510915)                (useful tools, 0.02702702702702703)
#   24  (signal processing algorithms, 0.0202003186337...  (feedforward neural network, 0.022996670147162...
#   25        (monte carlo methods, 0.020043256054692513)           (cluster analysis, 0.022996670147162994)
#   26           (bayesian methods, 0.019493136675966492)                  (algorithm, 0.022996670147162994)
#   27                (mathematics, 0.019243591941337023)                  (real life, 0.022996670147162994)
#   28           (particle filters, 0.013016648879645973)  (signal processing algorithms, 0.0212369326994...
#   29          (smoothing methods, 0.012681899703349667)               (laboratories, 0.017808225771546393)
#   30           (cluster analysis, 0.004966887418324936)                     (fading, 0.017808225771546393)
#   31  (multilayer feedforward neural networks, 0.004...           (bayesian methods, 0.016458188574087117)
#   32                  (increment, 0.004966887418324936)         (computer simulation, 0.01643554313354865)
#   33        (projection learning, 0.004966887418324936)              (linear systems, 0.01643554313354865)
#   34  (generalization capability, 0.004966887418324936)                (mathematics, 0.016366046635439162)
#   35  (generalization (psychology), 0.00496688741832...         (monte carlo methods, 0.01142861714308789)
#   36                  (real life, 0.004966887418324936)          (smoothing methods, 0.008355379174499954)
#   37  (reproducing kernel hilbert space, 0.004966887...           (particle filters, 0.008005800096357697)

# %% [markdown]
# ## Year 2002

# %%
#View tables for year 2002
tables_metrics_view(2002, latex = True)
# Out:
# Year: 2002
#
# Rank                       Node Betweenness                                  Degree Centrality
#    1                (bayesian methods, 0.0)  (independent component analysis, 0.22222222222...
#    2             (monte carlo methods, 0.0)      (blind source separation, 0.2222222222222222)
#    3            (filtering algorithms, 0.0)             (important method, 0.2222222222222222)
#    4               (lyapunov function, 0.0)       (overcomplete situation, 0.2222222222222222)
#    5  (independent component analysis, 0.0)        (unsupervised learning, 0.2222222222222222)
#    6         (blind source separation, 0.0)            (bayesian methods, 0.16666666666666666)
#    7                (important method, 0.0)         (monte carlo methods, 0.16666666666666666)
#    8          (overcomplete situation, 0.0)           (speech processing, 0.16666666666666666)
#    9               (speech processing, 0.0)       (intellectual property, 0.16666666666666666)
#   10                 (business models, 0.0)             (program product, 0.16666666666666666)
#   11           (intellectual property, 0.0)            (patent trademark, 0.16666666666666666)
#   12                 (program product, 0.0)           (signal processing, 0.16666666666666666)
#   13                (patent trademark, 0.0)        (organization company, 0.16666666666666666)
#   14               (signal processing, 0.0)        (filtering algorithms, 0.05555555555555555)
#   15                (state estimation, 0.0)           (lyapunov function, 0.05555555555555555)
#   16    (global exponential stability, 0.0)             (business models, 0.05555555555555555)
#   17           (unsupervised learning, 0.0)            (state estimation, 0.05555555555555555)
#   18               (consider thinking, 0.0)  (global exponential stability, 0.0555555555555...
#   19            (organization company, 0.0)           (consider thinking, 0.05555555555555555)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1      (overcomplete situation, 0.05780343855118794)            (bayesian methods, 0.05434528253466711)
#    2       (unsupervised learning, 0.05780343855118794)         (monte carlo methods, 0.05434528253466711)
#    3            (bayesian methods, 0.05780343855118793)           (signal processing, 0.05434528253466711)
#    4         (monte carlo methods, 0.05780343855118793)        (filtering algorithms, 0.05263157894736842)
#    5        (filtering algorithms, 0.05780343855118793)           (lyapunov function, 0.05263157894736842)
#    6           (lyapunov function, 0.05780343855118793)  (independent component analysis, 0.05263157894...
#    7  (independent component analysis, 0.05780343855...     (blind source separation, 0.05263157894736842)
#    8     (blind source separation, 0.05780343855118793)            (important method, 0.05263157894736842)
#    9            (important method, 0.05780343855118793)             (business models, 0.05263157894736842)
#   10           (speech processing, 0.05780343855118793)            (state estimation, 0.05263157894736842)
#   11       (intellectual property, 0.05780343855118793)  (global exponential stability, 0.0526315789473...
#   12             (program product, 0.05780343855118793)       (unsupervised learning, 0.05263157894736842)
#   13            (patent trademark, 0.05780343855118793)           (consider thinking, 0.05263157894736842)
#   14           (signal processing, 0.05780343855118793)        (organization company, 0.05263157894736842)
#   15            (state estimation, 0.05780343855118793)      (overcomplete situation, 0.05263157894736841)
#   16  (global exponential stability, 0.0578034385511...       (intellectual property, 0.05263157894736841)
#   17        (organization company, 0.05780343855118793)             (program product, 0.05263157894736841)
#   18            (business models, 0.008670772314902552)            (patent trademark, 0.05263157894736841)
#   19          (consider thinking, 0.008670772314902552)           (speech processing, 0.04749046818547229)

# %% [markdown]
# ## Year 2003

# %%
#View tables for year 2003
tables_metrics_view(2003)
# Out:
# Year: 2003
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1  (global exponential stability, 0.0234972677595...  (global exponential stability, 0.1475409836065...
#    2                  (algorithm, 0.013114754098360656)                   (algorithm, 0.14754098360655737)
#    3        (lyapunov functional, 0.009836065573770491)  (preliminary results provide, 0.11475409836065...
#    4   (recurrent neural networks, 0.00546448087431694)      (research program aimed, 0.11475409836065574)
#    5                (computation, 0.001639344262295082)  (dolce foundational ontology, 0.11475409836065...
#    6                                    (85.40.ls, 0.0)        (formal specification, 0.11475409836065574)
#    7                                    (43.80.+p, 0.0)         (ontowordnet project, 0.11475409836065574)
#    8                                   (filtering, 0.0)             (progress report, 0.11475409836065574)
#    9                         (state-space methods, 0.0)      (consistent modularized, 0.11475409836065574)
#   10                                    (87.18.sn, 0.0)     (research program aiming, 0.11475409836065574)
#   11                 (global asymptotic stability, 0.0)              (paper presents, 0.09836065573770492)
#   12                 (preliminary results provide, 0.0)            (web applications, 0.09836065573770492)
#   13                      (research program aimed, 0.0)         (existing techniques, 0.09836065573770492)
#   14                 (dolce foundational ontology, 0.0)           (visual perception, 0.09836065573770492)
#   15                        (formal specification, 0.0)   (tree independent approach, 0.09836065573770492)
#   16                         (ontowordnet project, 0.0)       (visual representation, 0.09836065573770492)
#   17                             (progress report, 0.0)   (automatic page adaptation, 0.09836065573770492)
#   18                      (consistent modularized, 0.0)               (feature vector, 0.0819672131147541)
#   19                              (feature vector, 0.0)        (first-order predicate, 0.0819672131147541)
#   20                       (first-order predicate, 0.0)                    (real life, 0.0819672131147541)
#   21                                   (real life, 0.0)                    (heuristic, 0.0819672131147541)
#   22                                   (heuristic, 0.0)      (really simple discovery, 0.0819672131147541)
#   23                              (paper presents, 0.0)                    (85.40.ls, 0.06557377049180328)
#   24                            (web applications, 0.0)                    (43.80.+p, 0.06557377049180328)
#   25                         (existing techniques, 0.0)                    (87.18.sn, 0.06557377049180328)
#   26                           (visual perception, 0.0)         (text categorization, 0.06557377049180328)
#   27                   (tree independent approach, 0.0)              (computed using, 0.06557377049180328)
#   28                       (visual representation, 0.0)      (support vector machine, 0.06557377049180328)
#   29                            (bayesian methods, 0.0)  (combines distributional clustering, 0.0655737...
#   30                         (pattern recognition, 0.0)                    (87.10.+e, 0.06557377049180328)
#   31                              (neural network, 0.0)                 (computation, 0.06557377049180328)
#   32                      (scheduling (computing), 0.0)      (cluster representation, 0.06557377049180328)
#   33                          (monte carlo method, 0.0)            (bayesian methods, 0.04918032786885246)
#   34                              (grid computing, 0.0)      (scheduling (computing), 0.04918032786885246)
#   35                    (random number generation, 0.0)          (monte carlo method, 0.04918032786885246)
#   36                       (walk on spheres (wos), 0.0)              (grid computing, 0.04918032786885246)
#   37                                    (87.15.vv, 0.0)       (walk on spheres (wos), 0.04918032786885246)
#   38                                    (84.37.+q, 0.0)                    (87.15.vv, 0.04918032786885246)
#   39                    (dimensionality reduction, 0.0)                    (84.37.+q, 0.04918032786885246)
#   40                  (original bayesian approach, 0.0)               (deconvolution, 0.04918032786885246)
#   41                            (young inequality, 0.0)                  (robustness, 0.04918032786885246)
#   42                         (text categorization, 0.0)         (lyapunov functional, 0.04918032786885246)
#   43                              (computed using, 0.0)           (signal processing, 0.04918032786885246)
#   44                      (support vector machine, 0.0)                    (82.20.pm, 0.04918032786885246)
#   45          (combines distributional clustering, 0.0)                   (filtering, 0.03278688524590164)
#   46                               (deconvolution, 0.0)         (state-space methods, 0.03278688524590164)
#   47                                  (robustness, 0.0)   (recurrent neural networks, 0.03278688524590164)
#   48                                    (87.10.+e, 0.0)         (pattern recognition, 0.03278688524590164)
#   49                            (state estimation, 0.0)    (dimensionality reduction, 0.03278688524590164)
#   50                     (research program aiming, 0.0)            (young inequality, 0.03278688524590164)
#   51                     (really simple discovery, 0.0)            (state estimation, 0.03278688524590164)
#   52                   (automatic page adaptation, 0.0)                 (scalability, 0.03278688524590164)
#   53                           (signal processing, 0.0)  (singular value decomposition, 0.0327868852459...
#   54                                 (scalability, 0.0)  (global asymptotic stability, 0.01639344262295...
#   55                  (content-addressable memory, 0.0)              (neural network, 0.01639344262295082)
#   56                           (periodic solution, 0.0)    (random number generation, 0.01639344262295082)
#   57                             (neural networks, 0.0)  (original bayesian approach, 0.01639344262295082)
#   58                       (sufficient conditions, 0.0)  (content-addressable memory, 0.01639344262295082)
#   59                                    (82.20.pm, 0.0)           (periodic solution, 0.01639344262295082)
#   60                (singular value decomposition, 0.0)             (neural networks, 0.01639344262295082)
#   61                           (noiseless context, 0.0)       (sufficient conditions, 0.01639344262295082)
#   62                      (cluster representation, 0.0)           (noiseless context, 0.01639344262295082)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (global exponential stability, 0.0480906694115...  (global exponential stability, 0.0440033207860...
#    2                   (algorithm, 0.03602199337717991)                   (algorithm, 0.03318016730618736)
#    3                (computation, 0.024236832294060023)                (computation, 0.022907773487308877)
#    4                   (85.40.ls, 0.019589590971926273)                   (87.10.+e, 0.021955377252055604)
#    5                   (43.80.+p, 0.019589590971926273)                     (85.40.ls, 0.0219553772520556)
#    6                   (87.18.sn, 0.019589590971926273)                     (43.80.+p, 0.0219553772520556)
#    7                   (87.10.+e, 0.019589590971926273)                     (87.18.sn, 0.0219553772520556)
#    8        (lyapunov functional, 0.019212204905601122)                  (real life, 0.018577277254703813)
#    9              (feature vector, 0.01863059076567867)                  (heuristic, 0.018577277254703813)
#   10       (first-order predicate, 0.01863059076567867)              (feature vector, 0.01857727725470381)
#   11                  (real life, 0.018630590765678665)       (first-order predicate, 0.01857727725470381)
#   12                  (heuristic, 0.018630590765678665)     (really simple discovery, 0.01857727725470381)
#   13    (really simple discovery, 0.018630590765678665)      (scheduling (computing), 0.01681671870702021)
#   14     (scheduling (computing), 0.017792444759863964)          (monte carlo method, 0.01681671870702021)
#   15         (monte carlo method, 0.017792444759863964)              (grid computing, 0.01681671870702021)
#   16             (grid computing, 0.017792444759863964)                  (filtering, 0.016129032258064516)
#   17                   (filtering, 0.01706484641638225)        (state-space methods, 0.016129032258064516)
#   18         (state-space methods, 0.01706484641638225)  (preliminary results provide, 0.01612903225806...
#   19              (neural network, 0.01706484641638225)     (research program aimed, 0.016129032258064516)
#   20  (original bayesian approach, 0.01706484641638225)  (dolce foundational ontology, 0.01612903225806...
#   21         (text categorization, 0.01706484641638225)       (formal specification, 0.016129032258064516)
#   22              (computed using, 0.01706484641638225)        (ontowordnet project, 0.016129032258064516)
#   23      (support vector machine, 0.01706484641638225)            (progress report, 0.016129032258064516)
#   24  (combines distributional clustering, 0.0170648...     (consistent modularized, 0.016129032258064516)
#   25            (state estimation, 0.01706484641638225)             (paper presents, 0.016129032258064516)
#   26  (content-addressable memory, 0.01706484641638225)           (web applications, 0.016129032258064516)
#   27           (noiseless context, 0.01706484641638225)        (existing techniques, 0.016129032258064516)
#   28      (cluster representation, 0.01706484641638225)          (visual perception, 0.016129032258064516)
#   29      (walk on spheres (wos), 0.017064846416382246)  (tree independent approach, 0.016129032258064516)
#   30                   (87.15.vv, 0.017064846416382246)      (visual representation, 0.016129032258064516)
#   31                   (84.37.+q, 0.017064846416382246)           (bayesian methods, 0.016129032258064516)
#   32                   (82.20.pm, 0.017064846416382246)             (neural network, 0.016129032258064516)
#   33  (preliminary results provide, 0.01706484641638...      (walk on spheres (wos), 0.016129032258064516)
#   34     (research program aimed, 0.017064846416382243)                   (87.15.vv, 0.016129032258064516)
#   35  (dolce foundational ontology, 0.01706484641638...                   (84.37.+q, 0.016129032258064516)
#   36       (formal specification, 0.017064846416382243)  (original bayesian approach, 0.016129032258064...
#   37        (ontowordnet project, 0.017064846416382243)              (deconvolution, 0.016129032258064516)
#   38            (progress report, 0.017064846416382243)                 (robustness, 0.016129032258064516)
#   39     (consistent modularized, 0.017064846416382243)           (state estimation, 0.016129032258064516)
#   40             (paper presents, 0.017064846416382243)    (research program aiming, 0.016129032258064516)
#   41           (web applications, 0.017064846416382243)  (automatic page adaptation, 0.016129032258064516)
#   42        (existing techniques, 0.017064846416382243)  (content-addressable memory, 0.016129032258064...
#   43          (visual perception, 0.017064846416382243)          (noiseless context, 0.016129032258064516)
#   44  (tree independent approach, 0.017064846416382243)        (text categorization, 0.016129032258064512)
#   45      (visual representation, 0.017064846416382243)             (computed using, 0.016129032258064512)
#   46    (research program aiming, 0.017064846416382243)     (support vector machine, 0.016129032258064512)
#   47  (automatic page adaptation, 0.017064846416382243)  (combines distributional clustering, 0.0161290...
#   48  (recurrent neural networks, 0.015930540567545358)          (signal processing, 0.016129032258064512)
#   49           (young inequality, 0.012542617906582627)                   (82.20.pm, 0.016129032258064512)
#   50        (pattern recognition, 0.010368379239562318)     (cluster representation, 0.016129032258064512)
#   51   (dimensionality reduction, 0.010368379239562318)        (lyapunov functional, 0.015994248670588965)
#   52                (scalability, 0.010368379239562318)  (recurrent neural networks, 0.013101362704432028)
#   53  (singular value decomposition, 0.0103683792395...  (singular value decomposition, 0.0103387314438...
#   54  (global asymptotic stability, 0.00933738756440...   (dimensionality reduction, 0.010338731443847555)
#   55   (random number generation, 0.007710065508259311)           (young inequality, 0.009077170385590682)
#   56          (periodic solution, 0.007102124251079297)  (global asymptotic stability, 0.00798250211502...
#   57            (neural networks, 0.007102124251079297)   (random number generation, 0.007287231681953032)
#   58      (sufficient conditions, 0.007102124251079297)        (pattern recognition, 0.007273153056621805)
#   59           (bayesian methods, 0.002559726962457338)               (scalability, 0.0072731530566218046)
#   60              (deconvolution, 0.002559726962457338)          (periodic solution, 0.005189424475631763)
#   61                 (robustness, 0.002559726962457338)            (neural networks, 0.005189424475631763)
#   62          (signal processing, 0.002559726962457338)      (sufficient conditions, 0.005189424475631763)

# %% [markdown]
# ## Year 2004

# %%
#View tables for year 2004
tables_metrics_view(2004)
# Out:
# Year: 2004
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1                  (algorithm, 0.015126050420168066)  (different learning circumstances, 0.117647058...
#    2      (subgroup a nepoviruses, 0.00784313725490196)  (conceptualisation effort produced, 0.11764705...
#    3            (rule (guideline), 0.00784313725490196)  (proposed evaluation strategy, 0.1176470588235...
#    4                  (real life, 0.006722689075630252)               (critical task, 0.11764705882352941)
#    5                   (web page, 0.001680672268907563)  (ontology learning algorithms, 0.1176470588235...
#    6  (mathematical optimization, 0.0011204481792717...          (domain specialists, 0.11764705882352941)
#    7                       (benchmark (computing), 0.0)  (detailed quantitative analysis, 0.11764705882...
#    8                 (particle swarm optimization, 0.0)         (knowledge engineers, 0.11764705882352941)
#    9                          (stochastic process, 0.0)              (paper provides, 0.11764705882352941)
#   10                    (random number generation, 0.0)  (ontolearn ontology learning, 0.11764705882352...
#   11                          (parallel computing, 0.0)         (ontology evaluation, 0.11764705882352941)
#   12                                     (shading, 0.0)                 (apply cross, 0.10588235294117647)
#   13                          (photometric stereo, 0.0)  (sentence pronoun resolution, 0.10588235294117...
#   14                                         (map, 0.0)            (document summary, 0.10588235294117647)
#   15                              (view synthesis, 0.0)        (summarizing document, 0.10588235294117647)
#   16                               (interpolation, 0.0)      (semantic normalization, 0.10588235294117647)
#   17                                    (test set, 0.0)              (semantic graph, 0.10588235294117647)
#   18                   (facial recognition system, 0.0)        (reference resolution, 0.10588235294117647)
#   19                                   (heuristic, 0.0)           (extract sentences, 0.10588235294117647)
#   20                          (monte carlo method, 0.0)           (original document, 0.10588235294117647)
#   21               (linear congruential generator, 0.0)     (deep syntactic analysis, 0.10588235294117647)
#   22               (pseudorandom number generator, 0.0)                   (algorithm, 0.08235294117647059)
#   23                              (digital images, 0.0)      (subgroup a nepoviruses, 0.08235294117647059)
#   24                                (rapid growth, 0.0)            (rule (guideline), 0.08235294117647059)
#   25                            (link information, 0.0)                    (web page, 0.08235294117647059)
#   26                            (efficient method, 0.0)         (previous work shows, 0.07058823529411765)
#   27                           (increasing demand, 0.0)            (uniform approach, 0.07058823529411765)
#   28                            (block containing, 0.0)             (consistent view, 0.07058823529411765)
#   29                                     (biasing, 0.0)                  (user study, 0.07058823529411765)
#   30                                 (apply cross, 0.0)           (multiple segments, 0.07058823529411765)
#   31                 (sentence pronoun resolution, 0.0)       (differentiating noisy, 0.07058823529411765)
#   32                            (document summary, 0.0)        (certain applications, 0.07058823529411765)
#   33                        (summarizing document, 0.0)                (large number, 0.07058823529411765)
#   34                      (semantic normalization, 0.0)                   (real time, 0.07058823529411765)
#   35                              (semantic graph, 0.0)         (desktop workstation, 0.07058823529411765)
#   36                        (reference resolution, 0.0)             (recent advances, 0.07058823529411765)
#   37                           (extract sentences, 0.0)                 (time vision, 0.07058823529411765)
#   38                           (original document, 0.0)        (implementing systems, 0.07058823529411765)
#   39                           (digital libraries, 0.0)   (random number generation, 0.058823529411764705)
#   40                            (fundamental ions, 0.0)         (parallel computing, 0.058823529411764705)
#   41                 (complex information systems, 0.0)                    (shading, 0.058823529411764705)
#   42                (linear discriminant analysis, 0.0)         (photometric stereo, 0.058823529411764705)
#   43     (bi-directional associative memory (bam), 0.0)                        (map, 0.058823529411764705)
#   44                                   (roc curve, 0.0)             (view synthesis, 0.058823529411764705)
#   45            (different learning circumstances, 0.0)              (interpolation, 0.058823529411764705)
#   46           (conceptualisation effort produced, 0.0)         (monte carlo method, 0.058823529411764705)
#   47                (proposed evaluation strategy, 0.0)  (linear congruential generator, 0.058823529411...
#   48                               (critical task, 0.0)  (pseudorandom number generator, 0.058823529411...
#   49                (ontology learning algorithms, 0.0)                  (real life, 0.058823529411764705)
#   50                          (domain specialists, 0.0)             (autostereogram, 0.058823529411764705)
#   51              (detailed quantitative analysis, 0.0)                (computation, 0.058823529411764705)
#   52                         (knowledge engineers, 0.0)  (mathematical optimization, 0.047058823529411764)
#   53                              (paper provides, 0.0)             (digital images, 0.047058823529411764)
#   54                 (ontolearn ontology learning, 0.0)               (rapid growth, 0.047058823529411764)
#   55                         (previous work shows, 0.0)           (efficient method, 0.047058823529411764)
#   56                            (uniform approach, 0.0)          (increasing demand, 0.047058823529411764)
#   57                             (consistent view, 0.0)           (images available, 0.047058823529411764)
#   58                                  (user study, 0.0)           (digital libraries, 0.03529411764705882)
#   59                           (multiple segments, 0.0)            (fundamental ions, 0.03529411764705882)
#   60                       (differentiating noisy, 0.0)  (complex information systems, 0.03529411764705...
#   61                               (link analysis, 0.0)                   (roc curve, 0.03529411764705882)
#   62                                  (consortium, 0.0)                       (large, 0.03529411764705882)
#   63                           (apriori algorithm, 0.0)                       (class, 0.03529411764705882)
#   64          (ant colony optimization algorithms, 0.0)    (interoperability suffers, 0.03529411764705882)
#   65                                       (large, 0.0)      (benchmark (computing), 0.023529411764705882)
#   66                                       (class, 0.0)  (particle swarm optimization, 0.02352941176470...
#   67                        (certain applications, 0.0)                  (heuristic, 0.023529411764705882)
#   68                                (large number, 0.0)           (link information, 0.023529411764705882)
#   69                                   (real time, 0.0)           (block containing, 0.023529411764705882)
#   70                         (desktop workstation, 0.0)  (linear discriminant analysis, 0.0235294117647...
#   71                             (recent advances, 0.0)                 (consortium, 0.023529411764705882)
#   72                                 (time vision, 0.0)          (apriori algorithm, 0.023529411764705882)
#   73                      (reinforcement learning, 0.0)  (ant colony optimization algorithms, 0.0235294...
#   74                              (autostereogram, 0.0)                 (experiment, 0.023529411764705882)
#   75                                 (overfitting, 0.0)       (accurately extracted, 0.023529411764705882)
#   76                                  (experiment, 0.0)  (apache ant (another neat tool), 0.02352941176...
#   77                                    (database, 0.0)         (stochastic process, 0.011764705882352941)
#   78                                 (computation, 0.0)                   (test set, 0.011764705882352941)
#   79                            (images available, 0.0)  (facial recognition system, 0.011764705882352941)
#   80                        (accurately extracted, 0.0)                    (biasing, 0.011764705882352941)
#   81                     (deep syntactic analysis, 0.0)  (bi-directional associative memory (bam), 0.01...
#   82                    (interoperability suffers, 0.0)              (link analysis, 0.011764705882352941)
#   83                         (lyapunov functional, 0.0)     (reinforcement learning, 0.011764705882352941)
#   84                         (ontology evaluation, 0.0)                (overfitting, 0.011764705882352941)
#   85              (apache ant (another neat tool), 0.0)                   (database, 0.011764705882352941)
#   86                        (implementing systems, 0.0)        (lyapunov functional, 0.011764705882352941)
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1                  (algorithm, 0.030722278862506256)                   (algorithm, 0.02957757915958128)
#    2     (subgroup a nepoviruses, 0.024496386337981835)           (rule (guideline), 0.023901740646398426)
#    3           (rule (guideline), 0.024496386337981835)     (subgroup a nepoviruses, 0.023901740646398422)
#    4  (mathematical optimization, 0.019871136791998652)   (mathematical optimization, 0.02022117792492558)
#    5                  (real life, 0.018526191652255424)                     (real life, 0.015633855065748)
#    6                   (web page, 0.016984821813357583)                   (web page, 0.015306089597323451)
#    7        (previous work shows, 0.013707176388407608)  (particle swarm optimization, 0.01296419625505...
#    8           (uniform approach, 0.013707176388407608)        (previous work shows, 0.012352397307393941)
#    9            (consistent view, 0.013707176388407608)           (uniform approach, 0.012352397307393941)
#   10                 (user study, 0.013707176388407608)            (consistent view, 0.012352397307393941)
#   11          (multiple segments, 0.013707176388407608)                 (user study, 0.012352397307393941)
#   12      (differentiating noisy, 0.013707176388407608)          (multiple segments, 0.012352397307393941)
#   13              (critical task, 0.012903225806451618)      (differentiating noisy, 0.012352397307393941)
#   14  (ontology learning algorithms, 0.0129032258064...       (certain applications, 0.011627906976744191)
#   15         (domain specialists, 0.012903225806451618)               (large number, 0.011627906976744191)
#   16  (detailed quantitative analysis, 0.01290322580...    (random number generation, 0.01162790697674419)
#   17        (knowledge engineers, 0.012903225806451618)          (parallel computing, 0.01162790697674419)
#   18             (paper provides, 0.012903225806451618)                     (shading, 0.01162790697674419)
#   19  (ontolearn ontology learning, 0.01290322580645...          (photometric stereo, 0.01162790697674419)
#   20        (ontology evaluation, 0.012903225806451618)                         (map, 0.01162790697674419)
#   21   (random number generation, 0.012903225806451616)              (view synthesis, 0.01162790697674419)
#   22         (parallel computing, 0.012903225806451616)               (interpolation, 0.01162790697674419)
#   23                    (shading, 0.012903225806451616)          (monte carlo method, 0.01162790697674419)
#   24         (photometric stereo, 0.012903225806451616)  (linear congruential generator, 0.011627906976...
#   25                        (map, 0.012903225806451616)  (pseudorandom number generator, 0.011627906976...
#   26             (view synthesis, 0.012903225806451616)                   (real time, 0.01162790697674419)
#   27              (interpolation, 0.012903225806451616)         (desktop workstation, 0.01162790697674419)
#   28         (monte carlo method, 0.012903225806451616)             (recent advances, 0.01162790697674419)
#   29  (linear congruential generator, 0.012903225806...                 (time vision, 0.01162790697674419)
#   30  (pseudorandom number generator, 0.012903225806...              (autostereogram, 0.01162790697674419)
#   31  (different learning circumstances, 0.012903225...                 (computation, 0.01162790697674419)
#   32  (conceptualisation effort produced, 0.01290322...        (implementing systems, 0.01162790697674419)
#   33  (proposed evaluation strategy, 0.0129032258064...                   (test set, 0.011627906976744186)
#   34             (autostereogram, 0.012903225806451616)  (facial recognition system, 0.011627906976744186)
#   35                (computation, 0.012903225806451616)             (digital images, 0.011627906976744186)
#   36                   (test set, 0.012903225806451615)               (rapid growth, 0.011627906976744186)
#   37  (facial recognition system, 0.012903225806451615)           (link information, 0.011627906976744186)
#   38           (link information, 0.012903225806451615)           (efficient method, 0.011627906976744186)
#   39           (block containing, 0.012903225806451615)          (increasing demand, 0.011627906976744186)
#   40  (bi-directional associative memory (bam), 0.01...           (block containing, 0.011627906976744186)
#   41       (certain applications, 0.012903225806451615)          (digital libraries, 0.011627906976744186)
#   42               (large number, 0.012903225806451615)           (fundamental ions, 0.011627906976744186)
#   43                  (real time, 0.012903225806451615)  (complex information systems, 0.01162790697674...
#   44        (desktop workstation, 0.012903225806451615)  (bi-directional associative memory (bam), 0.01...
#   45            (recent advances, 0.012903225806451615)  (different learning circumstances, 0.011627906...
#   46                (overfitting, 0.012903225806451615)  (conceptualisation effort produced, 0.01162790...
#   47                   (database, 0.012903225806451615)  (proposed evaluation strategy, 0.0116279069767...
#   48       (accurately extracted, 0.012903225806451615)              (critical task, 0.011627906976744186)
#   49        (lyapunov functional, 0.012903225806451615)  (ontology learning algorithms, 0.0116279069767...
#   50                (time vision, 0.012903225806451613)         (domain specialists, 0.011627906976744186)
#   51       (implementing systems, 0.012903225806451613)  (detailed quantitative analysis, 0.01162790697...
#   52           (efficient method, 0.012903225806451611)        (knowledge engineers, 0.011627906976744186)
#   53          (increasing demand, 0.012903225806451611)             (paper provides, 0.011627906976744186)
#   54           (images available, 0.012903225806451611)  (ontolearn ontology learning, 0.01162790697674...
#   55              (digital images, 0.01290322580645161)                (overfitting, 0.011627906976744186)
#   56                (rapid growth, 0.01290322580645161)                   (database, 0.011627906976744186)
#   57           (digital libraries, 0.01290322580645161)           (images available, 0.011627906976744186)
#   58            (fundamental ions, 0.01290322580645161)       (accurately extracted, 0.011627906976744186)
#   59  (complex information systems, 0.01290322580645...   (interoperability suffers, 0.011627906976744186)
#   60    (interoperability suffers, 0.01290322580645161)        (lyapunov functional, 0.011627906976744186)
#   61      (benchmark (computing), 0.011819666240989016)        (ontology evaluation, 0.011627906976744186)
#   62                 (experiment, 0.011525698475500919)                (apply cross, 0.011627906976744182)
#   63  (linear discriminant analysis, 0.0115256984755...  (sentence pronoun resolution, 0.01162790697674...
#   64                   (roc curve, 0.01103501305407639)           (document summary, 0.011627906976744182)
#   65                      (large, 0.011003068273189183)       (summarizing document, 0.011627906976744182)
#   66                      (class, 0.011003068273189183)     (semantic normalization, 0.011627906976744182)
#   67  (ant colony optimization algorithms, 0.0098533...             (semantic graph, 0.011627906976744182)
#   68  (apache ant (another neat tool), 0.00985331123...       (reference resolution, 0.011627906976744182)
#   69  (particle swarm optimization, 0.00977392904826...          (extract sentences, 0.011627906976744182)
#   70                 (consortium, 0.008841140273196154)          (original document, 0.011627906976744182)
#   71          (apriori algorithm, 0.008841140273196154)    (deep syntactic analysis, 0.011627906976744182)
#   72                  (heuristic, 0.007886462779349374)                  (roc curve, 0.009183424105478991)
#   73         (stochastic process, 0.005663542838215506)                      (class, 0.009105432059729373)
#   74                    (biasing, 0.005663542838215506)                       (large, 0.00910543205972937)
#   75     (reinforcement learning, 0.005663542838215506)  (linear discriminant analysis, 0.0084682112813...
#   76              (link analysis, 0.003997926307809676)                 (experiment, 0.008468211281305128)
#   77               (apply cross, 0.0019354838709677422)      (benchmark (computing), 0.008017738141129474)
#   78  (sentence pronoun resolution, 0.00193548387096...  (ant colony optimization algorithms, 0.0078892...
#   79          (document summary, 0.0019354838709677422)  (apache ant (another neat tool), 0.00788922453...
#   80      (summarizing document, 0.0019354838709677422)                 (consortium, 0.007654637223518241)
#   81    (semantic normalization, 0.0019354838709677422)          (apriori algorithm, 0.007654637223518241)
#   82            (semantic graph, 0.0019354838709677422)                    (biasing, 0.007325658717426363)
#   83      (reference resolution, 0.0019354838709677422)                 (heuristic, 0.0065261739036369445)
#   84         (extract sentences, 0.0019354838709677422)         (stochastic process, 0.004534922381968996)
#   85         (original document, 0.0019354838709677422)     (reinforcement learning, 0.004534922381968996)
#   86   (deep syntactic analysis, 0.0019354838709677422)             (link analysis, 0.0036027823722663823)

# %% [markdown]
# ## Year 2005

# %%
#View tables for year 2005
tables_metrics_view(2005)
# Out:
# Year: 2005
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1            (visual quality, 0.0038363171355498722)           (ontology building, 0.11594202898550725)
#    2  (global exponential stability, 0.0021312872975...                (semantic web, 0.11594202898550725)
#    3          (bayesian methods, 0.0017050298380221654)        (usable methodologies, 0.11594202898550725)
#    4       (monte carlo methods, 0.0010656436487638534)               (aware version, 0.11594202898550725)
#    5  (artificial neural network, 0.0010656436487638...              (world wide web, 0.11594202898550725)
#    6          (lyapunov fractal, 0.0010656436487638534)      (making available large, 0.11594202898550725)
#    7      (sliding mode control, 0.0010656436487638534)            (methods proposed, 0.11594202898550725)
#    8  (particle swarm optimization, 0.00092355782892...    (knowledge representation, 0.11594202898550725)
#    9                (simulation, 0.0009235578289286729)       (widely used standards, 0.11594202898550725)
#   10  (linear matrix inequality, 0.00042625745950554...  (particle swarm optimization, 0.10144927536231...
#   11            (swarm robotics, 0.0002841716396703609)                  (simulation, 0.10144927536231885)
#   12    (benchmark (computing), 0.00021312872975277067)       (benchmark (computing), 0.08695652173913043)
#   13  (mathematical optimization, 0.0002131287297527...              (visual quality, 0.08695652173913043)
#   14                    (evolutionary computation, 0.0)        (experimental results, 0.08695652173913043)
#   15                           (genetic algorithm, 0.0)             (algorithm finds, 0.08695652173913043)
#   16                            (random variables, 0.0)       (user specified number, 0.08695652173913043)
#   17                        (inference algorithms, 0.0)               (synthetic mri, 0.08695652173913043)
#   18                         (bam neural networks, 0.0)            (satellite images, 0.08695652173913043)
#   19                          (human eyes sensing, 0.0)          (wide applicability, 0.08695652173913043)
#   20                                 (similar way, 0.0)   (mathematical optimization, 0.08695652173913043)
#   21                        (adaptive enhancement, 0.0)              (cluster groups, 0.08695652173913043)
#   22                   (tone frequency components, 0.0)    (evolutionary computation, 0.07246376811594203)
#   23                    (recurrent neural network, 0.0)           (genetic algorithm, 0.07246376811594203)
#   24                    (cellular neural networks, 0.0)   (artificial neural network, 0.07246376811594203)
#   25                         (activation function, 0.0)            (lyapunov fractal, 0.07246376811594203)
#   26                             (radio resources, 0.0)              (swarm robotics, 0.07246376811594203)
#   27                          (periodic solutions, 0.0)        (monte carlo methods, 0.057971014492753624)
#   28                         (convex optimization, 0.0)         (human eyes sensing, 0.057971014492753624)
#   29                        (experimental results, 0.0)                (similar way, 0.057971014492753624)
#   30                             (algorithm finds, 0.0)       (adaptive enhancement, 0.057971014492753624)
#   31                       (user specified number, 0.0)  (tone frequency components, 0.057971014492753624)
#   32                               (synthetic mri, 0.0)  (global exponential stability, 0.0579710144927...
#   33                            (satellite images, 0.0)       (sliding mode control, 0.057971014492753624)
#   34                          (wide applicability, 0.0)           (bayesian methods, 0.043478260869565216)
#   35                           (ontology building, 0.0)   (recurrent neural network, 0.043478260869565216)
#   36                                (semantic web, 0.0)                       (mimo, 0.043478260869565216)
#   37                        (usable methodologies, 0.0)      (transmitting antennas, 0.043478260869565216)
#   38                               (aware version, 0.0)         (receiving antennas, 0.043478260869565216)
#   39                              (world wide web, 0.0)          (social inequality, 0.043478260869565216)
#   40                      (making available large, 0.0)                  (algorithm, 0.043478260869565216)
#   41                            (methods proposed, 0.0)     (gaussian approximation, 0.043478260869565216)
#   42                    (knowledge representation, 0.0)       (inference algorithms, 0.028985507246376812)
#   43                               (volume brings, 0.0)        (activation function, 0.028985507246376812)
#   44                                        (mimo, 0.0)         (periodic solutions, 0.028985507246376812)
#   45                       (transmitting antennas, 0.0)                 (statistics, 0.028985507246376812)
#   46                          (receiving antennas, 0.0)                (mathematics, 0.028985507246376812)
#   47                                  (statistics, 0.0)           (state estimation, 0.028985507246376812)
#   48                                 (mathematics, 0.0)  (neural network simulation, 0.028985507246376812)
#   49                            (state estimation, 0.0)            (neural networks, 0.028985507246376812)
#   50                                 (scalability, 0.0)   (probability distribution, 0.028985507246376812)
#   51                                 (face images, 0.0)   (linear matrix inequality, 0.028985507246376812)
#   52                 (global asymptotic stability, 0.0)           (random variables, 0.014492753623188406)
#   53                           (equilibrium point, 0.0)        (bam neural networks, 0.014492753623188406)
#   54                       (exponential stability, 0.0)   (cellular neural networks, 0.014492753623188406)
#   55                     (digital images captured, 0.0)            (radio resources, 0.014492753623188406)
#   56                           (social inequality, 0.0)        (convex optimization, 0.014492753623188406)
#   57                   (neural network simulation, 0.0)              (volume brings, 0.014492753623188406)
#   58              (nonuniform lighting conditions, 0.0)                (scalability, 0.014492753623188406)
#   59                      (coordinated management, 0.0)                (face images, 0.014492753623188406)
#   60                             (neural networks, 0.0)  (global asymptotic stability, 0.01449275362318...
#   61                             (lyapunov method, 0.0)          (equilibrium point, 0.014492753623188406)
#   62                                   (algorithm, 0.0)      (exponential stability, 0.014492753623188406)
#   63                              (cluster groups, 0.0)    (digital images captured, 0.014492753623188406)
#   64                               (discrete-time, 0.0)  (nonuniform lighting conditions, 0.01449275362...
#   65                       (widely used standards, 0.0)     (coordinated management, 0.014492753623188406)
#   66                              (related topics, 0.0)            (lyapunov method, 0.014492753623188406)
#   67                      (gaussian approximation, 0.0)              (discrete-time, 0.014492753623188406)
#   68                    (probability distribution, 0.0)             (related topics, 0.014492753623188406)
#   69                              (problem domain, 0.0)             (problem domain, 0.014492753623188406)
#   70                            (face recognition, 0.0)           (face recognition, 0.014492753623188406)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (global exponential stability, 0.0297486742104...  (global exponential stability, 0.0288925838158...
#    2             (visual quality, 0.027307538320685477)             (visual quality, 0.025317989095744762)
#    3   (linear matrix inequality, 0.022502607929343003)        (monte carlo methods, 0.022808478518540058)
#    4  (artificial neural network, 0.022425208822695688)       (sliding mode control, 0.022808478518540055)
#    5           (lyapunov fractal, 0.022425208822695688)  (particle swarm optimization, 0.02211261747215...
#    6        (monte carlo methods, 0.021939029281879317)  (artificial neural network, 0.021983565297825164)
#    7       (sliding mode control, 0.021939029281879314)           (lyapunov fractal, 0.021983565297825164)
#    8           (bayesian methods, 0.017914243156452975)   (linear matrix inequality, 0.020835772870770916)
#    9         (human eyes sensing, 0.017047768281909667)       (benchmark (computing), 0.01949866874698526)
#   10                (similar way, 0.017047768281909667)   (mathematical optimization, 0.01949866874698526)
#   11       (adaptive enhancement, 0.017047768281909667)           (bayesian methods, 0.018579631183852054)
#   12  (tone frequency components, 0.017047768281909664)         (human eyes sensing, 0.015805716593330556)
#   13              (swarm robotics, 0.01698582163784304)                (similar way, 0.015805716593330556)
#   14      (benchmark (computing), 0.015719334936775797)       (adaptive enhancement, 0.015805716593330556)
#   15  (mathematical optimization, 0.015719334936775797)  (tone frequency components, 0.015805716593330556)
#   16          (ontology building, 0.015408320493066258)             (swarm robotics, 0.014735229629469592)
#   17               (semantic web, 0.015408320493066258)   (recurrent neural network, 0.014578269193537986)
#   18       (usable methodologies, 0.015408320493066258)          (social inequality, 0.014578269193537984)
#   19              (aware version, 0.015408320493066258)          (ontology building, 0.014285714285714292)
#   20             (world wide web, 0.015408320493066258)               (semantic web, 0.014285714285714292)
#   21     (making available large, 0.015408320493066258)       (usable methodologies, 0.014285714285714292)
#   22           (methods proposed, 0.015408320493066258)              (aware version, 0.014285714285714292)
#   23   (knowledge representation, 0.015408320493066258)             (world wide web, 0.014285714285714292)
#   24      (widely used standards, 0.015408320493066258)     (making available large, 0.014285714285714292)
#   25        (bam neural networks, 0.015408320493066254)            (methods proposed, 0.01428571428571429)
#   26            (radio resources, 0.015408320493066254)    (knowledge representation, 0.01428571428571429)
#   27              (volume brings, 0.015408320493066254)       (widely used standards, 0.01428571428571429)
#   28                (mathematics, 0.015408320493066254)        (bam neural networks, 0.014285714285714285)
#   29           (state estimation, 0.015408320493066254)            (radio resources, 0.014285714285714285)
#   30                (scalability, 0.015408320493066254)        (convex optimization, 0.014285714285714285)
#   31                (face images, 0.015408320493066254)              (volume brings, 0.014285714285714285)
#   32      (exponential stability, 0.015408320493066254)                (mathematics, 0.014285714285714285)
#   33     (coordinated management, 0.015408320493066254)           (state estimation, 0.014285714285714285)
#   34             (related topics, 0.015408320493066254)                (scalability, 0.014285714285714285)
#   35   (probability distribution, 0.015408320493066254)                (face images, 0.014285714285714285)
#   36             (problem domain, 0.015408320493066254)      (exponential stability, 0.014285714285714285)
#   37           (face recognition, 0.015408320493066254)     (coordinated management, 0.014285714285714285)
#   38                        (mimo, 0.01540832049306625)            (lyapunov method, 0.014285714285714285)
#   39       (transmitting antennas, 0.01540832049306625)             (related topics, 0.014285714285714285)
#   40          (receiving antennas, 0.01540832049306625)   (probability distribution, 0.014285714285714285)
#   41      (gaussian approximation, 0.01540832049306625)             (problem domain, 0.014285714285714285)
#   42       (experimental results, 0.015408320493066245)           (face recognition, 0.014285714285714285)
#   43            (algorithm finds, 0.015408320493066245)       (experimental results, 0.014285714285714282)
#   44      (user specified number, 0.015408320493066245)            (algorithm finds, 0.014285714285714282)
#   45              (synthetic mri, 0.015408320493066245)      (user specified number, 0.014285714285714282)
#   46           (satellite images, 0.015408320493066245)              (synthetic mri, 0.014285714285714282)
#   47         (wide applicability, 0.015408320493066245)           (satellite images, 0.014285714285714282)
#   48             (cluster groups, 0.015408320493066245)         (wide applicability, 0.014285714285714282)
#   49         (periodic solutions, 0.015013629693045772)                       (mimo, 0.014285714285714282)
#   50            (neural networks, 0.015013629693045772)      (transmitting antennas, 0.014285714285714282)
#   51   (recurrent neural network, 0.013863933587152441)         (receiving antennas, 0.014285714285714282)
#   52          (social inequality, 0.013863933587152441)             (cluster groups, 0.014285714285714282)
#   53  (particle swarm optimization, 0.01320879046087...     (gaussian approximation, 0.014285714285714282)
#   54  (global asymptotic stability, 0.01186117677492...                 (simulation, 0.013782071728604506)
#   55          (equilibrium point, 0.011861176774927878)            (neural networks, 0.013616769781051209)
#   56       (inference algorithms, 0.011635335430203996)         (periodic solutions, 0.011237785259640698)
#   57                 (statistics, 0.011635335430203996)   (cellular neural networks, 0.011073336000416325)
#   58        (activation function, 0.009935819069350638)  (global asymptotic stability, 0.01101068499318...
#   59  (neural network simulation, 0.009935819069350638)           (equilibrium point, 0.01101068499318597)
#   60    (cellular neural networks, 0.00863283443438204)   (evolutionary computation, 0.009158521673140407)
#   61               (discrete-time, 0.00863283443438204)          (genetic algorithm, 0.009158521673140407)
#   62           (random variables, 0.007386950377777925)       (inference algorithms, 0.008108151524612207)
#   63    (digital images captured, 0.006179816001569825)                 (statistics, 0.008108151524612207)
#   64  (nonuniform lighting conditions, 0.00617981600...             (discrete-time, 0.0066080965716367335)
#   65  (evolutionary computation, 0.0023112480739599386)                 (algorithm, 0.0063414146152331145)
#   66                (simulation, 0.0023112480739599386)        (activation function, 0.006295308365779689)
#   67         (genetic algorithm, 0.0023112480739599386)  (neural network simulation, 0.006295308365779689)
#   68       (convex optimization, 0.0023112480739599386)    (digital images captured, 0.005729572265466483)
#   69           (lyapunov method, 0.0023112480739599386)  (nonuniform lighting conditions, 0.00572957226...
#   70                 (algorithm, 0.0023112480739599386)           (random variables, 0.005301394444129151)

# %% [markdown]
# ## Year 2006

# %%
#View tables for year 2006
tables_metrics_view(2006)
# Out:
# Year: 2006
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1    (linear matrix inequality, 0.11374764595103579)    (linear matrix inequality, 0.21666666666666667)
#    2          (numerical analysis, 0.11271186440677966)                (global asymptotic stability, 0.15)
#    3    (artificial neural network, 0.0903954802259887)  (global exponential stability, 0.1333333333333...
#    4                   (algorithm, 0.07570621468926554)                  (permanence, 0.13333333333333333)
#    5  (global exponential stability, 0.0467043314500...          (numerical analysis, 0.13333333333333333)
#    6        (time-varying delays, 0.039830508474576275)  (lyapunov–krasovskii functional, 0.11666666666...
#    7  (global asymptotic stability, 0.01403013182674...                          (stochastic systems, 0.1)
#    8                  (permanence, 0.00847457627118644)                                   (algorithm, 0.1)
#    9        (distributed delays, 0.0064030131826741995)           (lyapunov function, 0.08333333333333333)
#   10  (lyapunov–krasovskii functional, 0.00338983050...  (globally asymptotic stability, 0.083333333333...
#   11         (periodic solution, 0.0025423728813559325)            (feedback control, 0.08333333333333333)
#   12         (stochastic systems, 0.001318267419962335)               (lower average, 0.08333333333333333)
#   13                 (particle swarm optimization, 0.0)                     (hessian, 0.08333333333333333)
#   14                              (paper presents, 0.0)       (variational principle, 0.08333333333333333)
#   15                   (computationally efficient, 0.0)                    (gradient, 0.08333333333333333)
#   16                          (ontology libraries, 0.0)                 (computation, 0.08333333333333333)
#   17              (cohen–grossberg neural network, 0.0)      (arachnoid spinal space, 0.08333333333333333)
#   18                              (core ontology , 0.0)      (biomedical application, 0.08333333333333333)
#   19                           (lyapunov function, 0.0)                  (tiny space, 0.08333333333333333)
#   20               (globally asymptotic stability, 0.0)        (strongly challenging, 0.08333333333333333)
#   21                            (feedback control, 0.0)  (delicate anatomical structures, 0.08333333333...
#   22                                       (34d40, 0.0)    (hopfield neural networks, 0.08333333333333333)
#   23                               (primary 34c05, 0.0)               (upper average, 0.08333333333333333)
#   24                               (lower average, 0.0)                  (experiment, 0.08333333333333333)
#   25                                 (time delays, 0.0)                (paper refers, 0.08333333333333333)
#   26             (discrete and distributed delays, 0.0)           (uncertain systems, 0.08333333333333333)
#   27               (compliant information systems, 0.0)  (discrete and distributed delays, 0.0666666666...
#   28                          (information models, 0.0)          (distributed delays, 0.06666666666666667)
#   29                            (standard defines, 0.0)         (time-varying delays, 0.06666666666666667)
#   30                                     (hessian, 0.0)                  (artificial neural network, 0.05)
#   31                       (variational principle, 0.0)                          (periodic solution, 0.05)
#   32                                    (gradient, 0.0)                                      (34d40, 0.05)
#   33                                 (computation, 0.0)                              (primary 34c05, 0.05)
#   34                                  (phy (chip), 0.0)              (compliant information systems, 0.05)
#   35                        (finite-state machine, 0.0)                         (information models, 0.05)
#   36                              (feature vector, 0.0)                           (standard defines, 0.05)
#   37                      (arachnoid spinal space, 0.0)                                      (34c25, 0.05)
#   38                      (biomedical application, 0.0)              (currently different standards, 0.05)
#   39                                  (tiny space, 0.0)  (particle swarm optimization, 0.03333333333333...
#   40                        (strongly challenging, 0.0)   (computationally efficient, 0.03333333333333333)
#   41              (delicate anatomical structures, 0.0)                 (time delays, 0.03333333333333333)
#   42                             (discrete delays, 0.0)        (finite-state machine, 0.03333333333333333)
#   43                    (hopfield neural networks, 0.0)              (feature vector, 0.03333333333333333)
#   44                                     (quantum, 0.0)             (discrete delays, 0.03333333333333333)
#   45                                  (frw method, 0.0)                     (quantum, 0.03333333333333333)
#   46                       (sufficient conditions, 0.0)       (sufficient conditions, 0.03333333333333333)
#   47                              (search engines, 0.0)            (lyapunov fractal, 0.03333333333333333)
#   48                            (lyapunov fractal, 0.0)             (neural networks, 0.03333333333333333)
#   49                             (neural networks, 0.0)      (mathematical induction, 0.03333333333333333)
#   50                          (ontology learning , 0.0)             (paper presents, 0.016666666666666666)
#   51                               (upper average, 0.0)         (ontology libraries, 0.016666666666666666)
#   52                                       (34c25, 0.0)  (cohen–grossberg neural network, 0.01666666666...
#   53                            (machine learning, 0.0)             (core ontology , 0.016666666666666666)
#   54               (currently different standards, 0.0)                 (phy (chip), 0.016666666666666666)
#   55                                  (experiment, 0.0)                 (frw method, 0.016666666666666666)
#   56                             (cognitive radio, 0.0)             (search engines, 0.016666666666666666)
#   57                      (mathematical induction, 0.0)         (ontology learning , 0.016666666666666666)
#   58                                (paper refers, 0.0)           (machine learning, 0.016666666666666666)
#   59                        (optimization problem, 0.0)            (cognitive radio, 0.016666666666666666)
#   60                (linear discriminant analysis, 0.0)       (optimization problem, 0.016666666666666666)
#   61                           (uncertain systems, 0.0)  (linear discriminant analysis, 0.0166666666666...
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1    (linear matrix inequality, 0.05116976276712638)    (linear matrix inequality, 0.04723868725492603)
#    2                  (algorithm, 0.046382564363985065)                    (algorithm, 0.0373085186826743)
#    3  (global asymptotic stability, 0.03447028746162...  (global asymptotic stability, 0.03500011069792...
#    4  (global exponential stability, 0.0341566561149...  (lyapunov–krasovskii functional, 0.02829778512...
#    5          (numerical analysis, 0.03251196108533648)                 (permanence, 0.027120771530626787)
#    6  (lyapunov–krasovskii functional, 0.02659230807...         (numerical analysis, 0.026660031356272405)
#    7         (stochastic systems, 0.023469851020043647)  (global exponential stability, 0.0251569784688...
#    8        (time-varying delays, 0.022860637601340175)         (stochastic systems, 0.021087467368231385)
#    9                     (hessian, 0.02001927691085533)                    (hessian, 0.017799243308859746)
#   10       (variational principle, 0.02001927691085533)      (variational principle, 0.017799243308859746)
#   11                    (gradient, 0.02001927691085533)                   (gradient, 0.017799243308859746)
#   12                 (computation, 0.02001927691085533)                (computation, 0.017799243308859746)
#   13                  (experiment, 0.02001927691085533)                 (experiment, 0.017799243308859746)
#   14      (arachnoid spinal space, 0.01968503937007875)          (lyapunov function, 0.016689363842060115)
#   15      (biomedical application, 0.01968503937007875)  (globally asymptotic stability, 0.016689363842...
#   16                  (tiny space, 0.01968503937007875)           (feedback control, 0.016689363842060115)
#   17        (strongly challenging, 0.01968503937007875)              (lower average, 0.016689363842060115)
#   18  (delicate anatomical structures, 0.01968503937...              (upper average, 0.016689363842060115)
#   19                (paper refers, 0.01968503937007875)              (paper presents, 0.01639344262295082)
#   20              (paper presents, 0.01968503937007874)          (ontology libraries, 0.01639344262295082)
#   21          (ontology libraries, 0.01968503937007874)              (core ontology , 0.01639344262295082)
#   22              (core ontology , 0.01968503937007874)  (compliant information systems, 0.016393442622...
#   23                  (phy (chip), 0.01968503937007874)          (information models, 0.01639344262295082)
#   24                  (frw method, 0.01968503937007874)            (standard defines, 0.01639344262295082)
#   25              (search engines, 0.01968503937007874)                  (phy (chip), 0.01639344262295082)
#   26          (ontology learning , 0.01968503937007874)        (finite-state machine, 0.01639344262295082)
#   27  (currently different standards, 0.019685039370...              (feature vector, 0.01639344262295082)
#   28             (cognitive radio, 0.01968503937007874)      (arachnoid spinal space, 0.01639344262295082)
#   29  (compliant information systems, 0.019685039370...      (biomedical application, 0.01639344262295082)
#   30         (information models, 0.019685039370078736)                  (tiny space, 0.01639344262295082)
#   31           (standard defines, 0.019685039370078736)        (strongly challenging, 0.01639344262295082)
#   32    (hopfield neural networks, 0.01940611715309335)  (delicate anatomical structures, 0.01639344262...
#   33           (uncertain systems, 0.01940611715309335)                  (frw method, 0.01639344262295082)
#   34  (artificial neural network, 0.017839901468282893)              (search engines, 0.01639344262295082)
#   35         (distributed delays, 0.017391455413541125)          (ontology learning , 0.01639344262295082)
#   36  (particle swarm optimization, 0.01656936415975...  (currently different standards, 0.016393442622...
#   37                    (quantum, 0.016569364159752138)             (cognitive radio, 0.01639344262295082)
#   38  (discrete and distributed delays, 0.0164114994...      (mathematical induction, 0.01639344262295082)
#   39           (periodic solution, 0.01618696443285531)                (paper refers, 0.01639344262295082)
#   40            (neural networks, 0.011167630820706546)   (hopfield neural networks, 0.016218250163248765)
#   41  (computationally efficient, 0.010953209337986443)          (uncertain systems, 0.016218250163248765)
#   42      (sufficient conditions, 0.010953209337986443)        (time-varying delays, 0.014660664817384247)
#   43            (discrete delays, 0.009903690834452337)         (distributed delays, 0.014155163562160976)
#   44           (lyapunov fractal, 0.009752740203806183)  (discrete and distributed delays, 0.0141250160...
#   45                (time delays, 0.009622990815309788)   (artificial neural network, 0.01334483019056413)
#   46           (machine learning, 0.009526674150382886)                      (34d40, 0.012324464288543339)
#   47       (optimization problem, 0.009526674150382886)              (primary 34c05, 0.012324464288543339)
#   48  (linear discriminant analysis, 0.0095266741503...                      (34c25, 0.012324464288543339)
#   49  (cohen–grossberg neural network, 0.00781153023...  (particle swarm optimization, 0.01215980201438...
#   50          (lyapunov function, 0.002952755905511812)                    (quantum, 0.012159802014389938)
#   51  (globally asymptotic stability, 0.002952755905...           (machine learning, 0.011524084666583816)
#   52           (feedback control, 0.002952755905511812)          (periodic solution, 0.010297549894983481)
#   53                      (34d40, 0.002952755905511812)            (discrete delays, 0.008371846329428275)
#   54              (primary 34c05, 0.002952755905511812)                (time delays, 0.008084406526750283)
#   55                 (permanence, 0.002952755905511812)            (neural networks, 0.007087061090243513)
#   56              (lower average, 0.002952755905511812)        (optimization problem, 0.00699155053001322)
#   57       (finite-state machine, 0.002952755905511812)  (linear discriminant analysis, 0.0069915505300...
#   58             (feature vector, 0.002952755905511812)           (lyapunov fractal, 0.006945676150912319)
#   59              (upper average, 0.002952755905511812)  (computationally efficient, 0.006770288231157738)
#   60                      (34c25, 0.002952755905511812)      (sufficient conditions, 0.006770288231157738)
#   61     (mathematical induction, 0.002952755905511812)  (cohen–grossberg neural network, 0.00557484462...

# %% [markdown]
# ## Year 2007

# %%
#View tables for year 2007
tables_metrics_view(2007)
# Out:
# Year: 2007
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1        (lyapunov functional, 0.056429232192414434)    (neural network simulation, 0.2127659574468085)
#    2   (neural network simulation, 0.04378661732963306)    (artificial neural network, 0.1702127659574468)
#    3  (artificial neural network, 0.016959605303731112)          (lyapunov functional, 0.1702127659574468)
#    4   (linear matrix inequality, 0.016034535923527597)     (linear matrix inequality, 0.1276595744680851)
#    5                       (chaos, 0.01387604070305273)            (social inequality, 0.0851063829787234)
#    6  (mathematical optimization, 0.002775208140610546)    (mathematical optimization, 0.0851063829787234)
#    7                 (particle swarm optimization, 0.0)         (estimating integrals, 0.0851063829787234)
#    8             (velocity (software development), 0.0)                  (widely used, 0.0851063829787234)
#    9                             (synchronization, 0.0)     (multidimensional domains, 0.0851063829787234)
#   10                            (lyapunov fractal, 0.0)  (scientific computation especially, 0.08510638...
#   11                         (time-varying delays, 0.0)                  (monte carlo, 0.0851063829787234)
#   12                           (social inequality, 0.0)  (particle swarm optimization, 0.06382978723404...
#   13                               (paper focuses, 0.0)  (velocity (software development), 0.0638297872...
#   14                         (fuzzy logic control, 0.0)                       (chaos, 0.06382978723404255)
#   15                                 (fuzzy multi, 0.0)         (time-varying delays, 0.06382978723404255)
#   16             (cohen–grossberg neural networks, 0.0)               (paper focuses, 0.06382978723404255)
#   17                           (genetic algorithm, 0.0)         (fuzzy logic control, 0.06382978723404255)
#   18                         (lag synchronization, 0.0)                 (fuzzy multi, 0.06382978723404255)
#   19                (multiplier-less architecture, 0.0)  (bidirectional associative memory, 0.063829787...
#   20                               (illegal trade, 0.0)  (content-addressable memory, 0.06382978723404255)
#   21                                (entry points, 0.0)         (mobility management, 0.06382978723404255)
#   22                          (numerical analysis, 0.0)      (evolutionary algorithm, 0.06382978723404255)
#   23                                 (human colon, 0.0)              (synchronization, 0.0425531914893617)
#   24                (lasalle invariance principle, 0.0)  (cohen–grossberg neural networks, 0.0425531914...
#   25                        (experimental results, 0.0)           (distributed delays, 0.0425531914893617)
#   26              (lyapunov–krasovskii functional, 0.0)  (bidirectional associative memory neural netwo...
#   27            (bidirectional associative memory, 0.0)               (varying delays, 0.0425531914893617)
#   28                          (distributed delays, 0.0)                    (e systems, 0.0425531914893617)
#   29  (bidirectional associative memory neural netwo...                (varying delay, 0.0425531914893617)
#   30                  (content-addressable memory, 0.0)            (lyapunov fractal, 0.02127659574468085)
#   31                              (varying delays, 0.0)           (genetic algorithm, 0.02127659574468085)
#   32                                   (e systems, 0.0)         (lag synchronization, 0.02127659574468085)
#   33                         (rate of convergence, 0.0)  (multiplier-less architecture, 0.0212765957446...
#   34                        (estimating integrals, 0.0)               (illegal trade, 0.02127659574468085)
#   35                                 (widely used, 0.0)                (entry points, 0.02127659574468085)
#   36                    (multidimensional domains, 0.0)          (numerical analysis, 0.02127659574468085)
#   37           (scientific computation especially, 0.0)                 (human colon, 0.02127659574468085)
#   38                         (mobility management, 0.0)  (lasalle invariance principle, 0.0212765957446...
#   39                                  (fuzzy rule, 0.0)        (experimental results, 0.02127659574468085)
#   40              (logarithmic domain computation, 0.0)  (lyapunov–krasovskii functional, 0.02127659574...
#   41                    (substantially contribute, 0.0)         (rate of convergence, 0.02127659574468085)
#   42                                   (web forms, 0.0)                  (fuzzy rule, 0.02127659574468085)
#   43                      (evolutionary algorithm, 0.0)  (logarithmic domain computation, 0.02127659574...
#   44                        (endoscopic technique, 0.0)    (substantially contribute, 0.02127659574468085)
#   45            (mean square asymptotic stability, 0.0)                   (web forms, 0.02127659574468085)
#   46                       (information retrieval, 0.0)        (endoscopic technique, 0.02127659574468085)
#   47                               (varying delay, 0.0)  (mean square asymptotic stability, 0.021276595...
#   48                                 (monte carlo, 0.0)       (information retrieval, 0.02127659574468085)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (neural network simulation, 0.060633121960916046)   (neural network simulation, 0.05795670125698635)
#    2        (lyapunov functional, 0.050701643550755675)   (artificial neural network, 0.04820815726292145)
#    3   (artificial neural network, 0.04617766598802629)         (lyapunov functional, 0.03987333008556535)
#    4   (linear matrix inequality, 0.036796269978574644)    (linear matrix inequality, 0.03889525665999487)
#    5   (mathematical optimization, 0.03310643570453202)          (social inequality, 0.031134793946771763)
#    6                      (chaos, 0.024476979184018737)  (mathematical optimization, 0.029589349813368238)
#    7     (evolutionary algorithm, 0.024303955063691506)                       (chaos, 0.02359289655659596)
#    8  (particle swarm optimization, 0.02430395506369...  (particle swarm optimization, 0.02172156706095...
#    9  (velocity (software development), 0.0243039550...  (velocity (software development), 0.0217215670...
#   10          (social inequality, 0.024156579573923385)     (evolutionary algorithm, 0.021721567060957844)
#   11          (genetic algorithm, 0.023310023310023305)        (estimating integrals, 0.02083333333333334)
#   12              (illegal trade, 0.023310023310023305)                 (widely used, 0.02083333333333334)
#   13               (entry points, 0.023310023310023305)    (multidimensional domains, 0.02083333333333334)
#   14                (human colon, 0.023310023310023305)  (scientific computation especially, 0.02083333...
#   15  (lasalle invariance principle, 0.0233100233100...                (monte carlo, 0.020833333333333336)
#   16       (experimental results, 0.023310023310023305)              (paper focuses, 0.020833333333333332)
#   17             (varying delays, 0.023310023310023305)        (fuzzy logic control, 0.020833333333333332)
#   18                  (e systems, 0.023310023310023305)                (fuzzy multi, 0.020833333333333332)
#   19       (estimating integrals, 0.023310023310023305)          (genetic algorithm, 0.020833333333333332)
#   20                (widely used, 0.023310023310023305)  (multiplier-less architecture, 0.0208333333333...
#   21   (multidimensional domains, 0.023310023310023305)              (illegal trade, 0.020833333333333332)
#   22  (scientific computation especially, 0.02331002...               (entry points, 0.020833333333333332)
#   23                 (fuzzy rule, 0.023310023310023305)                (human colon, 0.020833333333333332)
#   24   (substantially contribute, 0.023310023310023305)  (lasalle invariance principle, 0.0208333333333...
#   25                  (web forms, 0.023310023310023305)       (experimental results, 0.020833333333333332)
#   26       (endoscopic technique, 0.023310023310023305)             (varying delays, 0.020833333333333332)
#   27  (mean square asymptotic stability, 0.023310023...                  (e systems, 0.020833333333333332)
#   28      (information retrieval, 0.023310023310023305)        (mobility management, 0.020833333333333332)
#   29              (varying delay, 0.023310023310023305)                 (fuzzy rule, 0.020833333333333332)
#   30                (monte carlo, 0.023310023310023305)  (logarithmic domain computation, 0.02083333333...
#   31  (bidirectional associative memory, 0.018915236...   (substantially contribute, 0.020833333333333332)
#   32  (content-addressable memory, 0.018915236423610...                  (web forms, 0.020833333333333332)
#   33         (time-varying delays, 0.01876939783559467)       (endoscopic technique, 0.020833333333333332)
#   34            (synchronization, 0.015822770416232392)  (mean square asymptotic stability, 0.020833333...
#   35         (distributed delays, 0.015451563802940192)      (information retrieval, 0.020833333333333332)
#   36  (bidirectional associative memory neural netwo...              (varying delay, 0.020833333333333332)
#   37  (cohen–grossberg neural networks, 0.0135567637...              (synchronization, 0.0179274279739198)
#   38         (numerical analysis, 0.010531815654509998)  (content-addressable memory, 0.012468584772554...
#   39        (lag synchronization, 0.010435588677903677)  (bidirectional associative memory, 0.012468584...
#   40  (lyapunov–krasovskii functional, 0.00870913758...        (time-varying delays, 0.011810794914737311)
#   41           (lyapunov fractal, 0.008650438659625802)         (distributed delays, 0.011331216713317292)
#   42        (rate of convergence, 0.008650438659625802)  (bidirectional associative memory neural netwo...
#   43             (paper focuses, 0.0034965034965035013)         (numerical analysis, 0.009412615670424864)
#   44       (fuzzy logic control, 0.0034965034965035013)  (cohen–grossberg neural networks, 0.0089361445...
#   45               (fuzzy multi, 0.0034965034965035013)  (lyapunov–krasovskii functional, 0.00887430064...
#   46  (multiplier-less architecture, 0.0034965034965...        (lag synchronization, 0.007136479623230254)
#   47       (mobility management, 0.0034965034965035013)           (lyapunov fractal, 0.006110390088561414)
#   48  (logarithmic domain computation, 0.00349650349...        (rate of convergence, 0.006110390088561414)

# %% [markdown]
# ## Year 2008

# %%
#View tables for year 2008
tables_metrics_view(2008)
# Out:
# Year: 2008
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1   (linear matrix inequality, 0.016428328226081035)       (query server accesses, 0.14606741573033707)
#    2  (mathematical optimization, 0.007150153217568948)          (specified products, 0.14606741573033707)
#    3  (interference (communication), 0.0045965270684...             (crawler program, 0.14606741573033707)
#    4  (artificial neural network, 0.003830439223697651)            (scored web pages, 0.14606741573033707)
#    5        (rate of convergence, 0.003830439223697651)          (criteria according, 0.14606741573033707)
#    6                  (algorithm, 0.002553626149131767)                (locate pages, 0.14606741573033707)
#    7            (cognitive radio, 0.002553626149131767)        (responsive web pages, 0.14606741573033707)
#    8          (lyapunov fractal, 0.0020003404834865513)              (s search query, 0.14606741573033707)
#    9         (social inequality, 0.0020003404834865513)            (product offering, 0.14606741573033707)
#   10           (neural networks, 0.0005107252298263534)                (scored based, 0.14606741573033707)
#   11                          (numerical analysis, 0.0)               (search engine, 0.14606741573033707)
#   12                              (paper presents, 0.0)           (web pages located, 0.14606741573033707)
#   13                              (advanced cross, 0.0)          (locating web pages, 0.14606741573033707)
#   14                  (lingual information access, 0.0)               (assists users, 0.14606741573033707)
#   15                 (global asymptotic stability, 0.0)     (linear matrix inequality, 0.1348314606741573)
#   16                                  (simulation, 0.0)                   (algorithm, 0.10112359550561797)
#   17                                    (89.75.kd, 0.0)  (interference (communication), 0.1011235955056...
#   18                              (multistability, 0.0)             (lyapunov fractal, 0.0898876404494382)
#   19                                  (throughput, 0.0)            (social inequality, 0.0898876404494382)
#   20                (unbounded distributed delays, 0.0)                   (throughput, 0.0898876404494382)
#   21              (lyapunov–krasovskii functional, 0.0)   (ici (programming language), 0.0898876404494382)
#   22                                 (exponential, 0.0)         (systems architecture, 0.0898876404494382)
#   23                  (ici (programming language), 0.0)               (user interface, 0.0898876404494382)
#   24                        (systems architecture, 0.0)                   (multi-user, 0.0898876404494382)
#   25                              (user interface, 0.0)                        (relay, 0.0898876404494382)
#   26                                  (multi-user, 0.0)  (signal-to-interference-plus-noise ratio, 0.08...
#   27                                       (relay, 0.0)   (mathematical optimization, 0.07865168539325842)
#   28                    (access network selection, 0.0)   (artificial neural network, 0.07865168539325842)
#   29                              (varying delays, 0.0)          (numerical analysis, 0.06741573033707865)
#   30                       (krasovskii functional, 0.0)             (lyapunov method, 0.06741573033707865)
#   31                          (matlab lmi toolbox, 0.0)              (neural networks, 0.0449438202247191)
#   32                       (exponential stability, 0.0)            (using eigen faces, 0.0449438202247191)
#   33                                (chaos theory, 0.0)                (face database, 0.0449438202247191)
#   34                          (adaptive technique, 0.0)             (face recognition, 0.0449438202247191)
#   35           (enhancement technique constitutes, 0.0)                  (eigen faces, 0.0449438202247191)
#   36                           (color restoration, 0.0)   (approximation coefficients, 0.0449438202247191)
#   37                         (global optimization, 0.0)                  (new wavelet, 0.0449438202247191)
#   38                                       (pixel, 0.0)          (dimension reduction, 0.0449438202247191)
#   39                                (optical flow, 0.0)    (dynamic range compression, 0.0449438202247191)
#   40                           (using eigen faces, 0.0)               (popular method, 0.0449438202247191)
#   41                               (face database, 0.0)            (wavelet transform, 0.0449438202247191)
#   42                            (face recognition, 0.0)             (paper presents, 0.033707865168539325)
#   43                                 (eigen faces, 0.0)             (advanced cross, 0.033707865168539325)
#   44                  (approximation coefficients, 0.0)  (lingual information access, 0.033707865168539...
#   45                                 (new wavelet, 0.0)  (global asymptotic stability, 0.03370786516853...
#   46                         (dimension reduction, 0.0)  (unbounded distributed delays, 0.0337078651685...
#   47                   (dynamic range compression, 0.0)  (lyapunov–krasovskii functional, 0.03370786516...
#   48                            (domain ontology , 0.0)                (exponential, 0.033707865168539325)
#   49                       (query server accesses, 0.0)         (adaptive technique, 0.033707865168539325)
#   50                          (specified products, 0.0)  (enhancement technique constitutes, 0.03370786...
#   51                             (crawler program, 0.0)          (color restoration, 0.033707865168539325)
#   52                            (scored web pages, 0.0)           (domain ontology , 0.033707865168539325)
#   53                          (criteria according, 0.0)           (concept lattice , 0.033707865168539325)
#   54                                (locate pages, 0.0)         (description logic , 0.033707865168539325)
#   55                        (responsive web pages, 0.0)              (image scaling, 0.033707865168539325)
#   56                              (s search query, 0.0)        (selection algorithm, 0.033707865168539325)
#   57                            (product offering, 0.0)         (instance selection, 0.033707865168539325)
#   58                                (scored based, 0.0)               (task cluster, 0.033707865168539325)
#   59                               (search engine, 0.0)    (image enhancement based, 0.033707865168539325)
#   60                           (web pages located, 0.0)            (formal context , 0.033707865168539325)
#   61                          (locating web pages, 0.0)         (subgroup discovery, 0.033707865168539325)
#   62                            (concept lattice , 0.0)                    (89.75.kd, 0.02247191011235955)
#   63                          (description logic , 0.0)              (multistability, 0.02247191011235955)
#   64                      (heterogeneous networks, 0.0)             (cognitive radio, 0.02247191011235955)
#   65                               (image scaling, 0.0)       (krasovskii functional, 0.02247191011235955)
#   66                         (selection algorithm, 0.0)          (matlab lmi toolbox, 0.02247191011235955)
#   67                          (instance selection, 0.0)                       (pixel, 0.02247191011235955)
#   68                          (water distribution, 0.0)                (optical flow, 0.02247191011235955)
#   69                  (stochastic neural networks, 0.0)                    (07.05.mh, 0.02247191011235955)
#   70                                (markov chain, 0.0)            (distributed time, 0.02247191011235955)
#   71                                 (computation, 0.0)         (rate of convergence, 0.02247191011235955)
#   72                                (task cluster, 0.0)               (sparse matrix, 0.02247191011235955)
#   73                             (lyapunov method, 0.0)                 (simulation, 0.011235955056179775)
#   74                                    (07.05.mh, 0.0)   (access network selection, 0.011235955056179775)
#   75     (signal-to-interference-plus-noise ratio, 0.0)             (varying delays, 0.011235955056179775)
#   76                    (promising access network, 0.0)      (exponential stability, 0.011235955056179775)
#   77                            (distributed time, 0.0)               (chaos theory, 0.011235955056179775)
#   78                  (biological neural networks, 0.0)        (global optimization, 0.011235955056179775)
#   79                     (continuous optimization, 0.0)     (heterogeneous networks, 0.011235955056179775)
#   80                     (image enhancement based, 0.0)         (water distribution, 0.011235955056179775)
#   81                               (sparse matrix, 0.0)  (stochastic neural networks, 0.011235955056179...
#   82                              (popular method, 0.0)               (markov chain, 0.011235955056179775)
#   83                           (wavelet transform, 0.0)                (computation, 0.011235955056179775)
#   84                               (assists users, 0.0)   (promising access network, 0.011235955056179775)
#   85                             (formal context , 0.0)  (biological neural networks, 0.011235955056179...
#   86                                  (femto cell, 0.0)    (continuous optimization, 0.011235955056179775)
#   87                          (subgroup discovery, 0.0)                 (femto cell, 0.011235955056179775)
#   88                        (injected contaminant, 0.0)       (injected contaminant, 0.011235955056179775)
#   89                         (time-varying delays, 0.0)        (time-varying delays, 0.011235955056179775)
#   90                     (markov decision process, 0.0)    (markov decision process, 0.011235955056179775)
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1    (linear matrix inequality, 0.03415612439109939)     (linear matrix inequality, 0.0307261669823021)
#    2           (lyapunov fractal, 0.020766693797272064)           (social inequality, 0.02151879711532309)
#    3    (mathematical optimization, 0.0203515877750168)             (lyapunov fractal, 0.0172178880766082)
#    4  (artificial neural network, 0.020039484585842864)  (interference (communication), 0.0167334822868...
#    5          (social inequality, 0.018644781004862623)   (mathematical optimization, 0.01641240791522566)
#    6  (interference (communication), 0.0186241881274...   (artificial neural network, 0.01600441782531769)
#    7                  (algorithm, 0.018181359428228634)                  (algorithm, 0.014937019560329627)
#    8         (numerical analysis, 0.016377928299946547)         (numerical analysis, 0.013831740014505219)
#    9            (lyapunov method, 0.016377928299946547)            (lyapunov method, 0.013831740014505219)
#   10                 (multi-user, 0.015125420811739034)                 (throughput, 0.012413150885979787)
#   11                      (relay, 0.015125420811739034)  (ici (programming language), 0.012413150885979...
#   12  (signal-to-interference-plus-noise ratio, 0.01...       (systems architecture, 0.012413150885979787)
#   13                  (throughput, 0.01512542081173903)             (user interface, 0.012413150885979787)
#   14  (ici (programming language), 0.01512542081173903)                 (multi-user, 0.012413150885979787)
#   15        (systems architecture, 0.01512542081173903)                      (relay, 0.012413150885979787)
#   16              (user interface, 0.01512542081173903)  (signal-to-interference-plus-noise ratio, 0.01...
#   17                   (89.75.kd, 0.013386880856722058)      (query server accesses, 0.011111111111111118)
#   18             (multistability, 0.013386880856722058)         (specified products, 0.011111111111111118)
#   19   (access network selection, 0.013386880856722058)            (crawler program, 0.011111111111111118)
#   20      (krasovskii functional, 0.013386880856722058)         (criteria according, 0.011111111111111118)
#   21         (matlab lmi toolbox, 0.013386880856722058)               (locate pages, 0.011111111111111118)
#   22               (chaos theory, 0.013386880856722058)              (search engine, 0.011111111111111118)
#   23                      (pixel, 0.013386880856722058)           (scored web pages, 0.011111111111111117)
#   24               (optical flow, 0.013386880856722058)       (responsive web pages, 0.011111111111111117)
#   25          (using eigen faces, 0.013386880856722058)             (s search query, 0.011111111111111117)
#   26              (face database, 0.013386880856722058)           (product offering, 0.011111111111111117)
#   27           (face recognition, 0.013386880856722058)               (scored based, 0.011111111111111117)
#   28                (eigen faces, 0.013386880856722058)          (web pages located, 0.011111111111111117)
#   29  (approximation coefficients, 0.013386880856722...         (locating web pages, 0.011111111111111117)
#   30                (new wavelet, 0.013386880856722058)              (assists users, 0.011111111111111117)
#   31        (dimension reduction, 0.013386880856722058)             (paper presents, 0.011111111111111112)
#   32  (dynamic range compression, 0.013386880856722058)             (advanced cross, 0.011111111111111112)
#   33     (heterogeneous networks, 0.013386880856722058)  (lingual information access, 0.011111111111111...
#   34         (water distribution, 0.013386880856722058)                   (89.75.kd, 0.011111111111111112)
#   35  (stochastic neural networks, 0.013386880856722...             (multistability, 0.011111111111111112)
#   36               (markov chain, 0.013386880856722058)   (access network selection, 0.011111111111111112)
#   37                   (07.05.mh, 0.013386880856722058)      (krasovskii functional, 0.011111111111111112)
#   38   (promising access network, 0.013386880856722058)         (matlab lmi toolbox, 0.011111111111111112)
#   39           (distributed time, 0.013386880856722058)               (chaos theory, 0.011111111111111112)
#   40    (continuous optimization, 0.013386880856722058)         (adaptive technique, 0.011111111111111112)
#   41              (sparse matrix, 0.013386880856722058)  (enhancement technique constitutes, 0.01111111...
#   42             (popular method, 0.013386880856722058)          (color restoration, 0.011111111111111112)
#   43          (wavelet transform, 0.013386880856722058)                      (pixel, 0.011111111111111112)
#   44                 (femto cell, 0.013386880856722058)               (optical flow, 0.011111111111111112)
#   45       (injected contaminant, 0.013386880856722058)           (domain ontology , 0.011111111111111112)
#   46        (time-varying delays, 0.013386880856722058)           (concept lattice , 0.011111111111111112)
#   47    (markov decision process, 0.013386880856722058)         (description logic , 0.011111111111111112)
#   48             (paper presents, 0.013386880856722051)     (heterogeneous networks, 0.011111111111111112)
#   49             (advanced cross, 0.013386880856722051)              (image scaling, 0.011111111111111112)
#   50  (lingual information access, 0.013386880856722...        (selection algorithm, 0.011111111111111112)
#   51         (adaptive technique, 0.013386880856722051)         (instance selection, 0.011111111111111112)
#   52  (enhancement technique constitutes, 0.01338688...         (water distribution, 0.011111111111111112)
#   53          (color restoration, 0.013386880856722051)  (stochastic neural networks, 0.011111111111111...
#   54              (image scaling, 0.013386880856722051)               (markov chain, 0.011111111111111112)
#   55        (selection algorithm, 0.013386880856722051)               (task cluster, 0.011111111111111112)
#   56         (instance selection, 0.013386880856722051)                   (07.05.mh, 0.011111111111111112)
#   57                (task cluster, 0.01338688085672205)   (promising access network, 0.011111111111111112)
#   58     (image enhancement based, 0.01338688085672205)           (distributed time, 0.011111111111111112)
#   59          (subgroup discovery, 0.01338688085672205)    (continuous optimization, 0.011111111111111112)
#   60            (neural networks, 0.010980134350694028)    (image enhancement based, 0.011111111111111112)
#   61  (global asymptotic stability, 0.01046094738154...              (sparse matrix, 0.011111111111111112)
#   62  (unbounded distributed delays, 0.0104609473815...            (formal context , 0.011111111111111112)
#   63  (lyapunov–krasovskii functional, 0.01046094738...                 (femto cell, 0.011111111111111112)
#   64        (rate of convergence, 0.009686364856663672)         (subgroup discovery, 0.011111111111111112)
#   65                (exponential, 0.009174435082898239)       (injected contaminant, 0.011111111111111112)
#   66            (cognitive radio, 0.008575579590454302)        (time-varying delays, 0.011111111111111112)
#   67        (global optimization, 0.006131880521916279)    (markov decision process, 0.011111111111111112)
#   68                 (simulation, 0.005658463050334134)           (using eigen faces, 0.01111111111111111)
#   69             (varying delays, 0.004532737425117596)               (face database, 0.01111111111111111)
#   70      (exponential stability, 0.004532737425117596)            (face recognition, 0.01111111111111111)
#   71  (biological neural networks, 0.004441314603231...                 (eigen faces, 0.01111111111111111)
#   72               (computation, 0.0037250344020368104)  (approximation coefficients, 0.01111111111111111)
#   73          (domain ontology , 0.0020080321286673323)                 (new wavelet, 0.01111111111111111)
#   74     (query server accesses, 0.0020080321286673323)         (dimension reduction, 0.01111111111111111)
#   75        (specified products, 0.0020080321286673323)   (dynamic range compression, 0.01111111111111111)
#   76           (crawler program, 0.0020080321286673323)              (popular method, 0.01111111111111111)
#   77          (scored web pages, 0.0020080321286673323)           (wavelet transform, 0.01111111111111111)
#   78        (criteria according, 0.0020080321286673323)  (lyapunov–krasovskii functional, 0.00961528179...
#   79              (locate pages, 0.0020080321286673323)            (neural networks, 0.008947881526501462)
#   80      (responsive web pages, 0.0020080321286673323)  (global asymptotic stability, 0.00849813751351...
#   81            (s search query, 0.0020080321286673323)  (unbounded distributed delays, 0.0084981375135...
#   82          (product offering, 0.0020080321286673323)            (cognitive radio, 0.007814488556561775)
#   83              (scored based, 0.0020080321286673323)        (rate of convergence, 0.006523597046731265)
#   84             (search engine, 0.0020080321286673323)                (exponential, 0.004691172271981061)
#   85         (web pages located, 0.0020080321286673323)        (global optimization, 0.004436183700959878)
#   86        (locating web pages, 0.0020080321286673323)                (simulation, 0.0038790375018192377)
#   87          (concept lattice , 0.0020080321286673323)               (computation, 0.0030772492259638975)
#   88        (description logic , 0.0020080321286673323)  (biological neural networks, 0.002712959277747...
#   89             (assists users, 0.0020080321286673323)            (varying delays, 0.0027111901472106036)
#   90           (formal context , 0.0020080321286673323)     (exponential stability, 0.0027111901472106036)

# %% [markdown]
# ## Year 2009

# %%
#View tables for year 2009
tables_metrics_view(2009)
# Out:
# Year: 2009
#
# Rank                                  Node Betweenness                                  Degree Centrality
#    1  (mathematical optimization, 0.08028919330289193)     (mathematical optimization, 0.273972602739726)
#    2      (evolutionary algorithm, 0.0273972602739726)  (particle swarm optimization, 0.1780821917808219)
#    3                 (algorithm, 0.026255707762557076)  (adaptive neuro fuzzy inference system, 0.1780...
#    4     (differential evolution, 0.00228310502283105)             (gradient descent, 0.1780821917808219)
#    5            (cognitive radio, 0.00076103500761035)                    (recursion, 0.1780821917808219)
#    6            (neural networks, 0.00076103500761035)               (identification, 0.1780821917808219)
#    7                 (05.45.xt, 0.0001902587519025875)           (stability analysis, 0.1780821917808219)
#    8                 (05.45.gg, 0.0001902587519025875)                        (anfis, 0.1780821917808219)
#    9                (particle swarm optimization, 0.0)  (recursive least squares filter, 0.17808219178...
#   10                           (web applications, 0.0)    (hybrid learning algorithm, 0.1780821917808219)
#   11                             (real data sets, 0.0)            (system identifier, 0.1780821917808219)
#   12                         (desirable property, 0.0)                   (simulation, 0.1780821917808219)
#   13                            (style algorithm, 0.0)             (lyapunov fractal, 0.1780821917808219)
#   14                              (dual sparsity, 0.0)             (machine learning, 0.1780821917808219)
#   15                                      (34k14, 0.0)          (semantic attributes, 0.0958904109589041)
#   16                          (distributed delay, 0.0)            (semantic filexa0…, 0.0958904109589041)
#   17                               (blog network, 0.0)                 (manual entry, 0.0958904109589041)
#   18                    (disjunctive normal form, 0.0)   (semantic attributes allows, 0.0958904109589041)
#   19                                 (fuzzy rule, 0.0)        (improved organization, 0.0958904109589041)
#   20                                   (05.45.vx, 0.0)        (attribute information, 0.0958904109589041)
#   21                   (linear matrix inequality, 0.0)      (automatically generated, 0.0958904109589041)
#   22                             (visual quality, 0.0)       (evolutionary algorithm, 0.0958904109589041)
#   23                  (artificial neural network, 0.0)                 (new approach, 0.0958904109589041)
#   24                        (semantic attributes, 0.0)                     (deep web, 0.0958904109589041)
#   25                          (semantic filexa0…, 0.0)              (kosmix approach, 0.0958904109589041)
#   26                               (manual entry, 0.0)  (significant information resource, 0.095890410...
#   27                 (semantic attributes allows, 0.0)                 (web crawlers, 0.0958904109589041)
#   28                      (improved organization, 0.0)          (inhospitable region, 0.0958904109589041)
#   29                      (attribute information, 0.0)        (information discovery, 0.0958904109589041)
#   30                    (automatically generated, 0.0)         (semantic information, 0.0958904109589041)
#   31                           (complex networks, 0.0)      (conventional web search, 0.0958904109589041)
#   32                               (data mining , 0.0)       (differential evolution, 0.0821917808219178)
#   33      (adaptive neuro fuzzy inference system, 0.0)                    (algorithm, 0.0547945205479452)
#   34                           (gradient descent, 0.0)               (real data sets, 0.0547945205479452)
#   35                                  (recursion, 0.0)           (desirable property, 0.0547945205479452)
#   36                             (identification, 0.0)              (style algorithm, 0.0547945205479452)
#   37                         (stability analysis, 0.0)                (dual sparsity, 0.0547945205479452)
#   38                                      (anfis, 0.0)          (global optimization, 0.0547945205479452)
#   39             (recursive least squares filter, 0.0)          (rate of convergence, 0.0547945205479452)
#   40                  (hybrid learning algorithm, 0.0)        (margin markov network, 0.0547945205479452)
#   41                          (system identifier, 0.0)              (cognitive radio, 0.0410958904109589)
#   42                                 (simulation, 0.0)                     (05.45.xt, 0.0410958904109589)
#   43                           (lyapunov fractal, 0.0)                   (test suite, 0.0410958904109589)
#   44                           (machine learning, 0.0)         (optimization problem, 0.0410958904109589)
#   45                        (global optimization, 0.0)                     (aliasing, 0.0410958904109589)
#   46                                 (test suite, 0.0)                  (3d modeling, 0.0410958904109589)
#   47                        (rate of convergence, 0.0)              (neural networks, 0.0410958904109589)
#   48                       (optimization problem, 0.0)                     (05.45.gg, 0.0410958904109589)
#   49                               (new approach, 0.0)       (reinforcement learning, 0.0410958904109589)
#   50                                   (deep web, 0.0)                     (05.45.vx, 0.0273972602739726)
#   51                            (kosmix approach, 0.0)     (linear matrix inequality, 0.0273972602739726)
#   52           (significant information resource, 0.0)             (complex networks, 0.0273972602739726)
#   53                               (web crawlers, 0.0)         (frequency allocation, 0.0273972602739726)
#   54                        (inhospitable region, 0.0)               (frequency band, 0.0273972602739726)
#   55                      (information discovery, 0.0)            (social inequality, 0.0273972602739726)
#   56                                   (aliasing, 0.0)             (web applications, 0.0136986301369863)
#   57                                (3d modeling, 0.0)                        (34k14, 0.0136986301369863)
#   58                             (paper presents, 0.0)            (distributed delay, 0.0136986301369863)
#   59                       (frequency allocation, 0.0)                 (blog network, 0.0136986301369863)
#   60                             (frequency band, 0.0)      (disjunctive normal form, 0.0136986301369863)
#   61               (interference (communication), 0.0)                   (fuzzy rule, 0.0136986301369863)
#   62                                 (web forums, 0.0)               (visual quality, 0.0136986301369863)
#   63                      (margin markov network, 0.0)    (artificial neural network, 0.0136986301369863)
#   64                                      (92b20, 0.0)                 (data mining , 0.0136986301369863)
#   65                        (lyapunov functional, 0.0)               (paper presents, 0.0136986301369863)
#   66                      (information diffusion, 0.0)  (interference (communication), 0.0136986301369...
#   67                          (social inequality, 0.0)                   (web forums, 0.0136986301369863)
#   68                    (digital images captured, 0.0)                        (92b20, 0.0136986301369863)
#   69                 (biological neural networks, 0.0)          (lyapunov functional, 0.0136986301369863)
#   70                       (semantic information, 0.0)        (information diffusion, 0.0136986301369863)
#   71                    (conventional web search, 0.0)      (digital images captured, 0.0136986301369863)
#   72                     (reinforcement learning, 0.0)   (biological neural networks, 0.0136986301369863)
#   73                            (lyapunov method, 0.0)              (lyapunov method, 0.0136986301369863)
#   74                           (cognitive radios, 0.0)             (cognitive radios, 0.0136986301369863)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (mathematical optimization, 0.034332896447423156)   (mathematical optimization, 0.03031380581347598)
#    2      (evolutionary algorithm, 0.02360992065659045)            (cognitive radio, 0.019823351775115405)
#    3             (cognitive radio, 0.02155636618429134)     (evolutionary algorithm, 0.019425658903641983)
#    4                   (05.45.vx, 0.017352672537676993)             (neural networks, 0.01793318470396496)
#    5  (particle swarm optimization, 0.01700137771467...                    (05.45.xt, 0.01754385962221373)
#    6  (adaptive neuro fuzzy inference system, 0.0170...                    (05.45.gg, 0.01754385962221373)
#    7           (gradient descent, 0.017001377714673405)  (particle swarm optimization, 0.01724091812933...
#    8           (machine learning, 0.017001377714673405)  (adaptive neuro fuzzy inference system, 0.0169...
#    9                  (recursion, 0.017001377714673402)           (gradient descent, 0.016972937704095373)
#   10             (identification, 0.017001377714673402)                  (recursion, 0.016972937704095373)
#   11         (stability analysis, 0.017001377714673402)             (identification, 0.016972937704095373)
#   12                      (anfis, 0.017001377714673402)         (stability analysis, 0.016972937704095373)
#   13  (recursive least squares filter, 0.01700137771...                      (anfis, 0.016972937704095373)
#   14  (hybrid learning algorithm, 0.017001377714673402)  (recursive least squares filter, 0.01697293770...
#   15          (system identifier, 0.017001377714673402)  (hybrid learning algorithm, 0.016972937704095373)
#   16                 (simulation, 0.017001377714673402)          (system identifier, 0.016972937704095373)
#   17           (lyapunov fractal, 0.017001377714673402)                 (simulation, 0.016972937704095373)
#   18     (differential evolution, 0.015966175177148226)           (lyapunov fractal, 0.016972937704095373)
#   19   (linear matrix inequality, 0.014695077149155036)           (machine learning, 0.016972937704095373)
#   20            (neural networks, 0.014695077149155036)   (linear matrix inequality, 0.014506365223108287)
#   21          (social inequality, 0.014695077149155036)          (social inequality, 0.014506365223108287)
#   22        (semantic attributes, 0.014695077149155035)           (web applications, 0.013513513513513514)
#   23          (semantic filexa0…, 0.014695077149155035)             (real data sets, 0.013513513513513514)
#   24               (manual entry, 0.014695077149155035)         (desirable property, 0.013513513513513514)
#   25  (semantic attributes allows, 0.014695077149155...            (style algorithm, 0.013513513513513514)
#   26      (improved organization, 0.014695077149155035)              (dual sparsity, 0.013513513513513514)
#   27      (attribute information, 0.014695077149155035)                      (34k14, 0.013513513513513514)
#   28    (automatically generated, 0.014695077149155035)          (distributed delay, 0.013513513513513514)
#   29               (new approach, 0.014695077149155035)               (blog network, 0.013513513513513514)
#   30                   (deep web, 0.014695077149155035)             (visual quality, 0.013513513513513514)
#   31            (kosmix approach, 0.014695077149155035)  (artificial neural network, 0.013513513513513514)
#   32  (significant information resource, 0.014695077...        (semantic attributes, 0.013513513513513514)
#   33               (web crawlers, 0.014695077149155035)          (semantic filexa0…, 0.013513513513513514)
#   34        (inhospitable region, 0.014695077149155035)               (manual entry, 0.013513513513513514)
#   35      (information discovery, 0.014695077149155035)  (semantic attributes allows, 0.013513513513513...
#   36       (semantic information, 0.014695077149155035)      (improved organization, 0.013513513513513514)
#   37    (conventional web search, 0.014695077149155035)      (attribute information, 0.013513513513513514)
#   38           (web applications, 0.014695077149155033)    (automatically generated, 0.013513513513513514)
#   39             (real data sets, 0.014695077149155033)               (new approach, 0.013513513513513514)
#   40         (desirable property, 0.014695077149155033)                   (deep web, 0.013513513513513514)
#   41            (style algorithm, 0.014695077149155033)            (kosmix approach, 0.013513513513513514)
#   42              (dual sparsity, 0.014695077149155033)  (significant information resource, 0.013513513...
#   43                      (34k14, 0.014695077149155033)               (web crawlers, 0.013513513513513514)
#   44          (distributed delay, 0.014695077149155033)        (inhospitable region, 0.013513513513513514)
#   45             (visual quality, 0.014695077149155033)      (information discovery, 0.013513513513513514)
#   46  (artificial neural network, 0.014695077149155033)             (paper presents, 0.013513513513513514)
#   47             (paper presents, 0.014695077149155033)                 (web forums, 0.013513513513513514)
#   48                 (web forums, 0.014695077149155033)      (margin markov network, 0.013513513513513514)
#   49      (margin markov network, 0.014695077149155033)                      (92b20, 0.013513513513513514)
#   50                      (92b20, 0.014695077149155033)        (lyapunov functional, 0.013513513513513514)
#   51        (lyapunov functional, 0.014695077149155033)      (information diffusion, 0.013513513513513514)
#   52    (digital images captured, 0.014695077149155033)    (digital images captured, 0.013513513513513514)
#   53  (biological neural networks, 0.014695077149155...  (biological neural networks, 0.013513513513513...
#   54           (cognitive radios, 0.014695077149155033)       (semantic information, 0.013513513513513514)
#   55        (frequency allocation, 0.01445584362825564)    (conventional web search, 0.013513513513513514)
#   56              (frequency band, 0.01445584362825564)           (cognitive radios, 0.013513513513513514)
#   57                   (05.45.xt, 0.013366279454894051)       (frequency allocation, 0.013293452192587122)
#   58                   (05.45.gg, 0.013366279454894051)             (frequency band, 0.013293452192587122)
#   59         (global optimization, 0.01116778024636041)     (differential evolution, 0.011581386231270896)
#   60        (rate of convergence, 0.011167780246360408)                  (algorithm, 0.011245279293953796)
#   61  (interference (communication), 0.0083122551558...                   (aliasing, 0.010201674562858174)
#   62                 (test suite, 0.008269563556795288)                (3d modeling, 0.010201674562858174)
#   63       (optimization problem, 0.008269563556795288)     (reinforcement learning, 0.010201674562858174)
#   64    (disjunctive normal form, 0.005072245303005871)                   (05.45.vx, 0.009483167404813298)
#   65                 (fuzzy rule, 0.005072245303005871)           (complex networks, 0.009483167404813298)
#   66               (data mining , 0.005072245303005871)       (global optimization, 0.0076708775894987315)
#   67                  (algorithm, 0.003663525492475699)       (rate of convergence, 0.0076708775894987315)
#   68              (blog network, 0.0022042615723732555)  (interference (communication), 0.0076437978937...
#   69          (complex networks, 0.0022042615723732555)           (lyapunov method, 0.0071081389038725185)
#   70                  (aliasing, 0.0022042615723732555)                 (fuzzy rule, 0.006156254327330366)
#   71               (3d modeling, 0.0022042615723732555)                (test suite, 0.0055481247473898035)
#   72     (information diffusion, 0.0022042615723732555)      (optimization problem, 0.0055481247473898035)
#   73    (reinforcement learning, 0.0022042615723732555)   (disjunctive normal form, 0.0040916406771786965)
#   74           (lyapunov method, 0.0022042615723732555)              (data mining , 0.0040916406771786965)

# %% [markdown]
# ## Year 2010

# %%
#View tables for year 2010
tables_metrics_view(2010)
# Out:
# Year: 2010
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1                   (algorithm, 0.04395497800259705)       (reinforcement learning, 0.2527472527472528)
#    2            (cognitive radio, 0.034901641568308245)  (interference (communication), 0.2307692307692...
#    3    (linear matrix inequality, 0.02612942612942613)                   (algorithm, 0.23076923076923078)
#    4     (reinforcement learning, 0.023558830939783323)           (multi-agent system, 0.2087912087912088)
#    5  (interference (communication), 0.0168026241835...              (cognitive radio, 0.2087912087912088)
#    6  (artificial neural network, 0.007081807081807082)        (programming paradigm, 0.17582417582417584)
#    7         (multi-agent system, 0.006855534236486616)                  (q-learning, 0.17582417582417584)
#    8       (programming paradigm, 0.006226040273659321)  (whole earth 'lectronic link, 0.16483516483516...
#    9                 (q-learning, 0.004648719886815125)    (linear matrix inequality, 0.14285714285714288)
#   10  (whole earth 'lectronic link, 0.00397804135899...         (rate of convergence, 0.13186813186813187)
#   11            (neural networks, 0.003663003663003663)              (coexist (image), 0.1098901098901099)
#   12           (coexist (image), 0.0020512820512820504)           (self-organization, 0.09890109890109891)
#   13      (centralized computing, 0.001784212260402737)             (real-time clock, 0.09890109890109891)
#   14                (simulation, 0.0017582417582417582)            (action selection, 0.09890109890109891)
#   15       (rate of convergence, 0.0003357753357753358)                  (simulation, 0.09890109890109891)
#   16               (data mining, 0.0001221001221001221)        (overhead (computing), 0.08791208791208792)
#   17  (mathematical optimization, 0.0001221001221001...     (real-time transcription, 0.08791208791208792)
#   18          (machine learning, 0.0001221001221001221)                 (interaction, 0.08791208791208792)
#   19        (self-organization, 3.0525030525030525e-05)          (stationary process, 0.07692307692307693)
#   20                 (particle swarm optimization, 0.0)             (make inferences, 0.06593406593406594)
#   21                          (numerical analysis, 0.0)  (underlying application logic, 0.0659340659340...
#   22                             (real-time clock, 0.0)                (synergic use, 0.06593406593406594)
#   23                                    (numerous, 0.0)       (ontological framework, 0.06593406593406594)
#   24                            (action selection, 0.0)           (semantic approach, 0.06593406593406594)
#   25                           (spectrum analyzer, 0.0)           (business scenario, 0.06593406593406594)
#   26                   (height above ground level, 0.0)  (early termination techniques, 0.0659340659340...
#   27                                (neutral type, 0.0)              (new techniques, 0.06593406593406594)
#   28                              (input multiple, 0.0)         (existing approaches, 0.06593406593406594)
#   29                      (scheduling (computing), 0.0)           (resulting indexes, 0.06593406593406594)
#   30                                (social media, 0.0)            (query processing, 0.06593406593406594)
#   31                           (context awareness, 0.0)              (inverted lists, 0.06593406593406594)
#   32                          (network congestion, 0.0)             (based formalism, 0.06593406593406594)
#   33                       (operating environment, 0.0)                   (cognition, 0.06593406593406594)
#   34                            (channel capacity, 0.0)  (detailed experimental evaluation, 0.065934065...
#   35                          (analysis technique, 0.0)       (centralized computing, 0.05494505494505495)
#   36                    (continuous optimization , 0.0)      (scheduling (computing), 0.05494505494505495)
#   37              (lyapunov–krasovskii functional, 0.0)           (context awareness, 0.05494505494505495)
#   38                 (genetic regulatory networks, 0.0)          (network congestion, 0.05494505494505495)
#   39                                 (game theory, 0.0)       (operating environment, 0.05494505494505495)
#   40                (global exponential stability, 0.0)                    (numerous, 0.04395604395604396)
#   41                                  (web search, 0.0)   (artificial neural network, 0.04395604395604396)
#   42                                 (hoc network, 0.0)                 (hoc network, 0.04395604395604396)
#   43                 (opportunistically transmits, 0.0)  (opportunistically transmits, 0.04395604395604...
#   44           (exploiting underutilized channels, 0.0)  (exploiting underutilized channels, 0.04395604...
#   45                                   (gsm bands, 0.0)                   (gsm bands, 0.04395604395604396)
#   46                (structure prediction problem, 0.0)  (structure prediction problem, 0.0439560439560...
#   47                            (english sentence, 0.0)            (english sentence, 0.04395604395604396)
#   48                          (implemented parser, 0.0)          (implemented parser, 0.04395604395604396)
#   49                     (semantic representation, 0.0)     (semantic representation, 0.04395604395604396)
#   50                            (iterative method, 0.0)           (efficiently share, 0.04395604395604396)
#   51                           (efficiently share, 0.0)        (diversity techniques, 0.04395604395604396)
#   52                        (diversity techniques, 0.0)         (secondary terminals, 0.04395604395604396)
#   53                         (secondary terminals, 0.0)    (cognitive radio networks, 0.04395604395604396)
#   54                    (cognitive radio networks, 0.0)        (overlay cognitive ad, 0.04395604395604396)
#   55                             (make inferences, 0.0)            (semantic parsing, 0.04395604395604396)
#   56                (underlying application logic, 0.0)          (spectral resources, 0.04395604395604396)
#   57                                (synergic use, 0.0)                 (data mining, 0.03296703296703297)
#   58                       (ontological framework, 0.0)             (neural networks, 0.03296703296703297)
#   59                           (semantic approach, 0.0)            (iterative method, 0.03296703296703297)
#   60                           (business scenario, 0.0)             (systems biology, 0.03296703296703297)
#   61                              (multistability, 0.0)            (lyapunov fractal, 0.03296703296703297)
#   62                             (systems biology, 0.0)   (mathematical optimization, 0.03296703296703297)
#   63                            (lyapunov fractal, 0.0)            (machine learning, 0.03296703296703297)
#   64                        (overhead (computing), 0.0)     (gene regulatory network, 0.03296703296703297)
#   65                          (stationary process, 0.0)  (particle swarm optimization, 0.02197802197802...
#   66                     (real-time transcription, 0.0)          (numerical analysis, 0.02197802197802198)
#   67                               (decision tree, 0.0)           (spectrum analyzer, 0.02197802197802198)
#   68                             (complex network, 0.0)   (height above ground level, 0.02197802197802198)
#   69                         (speaker recognition, 0.0)            (channel capacity, 0.02197802197802198)
#   70                (early termination techniques, 0.0)  (genetic regulatory networks, 0.02197802197802...
#   71                              (new techniques, 0.0)                 (game theory, 0.02197802197802198)
#   72                         (existing approaches, 0.0)              (multistability, 0.02197802197802198)
#   73                           (resulting indexes, 0.0)               (decision tree, 0.02197802197802198)
#   74                            (query processing, 0.0)           (social inequality, 0.02197802197802198)
#   75                              (inverted lists, 0.0)         (lyapunov functional, 0.02197802197802198)
#   76                        (output communication, 0.0)                (neutral type, 0.01098901098901099)
#   77                           (social inequality, 0.0)              (input multiple, 0.01098901098901099)
#   78                              (important tool, 0.0)                (social media, 0.01098901098901099)
#   79                                 (interaction, 0.0)          (analysis technique, 0.01098901098901099)
#   80                     (differential evolution , 0.0)    (continuous optimization , 0.01098901098901099)
#   81                             (time complexity, 0.0)  (lyapunov–krasovskii functional, 0.01098901098...
#   82                         (lyapunov functional, 0.0)  (global exponential stability, 0.0109890109890...
#   83                         (context information, 0.0)                  (web search, 0.01098901098901099)
#   84                        (overlay cognitive ad, 0.0)             (complex network, 0.01098901098901099)
#   85                            (semantic parsing, 0.0)         (speaker recognition, 0.01098901098901099)
#   86                          (spectral resources, 0.0)        (output communication, 0.01098901098901099)
#   87                             (based formalism, 0.0)              (important tool, 0.01098901098901099)
#   88                     (gene regulatory network, 0.0)     (differential evolution , 0.01098901098901099)
#   89                                   (cognition, 0.0)             (time complexity, 0.01098901098901099)
#   90                      (evolutionary algorithm, 0.0)         (context information, 0.01098901098901099)
#   91                 (global asymptotic stability, 0.0)      (evolutionary algorithm, 0.01098901098901099)
#   92            (detailed experimental evaluation, 0.0)  (global asymptotic stability, 0.01098901098901...
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1    (linear matrix inequality, 0.04922243879022824)    (linear matrix inequality, 0.05396863761181614)
#    2     (reinforcement learning, 0.026309482111826703)      (reinforcement learning, 0.03549058367137446)
#    3                  (algorithm, 0.025263096884051033)            (cognitive radio, 0.030581861742810502)
#    4             (cognitive radio, 0.02501627704226765)                   (algorithm, 0.02969798452006319)
#    5  (interference (communication), 0.0242048096398...         (multi-agent system, 0.026525721803430397)
#    6         (multi-agent system, 0.021760265916818476)  (interference (communication), 0.0247305152664...
#    7       (programming paradigm, 0.019526648978279985)                 (q-learning, 0.022085625624936964)
#    8  (artificial neural network, 0.018732036446090155)       (programming paradigm, 0.020894018783911845)
#    9                 (q-learning, 0.018508605706331907)  (whole earth 'lectronic link, 0.01979648548847...
#   10  (whole earth 'lectronic link, 0.01760634818452...  (artificial neural network, 0.016977767675788395)
#   11        (rate of convergence, 0.014008785707134343)  (genetic regulatory networks, 0.01371072786920...
#   12            (coexist (image), 0.012510385874265303)             (multistability, 0.013710727869201796)
#   13            (systems biology, 0.011768047506186062)        (lyapunov functional, 0.012691432688711236)
#   14           (lyapunov fractal, 0.011768047506186062)        (rate of convergence, 0.011341940142099174)
#   15    (gene regulatory network, 0.011768047506186062)             (input multiple, 0.010869565217391304)
#   16                 (simulation, 0.011550347622628744)               (social media, 0.010869565217391304)
#   17             (input multiple, 0.011074197120708748)   (continuous optimization , 0.010869565217391304)
#   18               (social media, 0.011074197120708748)                 (web search, 0.010869565217391304)
#   19   (continuous optimization , 0.011074197120708748)                (hoc network, 0.010869565217391304)
#   20                 (web search, 0.011074197120708748)  (opportunistically transmits, 0.01086956521739...
#   21        (speaker recognition, 0.011074197120708748)  (exploiting underutilized channels, 0.01086956...
#   22       (output communication, 0.011074197120708748)                  (gsm bands, 0.010869565217391304)
#   23             (important tool, 0.011074197120708748)  (structure prediction problem, 0.0108695652173...
#   24    (differential evolution , 0.011074197120708748)           (english sentence, 0.010869565217391304)
#   25        (context information, 0.011074197120708748)         (implemented parser, 0.010869565217391304)
#   26     (evolutionary algorithm, 0.011074197120708748)    (semantic representation, 0.010869565217391304)
#   27                (hoc network, 0.011074197120708746)          (efficiently share, 0.010869565217391304)
#   28  (opportunistically transmits, 0.01107419712070...       (diversity techniques, 0.010869565217391304)
#   29  (exploiting underutilized channels, 0.01107419...        (secondary terminals, 0.010869565217391304)
#   30                  (gsm bands, 0.011074197120708746)   (cognitive radio networks, 0.010869565217391304)
#   31  (structure prediction problem, 0.0110741971207...        (speaker recognition, 0.010869565217391304)
#   32           (english sentence, 0.011074197120708746)       (output communication, 0.010869565217391304)
#   33         (implemented parser, 0.011074197120708746)             (important tool, 0.010869565217391304)
#   34    (semantic representation, 0.011074197120708746)    (differential evolution , 0.010869565217391304)
#   35          (efficiently share, 0.011074197120708746)        (context information, 0.010869565217391304)
#   36       (diversity techniques, 0.011074197120708746)       (overlay cognitive ad, 0.010869565217391304)
#   37        (secondary terminals, 0.011074197120708746)           (semantic parsing, 0.010869565217391304)
#   38   (cognitive radio networks, 0.011074197120708746)         (spectral resources, 0.010869565217391304)
#   39       (overlay cognitive ad, 0.011074197120708746)     (evolutionary algorithm, 0.010869565217391304)
#   40           (semantic parsing, 0.011074197120708746)              (make inferences, 0.0108695652173913)
#   41         (spectral resources, 0.011074197120708746)  (underlying application logic, 0.0108695652173...
#   42          (business scenario, 0.011074197120708744)                 (synergic use, 0.0108695652173913)
#   43             (inverted lists, 0.011074197120708744)        (ontological framework, 0.0108695652173913)
#   44            (based formalism, 0.011074197120708744)            (semantic approach, 0.0108695652173913)
#   45  (detailed experimental evaluation, 0.011074197...            (business scenario, 0.0108695652173913)
#   46            (make inferences, 0.011074197120708743)  (early termination techniques, 0.0108695652173...
#   47  (underlying application logic, 0.0110741971207...               (new techniques, 0.0108695652173913)
#   48               (synergic use, 0.011074197120708743)          (existing approaches, 0.0108695652173913)
#   49      (ontological framework, 0.011074197120708743)            (resulting indexes, 0.0108695652173913)
#   50          (semantic approach, 0.011074197120708743)             (query processing, 0.0108695652173913)
#   51  (early termination techniques, 0.0110741971207...               (inverted lists, 0.0108695652173913)
#   52             (new techniques, 0.011074197120708743)              (based formalism, 0.0108695652173913)
#   53        (existing approaches, 0.011074197120708743)  (detailed experimental evaluation, 0.010869565...
#   54          (resulting indexes, 0.011074197120708743)                 (simulation, 0.010178894774867553)
#   55           (query processing, 0.011074197120708743)             (neural networks, 0.00993540272969087)
#   56          (self-organization, 0.010861241365220925)            (coexist (image), 0.009835610158433655)
#   57            (real-time clock, 0.010819718775763489)          (social inequality, 0.008612961664267733)
#   58           (action selection, 0.010819718775763489)            (systems biology, 0.008572794106983906)
#   59       (overhead (computing), 0.009986157925894058)           (lyapunov fractal, 0.008572794106983904)
#   60    (real-time transcription, 0.009986157925894058)    (gene regulatory network, 0.008572794106983904)
#   61                (interaction, 0.009986157925894058)     (scheduling (computing), 0.008393641705848226)
#   62            (neural networks, 0.009241343436531654)          (context awareness, 0.008393641705848226)
#   63  (genetic regulatory networks, 0.00886919559588...         (network congestion, 0.008393641705848226)
#   64             (multistability, 0.008869195595884552)      (operating environment, 0.008393641705848224)
#   65         (stationary process, 0.008814607635478235)                (interaction, 0.008325012211633115)
#   66        (lyapunov functional, 0.007942235384191785)          (self-organization, 0.008230432336918364)
#   67      (centralized computing, 0.007837693569888298)       (overhead (computing), 0.007985301787856544)
#   68                  (cognition, 0.007822329056199579)            (real-time clock, 0.007318805960748306)
#   69     (scheduling (computing), 0.007791681752690157)           (action selection, 0.007318805960748306)
#   70          (context awareness, 0.007791681752690157)  (mathematical optimization, 0.007313277596612715)
#   71         (network congestion, 0.007791681752690155)      (centralized computing, 0.006920703961404976)
#   72      (operating environment, 0.007791681752690155)    (real-time transcription, 0.006733323993714099)
#   73          (social inequality, 0.007307332843012555)         (stationary process, 0.006031630986573159)
#   74           (machine learning, 0.006935313213327408)  (lyapunov–krasovskii functional, 0.00579828696...
#   75  (mathematical optimization, 0.0059581133828924...                  (cognition, 0.005388919160236894)
#   76            (time complexity, 0.005649674314154413)                 (data mining, 0.00522583288210994)
#   77  (global asymptotic stability, 0.00564967431415...         (numerical analysis, 0.004828291868600383)
#   78                   (numerous, 0.005616050180980809)                (game theory, 0.004610874151393056)
#   79               (neutral type, 0.005099971173162372)           (machine learning, 0.004445473026904941)
#   80  (lyapunov–krasovskii functional, 0.00509997117...         (analysis technique, 0.004445109478833597)
#   81  (global exponential stability, 0.0050999711731...                   (numerous, 0.004038698308284965)
#   82            (complex network, 0.005099971173162372)            (time complexity, 0.004035044596584365)
#   83         (spectrum analyzer, 0.0049015906672897035)  (global asymptotic stability, 0.00403504459658...
#   84  (height above ground level, 0.0049015906672897...         (spectrum analyzer, 0.0039656769829695265)
#   85  (particle swarm optimization, 0.00484147194497...  (height above ground level, 0.0039656769829695...
#   86           (iterative method, 0.004720915997165173)              (decision tree, 0.003822313387621685)
#   87                (game theory, 0.004150787544405785)              (neutral type, 0.0037143608753257636)
#   88         (numerical analysis, 0.003828553929308644)  (global exponential stability, 0.0037143608753...
#   89          (channel capacity, 0.0037507048254560773)           (complex network, 0.0037143608753257636)
#   90                (data mining, 0.003626243236964066)  (particle swarm optimization, 0.00358492445396...
#   91        (analysis technique, 0.0016611295681063123)           (iterative method, 0.003566502812265058)
#   92             (decision tree, 0.0016611295681063123)          (channel capacity, 0.0029500602123577477)

# %% [markdown]
# ## Year 2011

# %%
#View tables for year 2011
tables_metrics_view(2011)
# Out:
# Year: 2011
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1      (differential evolution, 0.09299798167986337)     (increasingly inadequate, 0.18421052631578946)
#    2   (artificial neural network, 0.08947885939036382)               (critical role, 0.18421052631578946)
#    3       (evolutionary algorithm, 0.0888060860114889)            (topic navigation, 0.18421052631578946)
#    4                  (experiment, 0.08802980903586399)        (membership structure, 0.18421052631578946)
#    5   (mathematical optimization, 0.08764167054805154)       (promising alternative, 0.18421052631578946)
#    6                   (algorithm, 0.08181959323086477)  (coherent clusters allowing, 0.18421052631578946)
#    7             (cognitive radio, 0.07421207886974072)          (clustering results, 0.18421052631578946)
#    8  (interference (communication), 0.0427469854577...                (ranked lists, 0.18421052631578946)
#    9  (particle swarm optimization, 0.02010557366868...                   (long list, 0.18421052631578946)
#   10             (lyapunov fractal, 0.0151891528230606)             (common strategy, 0.18421052631578946)
#   11         (social inequality, 0.0032991771464058375)    (disparate search results, 0.18421052631578946)
#   12         (numerical analysis, 0.003182735600062102)              (search engines, 0.18421052631578946)
#   13        (quality of service, 0.0029498525073746312)  (automatic clustering procedure, 0.18421052631...
#   14  (linear matrix inequality, 0.0013714226569373283)              (wiki interface, 0.18421052631578946)
#   15               (simulation, 0.00020700719349997412)    (introduce clusteringwiki, 0.18421052631578946)
#   16         (fairness measure, 0.00020700719349997412)              (search results, 0.18421052631578946)
#   17  (neural network simulation, 3.881384878124515e...       (search engine utility, 0.18421052631578946)
#   18                           (checking (action), 0.0)          (clustering divides, 0.18421052631578946)
#   19                                 (exponential, 0.0)         (unprecedented scale, 0.18421052631578946)
#   20                             (swarm robotics , 0.0)   (personalized presentation, 0.18421052631578946)
#   21                          (self-organization , 0.0)     (personalized clustering, 0.18421052631578946)
#   22                     (telecommunications link, 0.0)       (clustering algorithms, 0.18421052631578946)
#   23                            (channel capacity, 0.0)   (artificial neural network, 0.15789473684210525)
#   24                      (multitier architecture, 0.0)  (interference (communication), 0.0964912280701...
#   25                             (time complexity, 0.0)            (lyapunov fractal, 0.08771929824561403)
#   26                      (reinforcement learning, 0.0)    (linear matrix inequality, 0.07017543859649122)
#   27                             (question search, 0.0)             (cognitive radio, 0.07017543859649122)
#   28                              (dependent deep, 0.0)  (particle swarm optimization, 0.06140350877192...
#   29                                (network hmms, 0.0)                  (simulation, 0.05263157894736842)
#   30                                (mixture hmms, 0.0)   (mathematical optimization, 0.05263157894736842)
#   31                        (discrepancy function, 0.0)            (fairness measure, 0.05263157894736842)
#   32                        (generalization error, 0.0)           (social inequality, 0.05263157894736842)
#   33                    (multiple secondary users, 0.0)                  (experiment, 0.05263157894736842)
#   34                                    (key idea, 0.0)           (nonlinear system, 0.043859649122807015)
#   35                      (multiple primary users, 0.0)         (numerical analysis, 0.043859649122807015)
#   36                               (pus negotiate, 0.0)  (neural network simulation, 0.043859649122807015)
#   37                                    (impulses, 0.0)    (approximation algorithm, 0.043859649122807015)
#   38                          (distributed delays, 0.0)            (convex function, 0.043859649122807015)
#   39                                   (resonance, 0.0)                (ising model, 0.043859649122807015)
#   40                                     (plasmon, 0.0)     (telecommunications link, 0.03508771929824561)
#   41                          (tree rearrangement, 0.0)            (channel capacity, 0.03508771929824561)
#   42                            (nonlinear system, 0.0)                   (algorithm, 0.03508771929824561)
#   43                        (parameter adaptation, 0.0)    (multiple secondary users, 0.03508771929824561)
#   44              (multiple transmitting antennas, 0.0)                    (key idea, 0.03508771929824561)
#   45                       (centralized computing, 0.0)      (multiple primary users, 0.03508771929824561)
#   46                            (mapreduce rounds, 0.0)               (pus negotiate, 0.03508771929824561)
#   47                            (hopfield network, 0.0)                   (resonance, 0.03508771929824561)
#   48                              (leakage delay , 0.0)                     (plasmon, 0.03508771929824561)
#   49                            (spectral leakage, 0.0)          (tree rearrangement, 0.03508771929824561)
#   50                   (stochastic neural network, 0.0)   (stochastic neural network, 0.03508771929824561)
#   51                              (method employs, 0.0)      (low-power broadcasting, 0.03508771929824561)
#   52                                   (s ability, 0.0)  (signal-to-interference-plus-noise ratio, 0.03...
#   53                        (experimental results, 0.0)          (proposed algorithm, 0.03508771929824561)
#   54                              (knowledge base, 0.0)      (differential evolution, 0.03508771929824561)
#   55                  (construct proposal kernels, 0.0)      (multitier architecture, 0.02631578947368421)
#   56                           (general framework, 0.0)              (dependent deep, 0.02631578947368421)
#   57                     (recently andrieu doucet, 0.0)                (network hmms, 0.02631578947368421)
#   58                     (approximation algorithm, 0.0)                (mixture hmms, 0.02631578947368421)
#   59                                (hard problem, 0.0)                    (impulses, 0.02631578947368421)
#   60                       (parallel applications, 0.0)          (distributed delays, 0.02631578947368421)
#   61                            (important factor, 0.0)            (spectral leakage, 0.02631578947368421)
#   62                     (increasingly inadequate, 0.0)  (construct proposal kernels, 0.02631578947368421)
#   63                               (critical role, 0.0)           (general framework, 0.02631578947368421)
#   64                            (topic navigation, 0.0)     (recently andrieu doucet, 0.02631578947368421)
#   65                        (membership structure, 0.0)                (hard problem, 0.02631578947368421)
#   66                       (promising alternative, 0.0)       (parallel applications, 0.02631578947368421)
#   67                  (coherent clusters allowing, 0.0)            (important factor, 0.02631578947368421)
#   68                          (clustering results, 0.0)          (quality of service, 0.02631578947368421)
#   69                                (ranked lists, 0.0)         (software deployment, 0.02631578947368421)
#   70                                   (long list, 0.0)  (discriminatively trained gaussian, 0.02631578...
#   71                             (common strategy, 0.0)  (hopfield-type neural networks, 0.026315789473...
#   72                    (disparate search results, 0.0)             (broadcast delay, 0.02631578947368421)
#   73                              (search engines, 0.0)      (using particle filters, 0.02631578947368421)
#   74              (automatic clustering procedure, 0.0)    (achieve high performance, 0.02631578947368421)
#   75                              (wiki interface, 0.0)                (exponential, 0.017543859649122806)
#   76                    (introduce clusteringwiki, 0.0)            (swarm robotics , 0.017543859649122806)
#   77                              (search results, 0.0)         (self-organization , 0.017543859649122806)
#   78                       (search engine utility, 0.0)            (time complexity, 0.017543859649122806)
#   79                          (clustering divides, 0.0)     (reinforcement learning, 0.017543859649122806)
#   80                         (unprecedented scale, 0.0)       (discrepancy function, 0.017543859649122806)
#   81                   (personalized presentation, 0.0)       (generalization error, 0.017543859649122806)
#   82                     (personalized clustering, 0.0)     (evolutionary algorithm, 0.017543859649122806)
#   83                             (convex function, 0.0)      (centralized computing, 0.017543859649122806)
#   84                                 (ising model, 0.0)           (hopfield network, 0.017543859649122806)
#   85                             (expected spread, 0.0)                  (s ability, 0.017543859649122806)
#   86                      (low-power broadcasting, 0.0)       (experimental results, 0.017543859649122806)
#   87                       (variational principle, 0.0)             (knowledge base, 0.017543859649122806)
#   88                      (support vector machine, 0.0)        (swarm intelligence , 0.017543859649122806)
#   89                 (genetic regulatory networks, 0.0)                (interaction, 0.017543859649122806)
#   90     (signal-to-interference-plus-noise ratio, 0.0)           (autonomous robot, 0.017543859649122806)
#   91                         (swarm intelligence , 0.0)                (maximal set, 0.017543859649122806)
#   92                         (software deployment, 0.0)       (population diversity, 0.017543859649122806)
#   93                                 (interaction, 0.0)             (entity linking, 0.017543859649122806)
#   94                      (queried question based, 0.0)          (checking (action), 0.008771929824561403)
#   95                            (autonomous robot, 0.0)            (question search, 0.008771929824561403)
#   96           (discriminatively trained gaussian, 0.0)       (parameter adaptation, 0.008771929824561403)
#   97                                 (maximal set, 0.0)  (multiple transmitting antennas, 0.00877192982...
#   98                          (proposed algorithm, 0.0)           (mapreduce rounds, 0.008771929824561403)
#   99               (hopfield-type neural networks, 0.0)             (leakage delay , 0.008771929824561403)
#  100          (synchronization (computer science), 0.0)             (method employs, 0.008771929824561403)
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (artificial neural network, 0.021978675436150754)  (artificial neural network, 0.034265409020009296)
#    2  (interference (communication), 0.0207921811873...  (interference (communication), 0.0216016433546...
#    3             (cognitive radio, 0.01890381530293209)            (lyapunov fractal, 0.02146921039111289)
#    4            (lyapunov fractal, 0.01860019471011637)             (cognitive radio, 0.01911837486270912)
#    5  (particle swarm optimization, 0.01675801557800...  (particle swarm optimization, 0.01753457601941...
#    6  (mathematical optimization, 0.014108466650465393)   (linear matrix inequality, 0.015817687809530957)
#    7           (fairness measure, 0.012489806528594702)                 (simulation, 0.014154807277561115)
#    8          (social inequality, 0.011808238455818906)         (numerical analysis, 0.013646844746903882)
#    9                  (experiment, 0.01173919255401861)  (mathematical optimization, 0.012710701167876476)
#   10                  (algorithm, 0.011171403295373295)                 (experiment, 0.011700220336755636)
#   11   (linear matrix inequality, 0.011151475320467574)    (telecommunications link, 0.010422088361682288)
#   12     (differential evolution, 0.010832056542471342)                  (resonance, 0.010381174003801404)
#   13                  (simulation, 0.01010090098218872)                    (plasmon, 0.010381174003801404)
#   14           (nonlinear system, 0.009510722092906026)         (tree rearrangement, 0.010381174003801404)
#   15    (approximation algorithm, 0.009510722092906026)                  (algorithm, 0.010018164342031056)
#   16            (convex function, 0.009510722092906026)           (fairness measure, 0.009546939539496107)
#   17                (ising model, 0.009510722092906026)           (nonlinear system, 0.009488819153137592)
#   18                  (resonance, 0.009429734228313828)    (approximation algorithm, 0.009488819153137592)
#   19                    (plasmon, 0.009429734228313828)            (convex function, 0.009488819153137592)
#   20         (tree rearrangement, 0.009429734228313828)                (ising model, 0.009488819153137592)
#   21            (swarm robotics , 0.009242144177449167)            (swarm robotics , 0.008695652173913044)
#   22         (self-organization , 0.009242144177449167)         (self-organization , 0.008695652173913044)
#   23            (question search, 0.009242144177449167)            (question search, 0.008695652173913044)
#   24       (discrepancy function, 0.009242144177449167)             (dependent deep, 0.008695652173913044)
#   25       (generalization error, 0.009242144177449167)               (network hmms, 0.008695652173913044)
#   26   (multiple secondary users, 0.009242144177449167)               (mixture hmms, 0.008695652173913044)
#   27                   (key idea, 0.009242144177449167)       (discrepancy function, 0.008695652173913044)
#   28     (multiple primary users, 0.009242144177449167)       (generalization error, 0.008695652173913044)
#   29              (pus negotiate, 0.009242144177449167)   (multiple secondary users, 0.008695652173913044)
#   30           (mapreduce rounds, 0.009242144177449167)                   (key idea, 0.008695652173913044)
#   31             (leakage delay , 0.009242144177449167)     (multiple primary users, 0.008695652173913044)
#   32       (experimental results, 0.009242144177449167)              (pus negotiate, 0.008695652173913044)
#   33             (knowledge base, 0.009242144177449167)  (multiple transmitting antennas, 0.00869565217...
#   34  (personalized presentation, 0.009242144177449167)           (mapreduce rounds, 0.008695652173913044)
#   35    (personalized clustering, 0.009242144177449167)             (leakage delay , 0.008695652173913044)
#   36            (expected spread, 0.009242144177449167)             (method employs, 0.008695652173913044)
#   37      (variational principle, 0.009242144177449167)       (experimental results, 0.008695652173913044)
#   38     (support vector machine, 0.009242144177449167)             (knowledge base, 0.008695652173913044)
#   39  (genetic regulatory networks, 0.00924214417744...  (construct proposal kernels, 0.008695652173913...
#   40        (swarm intelligence , 0.009242144177449167)          (general framework, 0.008695652173913044)
#   41     (queried question based, 0.009242144177449167)    (recently andrieu doucet, 0.008695652173913044)
#   42                (maximal set, 0.009242144177449167)               (hard problem, 0.008695652173913044)
#   43         (proposed algorithm, 0.009242144177449167)      (parallel applications, 0.008695652173913044)
#   44            (constant number, 0.009242144177449167)           (important factor, 0.008695652173913044)
#   45  (linear matrix inequality , 0.009242144177449167)            (expected spread, 0.008695652173913044)
#   46             (entity linking, 0.009242144177449167)      (variational principle, 0.008695652173913044)
#   47      (clustering algorithms, 0.009242144177449167)     (support vector machine, 0.008695652173913044)
#   48     (influence maximization, 0.009242144177449167)  (genetic regulatory networks, 0.00869565217391...
#   49                 (inpainting, 0.009242144177449167)        (swarm intelligence , 0.008695652173913044)
#   50            (model selection, 0.009242144177449167)     (queried question based, 0.008695652173913044)
#   51    (gene regulatory network, 0.009242144177449167)  (discriminatively trained gaussian, 0.00869565...
#   52    (increasingly inadequate, 0.009242144177449165)                (maximal set, 0.008695652173913044)
#   53              (critical role, 0.009242144177449165)         (proposed algorithm, 0.008695652173913044)
#   54           (topic navigation, 0.009242144177449165)  (multiple receiving antennas, 0.00869565217391...
#   55       (membership structure, 0.009242144177449165)            (constant number, 0.008695652173913044)
#   56      (promising alternative, 0.009242144177449165)  (linear matrix inequality , 0.008695652173913044)
#   57  (coherent clusters allowing, 0.009242144177449...            (paper describes, 0.008695652173913044)
#   58         (clustering results, 0.009242144177449165)             (entity linking, 0.008695652173913044)
#   59               (ranked lists, 0.009242144177449165)     (using particle filters, 0.008695652173913044)
#   60                  (long list, 0.009242144177449165)   (achieve high performance, 0.008695652173913044)
#   61            (common strategy, 0.009242144177449165)     (influence maximization, 0.008695652173913044)
#   62   (disparate search results, 0.009242144177449165)                 (inpainting, 0.008695652173913044)
#   63             (search engines, 0.009242144177449165)            (model selection, 0.008695652173913044)
#   64  (automatic clustering procedure, 0.00924214417...    (gene regulatory network, 0.008695652173913044)
#   65             (wiki interface, 0.009242144177449165)    (increasingly inadequate, 0.008695652173913037)
#   66   (introduce clusteringwiki, 0.009242144177449165)              (critical role, 0.008695652173913037)
#   67             (search results, 0.009242144177449165)           (topic navigation, 0.008695652173913037)
#   68      (search engine utility, 0.009242144177449165)       (membership structure, 0.008695652173913037)
#   69         (clustering divides, 0.009242144177449165)      (promising alternative, 0.008695652173913037)
#   70        (unprecedented scale, 0.009242144177449165)  (coherent clusters allowing, 0.008695652173913...
#   71               (mixture hmms, 0.009242144177449164)         (clustering results, 0.008695652173913037)
#   72    (recently andrieu doucet, 0.009242144177449164)               (ranked lists, 0.008695652173913037)
#   73           (important factor, 0.009242144177449164)                  (long list, 0.008695652173913037)
#   74  (discriminatively trained gaussian, 0.00924214...            (common strategy, 0.008695652173913037)
#   75     (using particle filters, 0.009242144177449164)   (disparate search results, 0.008695652173913037)
#   76   (achieve high performance, 0.009242144177449164)             (search engines, 0.008695652173913037)
#   77             (dependent deep, 0.009242144177449162)  (automatic clustering procedure, 0.00869565217...
#   78               (network hmms, 0.009242144177449162)             (wiki interface, 0.008695652173913037)
#   79  (construct proposal kernels, 0.009242144177449...   (introduce clusteringwiki, 0.008695652173913037)
#   80          (general framework, 0.009242144177449162)             (search results, 0.008695652173913037)
#   81               (hard problem, 0.009242144177449162)      (search engine utility, 0.008695652173913037)
#   82      (parallel applications, 0.009242144177449162)         (clustering divides, 0.008695652173913037)
#   83           (channel capacity, 0.008749039459422882)        (unprecedented scale, 0.008695652173913037)
#   84  (neural network simulation, 0.008629298352485631)  (personalized presentation, 0.008695652173913037)
#   85     (low-power broadcasting, 0.008593213622259174)    (personalized clustering, 0.008695652173913037)
#   86  (signal-to-interference-plus-noise ratio, 0.00...      (clustering algorithms, 0.008695652173913037)
#   87  (stochastic neural network, 0.008532199640975093)     (differential evolution, 0.008397512203495468)
#   88         (numerical analysis, 0.007902027484085632)          (social inequality, 0.007757532283146365)
#   89         (quality of service, 0.007562439182715253)  (neural network simulation, 0.0074640450695213...
#   90    (multitier architecture, 0.0073861260912350055)      (reinforcement learning, 0.00714690310568645)
#   91       (software deployment, 0.0073861260912350055)          (autonomous robot, 0.0068545454153444985)
#   92           (spectral leakage, 0.006699007734721491)      (low-power broadcasting, 0.00597401540681468)
#   93            (broadcast delay, 0.006699007734721491)  (signal-to-interference-plus-noise ratio, 0.00...
#   94                (interaction, 0.006261180881711397)           (channel capacity, 0.005811917901361293)
#   95    (telecommunications link, 0.006217883476549502)         (quality of service, 0.005513439369982975)
#   96                  (s ability, 0.005951535015102375)     (multitier architecture, 0.005312924869492328)
#   97       (population diversity, 0.005951535015102375)        (software deployment, 0.005312924869492328)
#   98           (autonomous robot, 0.005856693488865245)  (stochastic neural network, 0.005184600810006256)
#   99     (reinforcement learning, 0.005445872913610818)           (spectral leakage, 0.005007209590720291)
#  100      (evolutionary algorithm, 0.00534913297383726)            (broadcast delay, 0.005007209590720291)

# %% [markdown]
# ## Year 2012

# %%
#View tables for year 2012
tables_metrics_view(2012)
# Out:
# Year: 2012
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1   (mathematical optimization, 0.11637313860252005)    (mathematical optimization, 0.1958762886597938)
#    2                  (algorithm, 0.057488545246277195)                   (algorithm, 0.18556701030927836)
#    3  (interference (communication), 0.0400558419243...                  (experiment, 0.15463917525773196)
#    4                 (simulation, 0.030963631156930134)        (fuzzy control system, 0.14432989690721648)
#    5                  (experiment, 0.01800544100801833)  (interference (communication), 0.1443298969072...
#    6       (fuzzy control system, 0.015607101947308131)             (cognitive radio, 0.14432989690721648)
#    7  (artificial neural network, 0.011060996563573884)   (artificial neural network, 0.12371134020618557)
#    8            (cognitive radio, 0.004975658648339061)                  (simulation, 0.12371134020618557)
#    9   (telecommunications link, 0.0011812714776632302)            (approach improves, 0.1134020618556701)
#   10    (evolutionary algorithm, 0.0007875143184421534)               (latent factors, 0.1134020618556701)
#   11  (neural network simulation, 0.0003221649484536...  (exploit parallel architectures, 0.11340206185...
#   12                   (dropout (neural networks), 0.0)           (nips 2011 workshop, 0.1134020618556701)
#   13                                 (overfitting, 0.0)                (sparse coding, 0.1134020618556701)
#   14                                 (data mining, 0.0)  (learning hierarchical models, 0.1134020618556...
#   15                         (supervised learning, 0.0)  (transfer learning challenge, 0.1134020618556701)
#   16                                (missing data, 0.0)            (training set size, 0.1134020618556701)
#   17                              (search results, 0.0)  (supervised learning capabilities, 0.113402061...
#   18                    (recurrent neural network, 0.0)        (dramatically increase, 0.1134020618556701)
#   19                           (approach improves, 0.0)                   (prior work, 0.1134020618556701)
#   20                              (latent factors, 0.0)                 (factor model, 0.1134020618556701)
#   21              (exploit parallel architectures, 0.0)       (premature convergence, 0.10309278350515463)
#   22                          (nips 2011 workshop, 0.0)                 (computation, 0.10309278350515463)
#   23                               (sparse coding, 0.0)           (genetic algorithm, 0.10309278350515463)
#   24                (learning hierarchical models, 0.0)  (combinatorial optimization, 0.10309278350515463)
#   25                 (transfer learning challenge, 0.0)                 (fuzzy logic, 0.10309278350515463)
#   26                           (training set size, 0.0)            (genetic operator, 0.10309278350515463)
#   27            (supervised learning capabilities, 0.0)            (knapsack problem, 0.10309278350515463)
#   28                       (dramatically increase, 0.0)            (inference engine, 0.10309278350515463)
#   29                                  (prior work, 0.0)            (machine learning, 0.08247422680412371)
#   30                       (benchmark (computing), 0.0)                 (transmitter, 0.08247422680412371)
#   31                 (particle swarm optimization, 0.0)               (sparse matrix, 0.08247422680412371)
#   32                       (premature convergence, 0.0)                  (q-learning, 0.08247422680412371)
#   33                             (radio frequency, 0.0)  (signal-to-interference-plus-noise ratio, 0.08...
#   34           (receiver operating characteristic, 0.0)              (frequency band, 0.08247422680412371)
#   35                     (cyclostationary process, 0.0)             (radio frequency, 0.07216494845360824)
#   36                            (autonomous robot, 0.0)  (receiver operating characteristic, 0.07216494...
#   37                              (nodes organize, 0.0)     (cyclostationary process, 0.07216494845360824)
#   38                  (main organizing principles, 0.0)            (autonomous robot, 0.07216494845360824)
#   39                              (labeled ground, 0.0)                   (cognition, 0.07216494845360824)
#   40                         (network communities, 0.0)                 (data mining, 0.05154639175257732)
#   41                                 (computation, 0.0)         (supervised learning, 0.05154639175257732)
#   42                          (numerical analysis, 0.0)                (missing data, 0.05154639175257732)
#   43                                    (gradient, 0.0)     (telecommunications link, 0.05154639175257732)
#   44                           (genetic algorithm, 0.0)                (preprocessor, 0.05154639175257732)
#   45                               (deep learning, 0.0)   (neural network simulation, 0.05154639175257732)
#   46                    (linear matrix inequality, 0.0)  (synchronization (computer science), 0.0412371...
#   47                  (combinatorial optimization, 0.0)  (sampling - surgical action, 0.041237113402061...
#   48                             (paper describes, 0.0)  (sampling (signal processing), 0.0412371134020...
#   49               (cross-validation (statistics), 0.0)     (evolutionary algorithm, 0.041237113402061855)
#   50                          (parallel computing, 0.0)  (dropout (neural networks), 0.030927835051546393)
#   51                           (diffusion network, 0.0)                (overfitting, 0.030927835051546393)
#   52                                 (time delay , 0.0)      (benchmark (computing), 0.030927835051546393)
#   53                        (optimization problem, 0.0)  (particle swarm optimization, 0.03092783505154...
#   54                         (complex simple mcmc, 0.0)             (nodes organize, 0.030927835051546393)
#   55                           (extract relations, 0.0)  (main organizing principles, 0.030927835051546...
#   56                     (unsupervised algorithms, 0.0)        (network communities, 0.030927835051546393)
#   57          (synchronization (computer science), 0.0)         (numerical analysis, 0.030927835051546393)
#   58                  (sampling - surgical action, 0.0)   (linear matrix inequality, 0.030927835051546393)
#   59                (sampling (signal processing), 0.0)            (coexist (image), 0.030927835051546393)
#   60                   (recurrent neural networks, 0.0)            (neural networks, 0.030927835051546393)
#   61                             (coexist (image), 0.0)  (optical character recognition, 0.030927835051...
#   62                            (machine learning, 0.0)                 (randomness, 0.030927835051546393)
#   63                                 (transmitter, 0.0)                  (test data, 0.030927835051546393)
#   64                               (sparse matrix, 0.0)          (social inequality, 0.030927835051546393)
#   65                                  (q-learning, 0.0)     (reinforcement learning, 0.030927835051546393)
#   66     (signal-to-interference-plus-noise ratio, 0.0)    (densely linked clusters, 0.030927835051546393)
#   67                                       (class, 0.0)        (software deployment, 0.030927835051546393)
#   68                                 (data models, 0.0)    (neural network software, 0.030927835051546393)
#   69                                 (fuzzy logic, 0.0)   (recurrent neural network, 0.020618556701030927)
#   70                            (genetic operator, 0.0)       (optimization problem, 0.020618556701030927)
#   71                             (neural networks, 0.0)          (extract relations, 0.020618556701030927)
#   72               (optical character recognition, 0.0)    (unsupervised algorithms, 0.020618556701030927)
#   73                                  (randomness, 0.0)                      (class, 0.020618556701030927)
#   74                            (knapsack problem, 0.0)  (expectation–maximization algorithm, 0.0206185...
#   75                            (inference engine, 0.0)          (tagging arguments, 0.020618556701030927)
#   76                                   (test data, 0.0)              (trees (plant), 0.020618556701030927)
#   77                                (preprocessor, 0.0)             (search results, 0.010309278350515464)
#   78                               (user behavior, 0.0)             (labeled ground, 0.010309278350515464)
#   79                           (social inequality, 0.0)                   (gradient, 0.010309278350515464)
#   80                      (reinforcement learning, 0.0)              (deep learning, 0.010309278350515464)
#   81                                (factor model, 0.0)            (paper describes, 0.010309278350515464)
#   82                                   (cognition, 0.0)  (cross-validation (statistics), 0.010309278350...
#   83                     (densely linked clusters, 0.0)         (parallel computing, 0.010309278350515464)
#   84                                  (truth data, 0.0)          (diffusion network, 0.010309278350515464)
#   85                          (linear combination, 0.0)                (time delay , 0.010309278350515464)
#   86                    (graphics processing unit, 0.0)        (complex simple mcmc, 0.010309278350515464)
#   87          (expectation–maximization algorithm, 0.0)  (recurrent neural networks, 0.010309278350515464)
#   88           (efficient approximation algorithm, 0.0)                (data models, 0.010309278350515464)
#   89                            (neural networks , 0.0)              (user behavior, 0.010309278350515464)
#   90                                (draw samples, 0.0)                 (truth data, 0.010309278350515464)
#   91                             (time complexity, 0.0)         (linear combination, 0.010309278350515464)
#   92                           (tagging arguments, 0.0)   (graphics processing unit, 0.010309278350515464)
#   93                                   (memristor, 0.0)  (efficient approximation algorithm, 0.01030927...
#   94                              (frequency band, 0.0)           (neural networks , 0.010309278350515464)
#   95                         (software deployment, 0.0)               (draw samples, 0.010309278350515464)
#   96                           (predictive models, 0.0)            (time complexity, 0.010309278350515464)
#   97                     (neural network software, 0.0)                  (memristor, 0.010309278350515464)
#   98                               (trees (plant), 0.0)          (predictive models, 0.010309278350515464)
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (artificial neural network, 0.029347219389499486)  (artificial neural network, 0.030592899866195705)
#    2  (mathematical optimization, 0.025349110986967797)                  (algorithm, 0.025929285033382734)
#    3                   (algorithm, 0.02460146221491121)  (mathematical optimization, 0.022927996060162187)
#    4                 (experiment, 0.018162424588452925)            (cognitive radio, 0.020162980474925325)
#    5  (interference (communication), 0.0178010619858...                 (experiment, 0.020064785556657538)
#    6            (cognitive radio, 0.016930354963083233)                  (simulation, 0.01995504805391505)
#    7                 (simulation, 0.016814491417594744)  (interference (communication), 0.0190680913312...
#    8       (fuzzy control system, 0.016555135679790438)        (fuzzy control system, 0.01892737391988371)
#    9           (knapsack problem, 0.011840362503731433)  (neural network simulation, 0.015626158196051777)
#   10  (combinatorial optimization, 0.011840362503731...            (radio frequency, 0.013619014557385466)
#   11                (fuzzy logic, 0.011840362503731432)  (receiver operating characteristic, 0.01361901...
#   12           (genetic operator, 0.011840362503731432)    (cyclostationary process, 0.013619014557385466)
#   13           (inference engine, 0.011840362503731432)           (autonomous robot, 0.013619014557385466)
#   14       (premature convergence, 0.01184036250373143)                  (cognition, 0.013619014557385466)
#   15                 (computation, 0.01184036250373143)    (telecommunications link, 0.011599246839122397)
#   16           (genetic algorithm, 0.01184036250373143)                (data mining, 0.011077037070345765)
#   17  (neural network simulation, 0.011669008931291344)        (supervised learning, 0.011077037070345765)
#   18                (transmitter, 0.010998511374478843)               (missing data, 0.011077037070345765)
#   19              (sparse matrix, 0.010998511374478843)               (preprocessor, 0.011077037070345765)
#   20                 (q-learning, 0.010998511374478843)  (synchronization (computer science), 0.0106226...
#   21  (signal-to-interference-plus-noise ratio, 0.01...  (sampling - surgical action, 0.010622630024861...
#   22             (frequency band, 0.010998511374478843)  (sampling (signal processing), 0.0106226300248...
#   23            (machine learning, 0.01036780270019707)                 (prior work, 0.010204081632653064)
#   24  (synchronization (computer science), 0.0102672...             (search results, 0.010204081632653062)
#   25  (sampling - surgical action, 0.010267226115291...         (nips 2011 workshop, 0.010204081632653062)
#   26  (sampling (signal processing), 0.0102672261152...              (sparse coding, 0.010204081632653062)
#   27                 (prior work, 0.010204081632653064)      (dramatically increase, 0.010204081632653062)
#   28             (search results, 0.010204081632653062)             (labeled ground, 0.010204081632653062)
#   29         (nips 2011 workshop, 0.010204081632653062)            (paper describes, 0.010204081632653062)
#   30              (sparse coding, 0.010204081632653062)         (parallel computing, 0.010204081632653062)
#   31      (dramatically increase, 0.010204081632653062)          (diffusion network, 0.010204081632653062)
#   32             (labeled ground, 0.010204081632653062)                (time delay , 0.010204081632653062)
#   33            (paper describes, 0.010204081632653062)        (complex simple mcmc, 0.010204081632653062)
#   34         (parallel computing, 0.010204081632653062)          (extract relations, 0.010204081632653062)
#   35          (diffusion network, 0.010204081632653062)    (unsupervised algorithms, 0.010204081632653062)
#   36                (time delay , 0.010204081632653062)  (recurrent neural networks, 0.010204081632653062)
#   37        (complex simple mcmc, 0.010204081632653062)                (data models, 0.010204081632653062)
#   38          (extract relations, 0.010204081632653062)              (user behavior, 0.010204081632653062)
#   39    (unsupervised algorithms, 0.010204081632653062)               (factor model, 0.010204081632653062)
#   40  (recurrent neural networks, 0.010204081632653062)    (densely linked clusters, 0.010204081632653062)
#   41                (data models, 0.010204081632653062)                 (truth data, 0.010204081632653062)
#   42              (user behavior, 0.010204081632653062)         (linear combination, 0.010204081632653062)
#   43               (factor model, 0.010204081632653062)   (graphics processing unit, 0.010204081632653062)
#   44    (densely linked clusters, 0.010204081632653062)  (efficient approximation algorithm, 0.01020408...
#   45                 (truth data, 0.010204081632653062)           (neural networks , 0.010204081632653062)
#   46         (linear combination, 0.010204081632653062)               (draw samples, 0.010204081632653062)
#   47   (graphics processing unit, 0.010204081632653062)          (tagging arguments, 0.010204081632653062)
#   48  (efficient approximation algorithm, 0.01020408...                  (memristor, 0.010204081632653062)
#   49           (neural networks , 0.010204081632653062)          (predictive models, 0.010204081632653062)
#   50               (draw samples, 0.010204081632653062)    (neural network software, 0.010204081632653062)
#   51          (tagging arguments, 0.010204081632653062)           (approach improves, 0.01020408163265306)
#   52                  (memristor, 0.010204081632653062)              (latent factors, 0.01020408163265306)
#   53          (predictive models, 0.010204081632653062)  (exploit parallel architectures, 0.01020408163...
#   54    (neural network software, 0.010204081632653062)  (learning hierarchical models, 0.0102040816326...
#   55           (approach improves, 0.01020408163265306)  (transfer learning challenge, 0.01020408163265...
#   56              (latent factors, 0.01020408163265306)           (training set size, 0.01020408163265306)
#   57  (exploit parallel architectures, 0.01020408163...  (supervised learning capabilities, 0.010204081...
#   58  (learning hierarchical models, 0.0102040816326...              (nodes organize, 0.01020408163265306)
#   59  (transfer learning challenge, 0.01020408163265...  (main organizing principles, 0.01020408163265306)
#   60           (training set size, 0.01020408163265306)         (network communities, 0.01020408163265306)
#   61  (supervised learning capabilities, 0.010204081...             (neural networks, 0.01020408163265306)
#   62              (nodes organize, 0.01020408163265306)  (optical character recognition, 0.010204081632...
#   63  (main organizing principles, 0.01020408163265306)                  (randomness, 0.01020408163265306)
#   64         (network communities, 0.01020408163265306)      (premature convergence, 0.009283070539805365)
#   65             (neural networks, 0.01020408163265306)                (computation, 0.009283070539805365)
#   66  (optical character recognition, 0.010204081632...          (genetic algorithm, 0.009283070539805365)
#   67                  (randomness, 0.01020408163265306)  (combinatorial optimization, 0.009283070539805...
#   68            (radio frequency, 0.010126801224399356)                (fuzzy logic, 0.009283070539805365)
#   69  (receiver operating characteristic, 0.01012680...           (genetic operator, 0.009283070539805365)
#   70    (cyclostationary process, 0.010126801224399356)           (knapsack problem, 0.009283070539805365)
#   71           (autonomous robot, 0.010126801224399356)           (inference engine, 0.009283070539805365)
#   72                  (cognition, 0.010126801224399355)  (dropout (neural networks), 0.008987777367554028)
#   73   (dropout (neural networks), 0.00853854691774412)                  (test data, 0.008987777367554028)
#   74                 (overfitting, 0.00853854691774412)                (overfitting, 0.008987777367554026)
#   75          (numerical analysis, 0.00853854691774412)           (machine learning, 0.007929842971946727)
#   76    (linear matrix inequality, 0.00853854691774412)            (coexist (image), 0.007911788979400224)
#   77                   (test data, 0.00853854691774412)     (reinforcement learning, 0.007911788979400224)
#   78           (social inequality, 0.00853854691774412)               (transmitter, 0.0072593207836379285)
#   79    (telecommunications link, 0.007667982046984956)              (sparse matrix, 0.007259320783637928)
#   80     (evolutionary algorithm, 0.007643813668868799)                 (q-learning, 0.007259320783637928)
#   81                (data mining, 0.007345135121899005)  (signal-to-interference-plus-noise ratio, 0.00...
#   82        (supervised learning, 0.007345135121899005)             (frequency band, 0.007259320783637928)
#   83               (missing data, 0.007345135121899005)          (numerical analysis, 0.00626064521480698)
#   84               (preprocessor, 0.007345135121899005)    (linear matrix inequality, 0.00626064521480698)
#   85             (coexist (image), 0.00632658052575819)           (social inequality, 0.00626064521480698)
#   86      (reinforcement learning, 0.00632658052575819)    (recurrent neural network, 0.00610823123249941)
#   87   (recurrent neural network, 0.005904002211550154)      (benchmark (computing), 0.005809548578283914)
#   88        (software deployment, 0.005832899611744088)  (particle swarm optimization, 0.00580954857828...
#   89      (benchmark (computing), 0.005688770276901572)     (evolutionary algorithm, 0.005584962818665007)
#   90  (particle swarm optimization, 0.00568877027690...       (optimization problem, 0.004277461359499069)
#   91                     (class, 0.0048336186093611904)  (expectation–maximization algorithm, 0.0042774...
#   92             (trees (plant), 0.0048336186093611904)                     (class, 0.0037889716530370033)
#   93       (optimization problem, 0.004744071134388556)             (trees (plant), 0.0037889716530370033)
#   94  (expectation–maximization algorithm, 0.0047440...        (software deployment, 0.003516023193558763)
#   95           (time complexity, 0.0036998708398088068)           (time complexity, 0.0027126141080753385)
#   96  (cross-validation (statistics), 0.002830130374...                  (gradient, 0.0024589618193826693)
#   97             (deep learning, 0.0027791781401967346)             (deep learning, 0.0021787542263991865)
#   98                  (gradient, 0.0027276588534397373)  (cross-validation (statistics), 0.002136309092...

# %% [markdown]
# ## Year 2013

# %%
#View tables for year 2013
tables_metrics_view(2013)
# Out:
# Year: 2013
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1            (lyapunov fractal, 0.08831479113072525)                   (simulation, 0.1242603550295858)
#    2                  (simulation, 0.08475669629515782)            (lyapunov fractal, 0.11834319526627218)
#    3    (mathematical optimization, 0.0397774081840016)     (approximation algorithm, 0.10059171597633136)
#    4                  (algorithm, 0.039205544150599105)            (nonlinear system, 0.09467455621301775)
#    5  (sampling (signal processing), 0.0381933847593...   (mathematical optimization, 0.08284023668639053)
#    6  (artificial neural network, 0.035929058731256514)                   (algorithm, 0.08284023668639053)
#    7     (approximation algorithm, 0.02509220785319687)            (numerical method, 0.08284023668639053)
#    8           (numerical method, 0.021058299148958484)                  (randomness, 0.08284023668639053)
#    9     (reinforcement learning, 0.016996739524212053)      (christopher d. manning, 0.08284023668639053)
#   10                 (randomness, 0.016906170752324597)                (andrew y. ng, 0.08284023668639053)
#   11           (nonlinear system, 0.012060177307430054)              (richard socher, 0.08284023668639053)
#   12                 (q-learning, 0.010183955238900299)               (tomas mikolov, 0.08284023668639053)
#   13         (mean squared error, 0.008593970132431671)   (artificial neural network, 0.07692307692307693)
#   14                  (iteration, 0.008571663379355688)          (mean squared error, 0.07692307692307693)
#   15        (hybrid optimization, 0.006977149834292692)  (synchronization (computer science), 0.0710059...
#   16          (social inequality, 0.006595968134429674)  (sampling (signal processing), 0.0650887573964...
#   17         (numerical analysis, 0.006407908330985253)        (bernoulli polynomials, 0.0650887573964497)
#   18          (self-organization, 0.006326312576312573)             (complex networks, 0.0650887573964497)
#   19     (organizing (structure), 0.006326312576312573)                    (couplings, 0.0650887573964497)
#   20              (manufacturing, 0.005846717385178923)         (stochastic processes, 0.0650887573964497)
#   21             (knowledge base, 0.005776275007044238)              (synchronization, 0.0650887573964497)
#   22  (particle swarm optimization, 0.00577627500704...                       (vertex, 0.0650887573964497)
#   23  (recurrent neural networks, 0.005776275007044238)                  (probability, 0.0650887573964497)
#   24             (word embedding, 0.005776275007044238)                     (switches, 0.0650887573964497)
#   25  (synchronization (computer science), 0.0028176...                 (lukás burget, 0.0650887573964497)
#   26  (neural network simulation, 0.002588757396449704)                  (wen-tau yih, 0.0650887573964497)
#   27  (sampling - surgical action, 0.002585997640942...                 (yee whye teh, 0.0650887573964497)
#   28         (optimization problem, 0.0025292168149311)               (geoffrey zweig, 0.0650887573964497)
#   29                (throughput, 0.0010964691596559728)              (stefan kombrink, 0.0650887573964497)
#   30     (variational principle, 0.0008453085376162299)              (peter d. turney, 0.0650887573964497)
#   31       (convex optimization, 0.0007232084155161079)                  (andriy mnih, 0.0650887573964497)
#   32    (telecommunications link, 0.000614525889251164)                 (jan cernocký, 0.0650887573964497)
#   33  (interference (communication), 0.0005990956540...           (collocation method, 0.0650887573964497)
#   34   (christopher d. manning, 0.00042265426880811494)  (gauss–kronrod quadrature formula, 0.065088757...
#   35             (andrew y. ng, 0.00042265426880811494)           (algebraic equation, 0.0650887573964497)
#   36           (richard socher, 0.00042265426880811494)        (newton–cotes formulas, 0.0650887573964497)
#   37            (tomas mikolov, 0.00042265426880811494)      (navier–stokes equations, 0.0650887573964497)
#   38            (dynamic multi, 0.00021132713440405747)  (error analysis (mathematics), 0.0650887573964...
#   39                    (linear matrix inequality, 0.0)                  (coefficient, 0.0650887573964497)
#   40                  (linguistic frame semantics, 0.0)                     (b-spline, 0.0650887573964497)
#   41                             (ontology design, 0.0)             (quintic function, 0.0650887573964497)
#   42                            (ready ontologies, 0.0)                   (iteration, 0.05325443786982249)
#   43                              (novel approach, 0.0)  (linguistic frame semantics, 0.04142011834319526)
#   44                             (converting text, 0.0)             (ontology design, 0.04142011834319526)
#   45                              (quality linked, 0.0)            (ready ontologies, 0.04142011834319526)
#   46                             (acceptable time, 0.0)              (novel approach, 0.04142011834319526)
#   47                              (taguchi method, 0.0)             (converting text, 0.04142011834319526)
#   48                       (frank–wolfe algorithm, 0.0)              (quality linked, 0.04142011834319526)
#   49                             (cognitive radio, 0.0)             (acceptable time, 0.04142011834319526)
#   50                      (information extraction, 0.0)     (telecommunications link, 0.04142011834319526)
#   51                                (named entity, 0.0)  (sampling - surgical action, 0.04142011834319526)
#   52                                   (wikipedia, 0.0)       (variational principle, 0.04142011834319526)
#   53                            (operational laws, 0.0)           (social inequality, 0.04142011834319526)
#   54                        (single solution does, 0.0)    (ontology design patterns, 0.04142011834319526)
#   55                      (objective optimisation, 0.0)          (numerical analysis, 0.03550295857988166)
#   56                         (pythagorean theorem, 0.0)                  (throughput, 0.03550295857988166)
#   57                                (related idea, 0.0)          (gregory s. corrado, 0.03550295857988166)
#   58                       (benchmark (computing), 0.0)                (jeffrey dean, 0.03550295857988166)
#   59                       (cell (microprocessor), 0.0)                    (kai chen, 0.03550295857988166)
#   60                                   (batteries, 0.0)           (self-organization, 0.03550295857988166)
#   61                               (deep learning, 0.0)      (organizing (structure), 0.03550295857988166)
#   62                       (combining game theory, 0.0)  (interference (communication), 0.0355029585798...
#   63                         (stochastic learning, 0.0)                  (q-learning, 0.03550295857988166)
#   64                     (tier femtocell networks, 0.0)   (linear matrix inequality, 0.029585798816568046)
#   65                               (failure cause, 0.0)        (convex optimization, 0.029585798816568046)
#   66                       (bernoulli polynomials, 0.0)     (reinforcement learning, 0.029585798816568046)
#   67                            (complex networks, 0.0)        (hybrid optimization, 0.029585798816568046)
#   68                                   (couplings, 0.0)       (data synchronization, 0.029585798816568046)
#   69                        (stochastic processes, 0.0)        (dynamic programming, 0.029585798816568046)
#   70                             (synchronization, 0.0)            (neural networks, 0.029585798816568046)
#   71                                      (vertex, 0.0)              (manufacturing, 0.023668639053254437)
#   72                                 (probability, 0.0)      (frank–wolfe algorithm, 0.023668639053254437)
#   73                                    (switches, 0.0)      (cell (microprocessor), 0.023668639053254437)
#   74                     (partitioning algorithms, 0.0)  (recurrent neural networks, 0.023668639053254437)
#   75                          (coordinate descent, 0.0)          (statistical model, 0.023668639053254437)
#   76                                (times ascent, 0.0)          (boltzmann machine, 0.023668639053254437)
#   77                 (stochastic gradient descent, 0.0)                        (dbm, 0.023668639053254437)
#   78                                 (performance, 0.0)                (duality gap, 0.023668639053254437)
#   79                     (unmanned aerial vehicle, 0.0)  (neural network simulation, 0.023668639053254437)
#   80                         (jensen's inequality, 0.0)           (greedy algorithm, 0.023668639053254437)
#   81                           (hammerstein model, 0.0)              (knowledge base, 0.01775147928994083)
#   82                                 (space model, 0.0)      (information extraction, 0.01775147928994083)
#   83                            (image resolution, 0.0)                (named entity, 0.01775147928994083)
#   84                                      (kinect, 0.0)                   (wikipedia, 0.01775147928994083)
#   85                        (data synchronization, 0.0)  (particle swarm optimization, 0.01775147928994...
#   86                    (recurrent neural network, 0.0)       (benchmark (computing), 0.01775147928994083)
#   87              (block cipher mode of operation, 0.0)       (combining game theory, 0.01775147928994083)
#   88                                    (big data, 0.0)         (stochastic learning, 0.01775147928994083)
#   89                        (programming paradigm, 0.0)     (tier femtocell networks, 0.01775147928994083)
#   90                 (minimally trained algorithm, 0.0)          (coordinate descent, 0.01775147928994083)
#   91                             (agents differed, 0.0)                (times ascent, 0.01775147928994083)
#   92                           (consensus problem, 0.0)  (stochastic gradient descent, 0.01775147928994...
#   93                            (bayesian network, 0.0)    (recurrent neural network, 0.01775147928994083)
#   94                      (calculus of variations, 0.0)            (bayesian network, 0.01775147928994083)
#   95                   (dropout (neural networks), 0.0)      (calculus of variations, 0.01775147928994083)
#   96                (convolutional neural network, 0.0)   (dropout (neural networks), 0.01775147928994083)
#   97                          (gregory s. corrado, 0.0)  (convolutional neural network, 0.0177514792899...
#   98                                (jeffrey dean, 0.0)                  (experiment, 0.01775147928994083)
#   99                                    (kai chen, 0.0)   (semi-structured resources, 0.01775147928994083)
#  100                         (dynamic programming, 0.0)               (dynamic multi, 0.01775147928994083)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1                 (simulation, 0.019190724958348723)                  (algorithm, 0.018935920217754938)
#    2                  (algorithm, 0.016447469201055036)                  (simulation, 0.01889519376186359)
#    3           (lyapunov fractal, 0.014699002202177194)  (mathematical optimization, 0.018708760519057354)
#    4  (artificial neural network, 0.014221206740629034)  (artificial neural network, 0.016404181814206383)
#    5  (mathematical optimization, 0.013880506458186562)  (sampling (signal processing), 0.0156523869088...
#    6              (dynamic multi, 0.011552375025920353)           (lyapunov fractal, 0.015524069167882994)
#    7    (approximation algorithm, 0.011383954306556322)  (sampling - surgical action, 0.011802431980856...
#    8  (sampling (signal processing), 0.0107818645653...              (dynamic multi, 0.011322818593368747)
#    9           (nonlinear system, 0.010383985244405538)    (approximation algorithm, 0.010951833993225428)
#   10                 (randomness, 0.010229998396127225)           (social inequality, 0.01059117738847039)
#   11      (variational principle, 0.010014251740631074)            (nonlinear system, 0.01028757203867781)
#   12         (mean squared error, 0.009430517736053459)        (variational principle, 0.0101673896509398)
#   13           (numerical method, 0.009115738549882254)                 (randomness, 0.009274528171090438)
#   14                  (iteration, 0.008334513176474533)         (mean squared error, 0.008756421426794846)
#   15  (synchronization (computer science), 0.0081784...   (linear matrix inequality, 0.008229036587354667)
#   16          (social inequality, 0.007660696931062714)        (data synchronization, 0.00799317192965975)
#   17             (richard socher, 0.007631186744132829)           (numerical method, 0.007849586596050272)
#   18     (christopher d. manning, 0.007631186744132828)  (synchronization (computer science), 0.0075905...
#   19               (andrew y. ng, 0.007631186744132828)    (christopher d. manning, 0.0075845502239630085)
#   20              (tomas mikolov, 0.007631186744132828)              (andrew y. ng, 0.0075845502239630085)
#   21     (telecommunications link, 0.00742744063584195)            (richard socher, 0.0075845502239630085)
#   22         (hybrid optimization, 0.00737513743914003)             (tomas mikolov, 0.0075845502239630085)
#   23      (bernoulli polynomials, 0.007302551298781692)    (reinforcement learning, 0.0071489594705919386)
#   24           (complex networks, 0.007302551298781692)          (self-organization, 0.006830479147801315)
#   25                  (couplings, 0.007302551298781692)     (organizing (structure), 0.006830479147801314)
#   26       (stochastic processes, 0.007302551298781691)                  (iteration, 0.006573036182121756)
#   27            (synchronization, 0.007302551298781691)        (convex optimization, 0.006513981851980784)
#   28                     (vertex, 0.007302551298781691)      (bernoulli polynomials, 0.006500105815470433)
#   29                (probability, 0.007302551298781691)           (complex networks, 0.006500105815470433)
#   30                   (switches, 0.007302551298781691)                  (couplings, 0.006500105815470433)
#   31  (sampling - surgical action, 0.006982721772756...       (stochastic processes, 0.006500105815470433)
#   32         (collocation method, 0.006866345898654564)            (synchronization, 0.006500105815470433)
#   33  (gauss–kronrod quadrature formula, 0.006866345...                     (vertex, 0.006500105815470433)
#   34         (algebraic equation, 0.006866345898654564)                (probability, 0.006500105815470433)
#   35      (newton–cotes formulas, 0.006866345898654563)                   (switches, 0.006500105815470433)
#   36    (navier–stokes equations, 0.006866345898654563)               (lukás burget, 0.006415615172878908)
#   37  (error analysis (mathematics), 0.0068663458986...                (wen-tau yih, 0.006415615172878908)
#   38                (coefficient, 0.006866345898654563)               (yee whye teh, 0.006415615172878908)
#   39                   (b-spline, 0.006866345898654563)             (geoffrey zweig, 0.006415615172878908)
#   40           (quintic function, 0.006866345898654563)            (stefan kombrink, 0.006415615172878908)
#   41          (self-organization, 0.006526495135725944)            (peter d. turney, 0.006415615172878908)
#   42     (organizing (structure), 0.006526495135725944)                (andriy mnih, 0.006415615172878908)
#   43              (manufacturing, 0.006494847672229613)               (jan cernocký, 0.006415615172878908)
#   44  (interference (communication), 0.0062096894082...         (collocation method, 0.006114400546140597)
#   45     (reinforcement learning, 0.006163632608016344)  (gauss–kronrod quadrature formula, 0.006114400...
#   46                 (throughput, 0.006134748813974655)         (algebraic equation, 0.006114400546140597)
#   47             (knowledge base, 0.006129091112557122)      (newton–cotes formulas, 0.006114400546140597)
#   48   (recurrent neural networks, 0.00606893263100287)    (navier–stokes equations, 0.006114400546140597)
#   49        (pythagorean theorem, 0.006002400960384154)  (error analysis (mathematics), 0.0061144005461...
#   50               (related idea, 0.006002400960384154)                (coefficient, 0.006114400546140596)
#   51                  (batteries, 0.006002400960384154)                   (b-spline, 0.006114400546140596)
#   52              (failure cause, 0.006002400960384154)           (quintic function, 0.006114400546140596)
#   53    (partitioning algorithms, 0.006002400960384154)   (telecommunications link, 0.0061125689855905645)
#   54          (hammerstein model, 0.006002400960384154)        (hybrid optimization, 0.005924015124016564)
#   55                (space model, 0.006002400960384154)  (linguistic frame semantics, 0.005882352941176...
#   56           (image resolution, 0.006002400960384154)           (ontology design, 0.0058823529411764705)
#   57                     (kinect, 0.006002400960384154)          (ready ontologies, 0.0058823529411764705)
#   58                   (big data, 0.006002400960384154)            (novel approach, 0.0058823529411764705)
#   59  (minimally trained algorithm, 0.00600240096038...           (converting text, 0.0058823529411764705)
#   60            (agents differed, 0.006002400960384154)            (quality linked, 0.0058823529411764705)
#   61          (consensus problem, 0.006002400960384154)           (acceptable time, 0.0058823529411764705)
#   62  (algorithm presented focuses, 0.00600240096038...          (operational laws, 0.0058823529411764705)
#   63          (3d reconstruction, 0.006002400960384154)       (pythagorean theorem, 0.0058823529411764705)
#   64            (images captured, 0.006002400960384154)              (related idea, 0.0058823529411764705)
#   65  (extreme lighting conditions, 0.00600240096038...                 (batteries, 0.0058823529411764705)
#   66            (social networks, 0.006002400960384154)             (failure cause, 0.0058823529411764705)
#   67     (empirical correlations, 0.006002400960384154)   (partitioning algorithms, 0.0058823529411764705)
#   68           (computer program, 0.006002400960384154)   (unmanned aerial vehicle, 0.0058823529411764705)
#   69            (fault detection, 0.006002400960384154)         (hammerstein model, 0.0058823529411764705)
#   70  (pythagorean membership grades, 0.006002400960...               (space model, 0.0058823529411764705)
#   71  (battery charge measurement, 0.006002400960384...          (image resolution, 0.0058823529411764705)
#   72  (failure mode and effects analysis, 0.00600240...                    (kinect, 0.0058823529411764705)
#   73              (visualization, 0.006002400960384154)                  (big data, 0.0058823529411764705)
#   74             (linear dynamic, 0.006002400960384154)  (minimally trained algorithm, 0.00588235294117...
#   75            (computer vision, 0.006002400960384154)           (agents differed, 0.0058823529411764705)
#   76                (future work, 0.006002400960384154)         (consensus problem, 0.0058823529411764705)
#   77     (syndromic surveillance, 0.006002400960384154)  (algorithm presented focuses, 0.00588235294117...
#   78   (time heterogeneous multi, 0.006002400960384154)         (3d reconstruction, 0.0058823529411764705)
#   79       (single moving camera, 0.006002400960384154)           (images captured, 0.0058823529411764705)
#   80             (visual quality, 0.006002400960384154)  (extreme lighting conditions, 0.00588235294117...
#   81     (online social networks, 0.006002400960384154)           (social networks, 0.0058823529411764705)
#   82     (support vector machine, 0.006002400960384154)    (empirical correlations, 0.0058823529411764705)
#   83                         (h?, 0.006002400960384154)          (computer program, 0.0058823529411764705)
#   84     (information extraction, 0.006002400960384152)           (fault detection, 0.0058823529411764705)
#   85               (named entity, 0.006002400960384152)  (ontology design patterns, 0.0058823529411764705)
#   86                  (wikipedia, 0.006002400960384152)  (multiple attribute decision making (madm), 0....
#   87      (combining game theory, 0.006002400960384152)  (pythagorean membership grades, 0.005882352941...
#   88        (stochastic learning, 0.006002400960384152)  (battery charge measurement, 0.005882352941176...
#   89    (tier femtocell networks, 0.006002400960384152)  (failure mode and effects analysis, 0.00588235...
#   90         (coordinate descent, 0.006002400960384152)             (visualization, 0.0058823529411764705)
#   91               (times ascent, 0.006002400960384152)  (unmanned quadrotor helicopter , 0.00588235294...
#   92  (stochastic gradient descent, 0.00600240096038...            (linear dynamic, 0.0058823529411764705)
#   93  (semi-structured resources, 0.006002400960384152)           (computer vision, 0.0058823529411764705)
#   94  (stackelberg game formulation, 0.0060024009603...               (future work, 0.0058823529411764705)
#   95        (rate of convergence, 0.006002400960384152)    (syndromic surveillance, 0.0058823529411764705)
#   96  (linguistic frame semantics, 0.00600240096038415)  (time heterogeneous multi, 0.0058823529411764705)
#   97             (ontology design, 0.00600240096038415)      (single moving camera, 0.0058823529411764705)
#   98            (ready ontologies, 0.00600240096038415)            (visual quality, 0.0058823529411764705)
#   99              (novel approach, 0.00600240096038415)    (online social networks, 0.0058823529411764705)
#  100             (converting text, 0.00600240096038415)    (support vector machine, 0.0058823529411764705)

# %% [markdown]
# ## Year 2014

# %%
#View tables for year 2014
tables_metrics_view(2014)
# Out:
# Year: 2014
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1    (artificial neural network, 0.2235249407211646)    (artificial neural network, 0.3045454545454545)
#    2    (mathematical optimization, 0.1730974846647971)   (mathematical optimization, 0.16363636363636364)
#    3  (interference (communication), 0.0656238600198...              (ilya sutskever, 0.13636363636363635)
#    4            (lyapunov fractal, 0.06178983134058488)             (lyapunov fractal, 0.1318181818181818)
#    5     (approximation algorithm, 0.04018860864742119)     (approximation algorithm, 0.12272727272727273)
#    6                 (simulation, 0.033448065163415676)            (nonlinear system, 0.10454545454545454)
#    7                 (experiment, 0.032702309655280086)          (numerical analysis, 0.10454545454545454)
#    8         (mathematical model, 0.023744292237442923)                   (algorithm, 0.09545454545454544)
#    9                  (algorithm, 0.023562599764868748)             (optimal control, 0.08636363636363636)
#   10         (numerical analysis, 0.023362643504877087)               (kyunghyun cho, 0.08636363636363636)
#   11  (sampling (signal processing), 0.0198572546175...  (statistical machine translation, 0.0863636363...
#   12            (cognitive radio, 0.016687422166874223)                     (encoder, 0.08636363636363636)
#   13   (neural network simulation, 0.01371703089464649)           (matthew d. zeiler, 0.08636363636363636)
#   14           (nonlinear system, 0.009903062218265273)                   (iteration, 0.08181818181818182)
#   15  (particle swarm optimization, 0.00624196959813...                  (simulation, 0.08181818181818182)
#   16                (computation, 0.006060606060606061)         (dynamic programming, 0.08181818181818182)
#   17             (language model, 0.006060606060606061)   (neural network simulation, 0.08181818181818182)
#   18          (analytical models, 0.005977584059775841)  (linear matrix inequalities, 0.08181818181818182)
#   19                   (topology, 0.005977584059775841)   (markovian jump parameters, 0.07727272727272727)
#   20             (ilya sutskever, 0.005334939263955455)                 (fuzzy model, 0.07727272727272727)
#   21      (optimization problem, 0.0053080119353095005)                (time bounded, 0.07727272727272727)
#   22            (machine learning, 0.00390730411522008)       (stochastically finite, 0.07727272727272727)
#   23           (optimal control, 0.0031650252613002606)                 (finite time, 0.07727272727272727)
#   24                 (iteration, 0.0028274141105499202)               (paper studies, 0.07727272727272727)
#   25        (dynamic programming, 0.002491405554917384)              (optimal finite, 0.07727272727272727)
#   26  (convolutional neural network, 0.0020649369110...          (designed algorithm, 0.07727272727272727)
#   27   (http public key pinning, 0.0016824534259154442)       (krasovskii functional, 0.07727272727272727)
#   28          (bellman equation, 0.0011959883889596013)           (numerical example, 0.07727272727272727)
#   29                  (bil herd, 0.0009179861234655758)        (sufficient condition, 0.07727272727272727)
#   30  (linear matrix inequalities, 0.000705687007056...        (appropriate lyapunov, 0.07727272727272727)
#   31   (markov decision process, 0.0006608247095207753)    (admissible uncertainties, 0.07727272727272727)
#   32              (usb on-the-go, 0.000650695126099858)       (bounded uncertainties, 0.07727272727272727)
#   33        (geoffrey e. hinton, 0.0005808919414149801)    (uncertain nonlinear mjss, 0.07727272727272727)
#   34  (recurrent neural network, 0.0004510547567832748)     (time passive controller, 0.07727272727272727)
#   35          (neural networks, 0.00040576628528060654)    (proposed design approach, 0.07727272727272727)
#   36  (linear matrix inequality, 0.00039919745399197...               (usb on-the-go, 0.06818181818181818)
#   37              (kyunghyun cho, 0.000366680503666805)            (bellman equation, 0.06818181818181818)
#   38  (statistical machine translation, 0.0003666805...     (markov decision process, 0.06818181818181818)
#   39                    (encoder, 0.000366680503666805)               (yoshua bengio, 0.06363636363636363)
#   40          (matthew d. zeiler, 0.000366680503666805)  (interference (communication), 0.0590909090909...
#   41         (social inequality, 0.0003462178989612877)          (geoffrey e. hinton, 0.05909090909090909)
#   42  (hamilton–jacobi–bellman equation, 0.000194715...               (oriol vinyals, 0.05909090909090909)
#   43    (benchmark (computing), 0.00018136353752792113)                  (quoc v. le, 0.05909090909090909)
#   44  (baseline (configuration management), 0.000166...  (neural machine translation, 0.05909090909090909)
#   45            (yoshua bengio, 0.00015220700152206997)                (phil blunsom, 0.05909090909090909)
#   46          (iterative method, 9.420840678623992e-05)        (bart van merrienboer, 0.05909090909090909)
#   47  (wireless sensor networks, 8.302200083022001e-05)  (deep learning papers review at neurotechnolog...
#   48         (genetic algorithm, 6.226650062266502e-05)            (nal kalchbrenner, 0.05909090909090909)
#   49          (alex krizhevsky, 5.0473602777463315e-05)  (hamilton–jacobi–bellman equation, 0.054545454...
#   50       (mean squared error, 4.1511000415110007e-05)             (neural networks, 0.05454545454545454)
#   51          (time complexity, 2.6174991928416586e-05)           (iterative method, 0.049999999999999996)
#   52  (velocity (software development), 1.1860285832...  (particle swarm optimization, 0.04999999999999...
#   53         (search algorithm, 1.1860285832888572e-05)  (point of view (computer hardware company), 0....
#   54            (metaheuristic, 1.1860285832888572e-05)     (multitier architecture, 0.049999999999999996)
#   55  (particle swarm optimization (pso), 1.18602858...                       (mimo, 0.049999999999999996)
#   56                      (multimodal interaction, 0.0)            (rayleigh fading, 0.049999999999999996)
#   57          (ant colony optimization algorithms, 0.0)                  (mimo-ofdm, 0.049999999999999996)
#   58                                   (heuristic, 0.0)      (shadowing (histology), 0.049999999999999996)
#   59                               (jacobi method, 0.0)                      (x.690, 0.049999999999999996)
#   60                            (natural language, 0.0)                (coefficient, 0.049999999999999996)
#   61                              (knowledge base, 0.0)       (constraint algorithm, 0.049999999999999996)
#   62                                 (xiang zhang, 0.0)             (bit error rate, 0.049999999999999996)
#   63                  (sampling - surgical action, 0.0)                 (experiment, 0.049999999999999996)
#   64                        (fuzzy control system, 0.0)         (quality of service, 0.049999999999999996)
#   65                               (oriol vinyals, 0.0)      (benchmark (computing), 0.045454545454545456)
#   66                                  (quoc v. le, 0.0)  (convolutional neural network, 0.0454545454545...
#   67                                 (alex graves, 0.0)                   (yang liu, 0.045454545454545456)
#   68                              (navdeep jaitly, 0.0)   (recurrent neural network, 0.045454545454545456)
#   69                                   (fuzzy set, 0.0)        (richard m. schwartz, 0.045454545454545456)
#   70                       (group decision making, 0.0)           (zhongqiang huang, 0.045454545454545456)
#   71                              (control theory, 0.0)               (john makhoul, 0.045454545454545456)
#   72                             (convex function, 0.0)         (mathematical model, 0.045454545454545456)
#   73                 (empirical risk minimization, 0.0)               (jacob devlin, 0.045454545454545456)
#   74                 (stochastic gradient descent, 0.0)  (velocity (software development), 0.0409090909...
#   75                          (image segmentation, 0.0)  (sampling (signal processing), 0.0409090909090...
#   76                         (global optimization, 0.0)            (search algorithm, 0.04090909090909091)
#   77                                    (yang liu, 0.0)               (metaheuristic, 0.04090909090909091)
#   78               (nicolas boulanger-lewandowski, 0.0)  (particle swarm optimization (pso), 0.04090909...
#   79                         (richard m. schwartz, 0.0)                 (computation, 0.04090909090909091)
#   80                            (zhongqiang huang, 0.0)             (alex krizhevsky, 0.04090909090909091)
#   81                                (john makhoul, 0.0)                 (xiang zhang, 0.03636363636363636)
#   82                              (neural network, 0.0)   (metaheuristic search (ms), 0.03636363636363636)
#   83                                 (exponential, 0.0)    (linear matrix inequality, 0.03636363636363636)
#   84                        (commercial potential, 0.0)     (http public key pinning, 0.03636363636363636)
#   85                    (multiple object tracking, 0.0)                       (pixel, 0.03636363636363636)
#   86                 (gained increasing attention, 0.0)        (optimization problem, 0.03636363636363636)
#   87                               (formal system, 0.0)  (neighborhood search (ns) operator, 0.03636363...
#   88                                 (fuzzy logic, 0.0)              (jacobi method, 0.031818181818181815)
#   89                                  (user using, 0.0)      (premature convergence, 0.031818181818181815)
#   90                                 (scalability, 0.0)       (computer performance, 0.031818181818181815)
#   91                                    (imagenet, 0.0)  (baseline (configuration management), 0.031818...
#   92                                   (computers, 0.0)                   (bil herd, 0.031818181818181815)
#   93                            (generative model, 0.0)          (social inequality, 0.031818181818181815)
#   94                      (calculus of variations, 0.0)            (machine learning, 0.02727272727272727)
#   95                   (metaheuristic search (ms), 0.0)  (nicolas boulanger-lewandowski, 0.027272727272...
#   96                                    (freebase, 0.0)               (formal system, 0.02727272727272727)
#   97                             (feasible region, 0.0)                 (fuzzy logic, 0.02727272727272727)
#   98                       (premature convergence, 0.0)         (rate of convergence, 0.02727272727272727)
#   99             (objective optimisation problems, 0.0)         (convex optimization, 0.02727272727272727)
#  100                             (noise reduction, 0.0)    (constrained optimization, 0.02727272727272727)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (artificial neural network, 0.030860883231411545)   (artificial neural network, 0.04194973034453649)
#    2  (mathematical optimization, 0.020280309520117196)  (mathematical optimization, 0.022477980454226536)
#    3            (lyapunov fractal, 0.01628200172398228)            (lyapunov fractal, 0.01884000118416622)
#    4             (ilya sutskever, 0.012394555422445032)            (nonlinear system, 0.01874072025473367)
#    5    (approximation algorithm, 0.011964115656944321)            (optimal control, 0.015822591573492525)
#    6         (numerical analysis, 0.011028942627548407)     (approximation algorithm, 0.01458837006490641)
#    7                  (algorithm, 0.009848031129536857)         (numerical analysis, 0.013238602325423402)
#    8        (dynamic programming, 0.008861182262317519)             (ilya sutskever, 0.012268577445591249)
#    9            (optimal control, 0.008801589089570957)                   (algorithm, 0.01012508795085669)
#   10  (neural network simulation, 0.008748631676610809)  (neural network simulation, 0.009815367751818703)
#   11                  (iteration, 0.008451719269832684)                  (iteration, 0.009748404918707362)
#   12                 (simulation, 0.007868585999454942)                  (simulation, 0.00967787303983831)
#   13                 (experiment, 0.007514432728018093)        (dynamic programming, 0.009456112149739364)
#   14              (kyunghyun cho, 0.007501054436543573)  (particle swarm optimization, 0.00801245071221...
#   15          (matthew d. zeiler, 0.007501054436543573)              (kyunghyun cho, 0.007738889860948456)
#   16  (statistical machine translation, 0.0075010544...  (statistical machine translation, 0.0077388898...
#   17                    (encoder, 0.007501054436543572)                    (encoder, 0.007738889860948455)
#   18              (usb on-the-go, 0.007304538720757552)          (matthew d. zeiler, 0.007738889860948455)
#   19           (bellman equation, 0.007251237585021234)           (bellman equation, 0.007348409181061323)
#   20           (nonlinear system, 0.007230268749723222)              (usb on-the-go, 0.007329809827304527)
#   21   (markov decision process, 0.0071321244669698075)    (markov decision process, 0.007168338706565409)
#   22   (wireless sensor networks, 0.006903984711132335)     (benchmark (computing), 0.0071430219917870096)
#   23  (sampling (signal processing), 0.0068805451635...                 (experiment, 0.006816904089240434)
#   24  (particle swarm optimization, 0.00687089146460...  (wireless sensor networks, 0.0066365163897108195)
#   25         (geoffrey e. hinton, 0.006707881271876788)              (metaheuristic, 0.006629682136890612)
#   26  (interference (communication), 0.0064076061963...  (sampling (signal processing), 0.0065949584349...
#   27             (neural networks, 0.00603639306088193)           (iterative method, 0.006330380850116918)
#   28  (hamilton–jacobi–bellman equation, 0.006014186...   (recurrent neural network, 0.005873802182965115)
#   29         (mathematical model, 0.005889098878160308)    (http public key pinning, 0.005676300702004246)
#   30    (http public key pinning, 0.005677803492752709)  (linear matrix inequalities, 0.005642112830691...
#   31  (linear matrix inequalities, 0.005671853812923...  (interference (communication), 0.0056418720138...
#   32      (benchmark (computing), 0.005537722839333498)              (yoshua bengio, 0.005592530800104543)
#   33             (yoshua bengio, 0.0054248177846132305)  (velocity (software development), 0.0055493491...
#   34  (velocity (software development), 0.0053987181...           (search algorithm, 0.005549349141898945)
#   35           (search algorithm, 0.005398718133039095)  (hamilton–jacobi–bellman equation, 0.005392930...
#   36              (metaheuristic, 0.005398718133039095)  (particle swarm optimization (pso), 0.00534162...
#   37  (particle swarm optimization (pso), 0.00539871...    (evolutionary algorithm, 0.0051902694982448394)
#   38            (iterative method, 0.00538186947779269)         (geoffrey e. hinton, 0.005106625064783806)
#   39               (computation, 0.0052997723240781275)   (linear matrix inequality, 0.005023143549267747)
#   40              (oriol vinyals, 0.005256012904293419)              (oriol vinyals, 0.004989181809875223)
#   41                 (quoc v. le, 0.005256012904293419)                 (quoc v. le, 0.004989181809875223)
#   42  (neural machine translation, 0.005256012904293...  (neural machine translation, 0.004989181809875...
#   43               (phil blunsom, 0.005256012904293419)               (phil blunsom, 0.004989181809875223)
#   44       (bart van merrienboer, 0.005256012904293419)       (bart van merrienboer, 0.004989181809875223)
#   45  (deep learning papers review at neurotechnolog...  (deep learning papers review at neurotechnolog...
#   46           (nal kalchbrenner, 0.005256012904293419)           (nal kalchbrenner, 0.004989181809875223)
#   47   (recurrent neural network, 0.005250116192914052)         (mathematical model, 0.004733997164363645)
#   48                  (bil herd, 0.0051705010467639565)        (rate of convergence, 0.004709973621765601)
#   49       (optimization problem, 0.004969779788148435)        (convex optimization, 0.004709973621765601)
#   50  (point of view (computer hardware company), 0....   (constrained optimization, 0.004709973621765601)
#   51    (multitier architecture, 0.0049457515335088265)     (premature convergence, 0.0046869858938782824)
#   52                      (mimo, 0.0049457515335088265)  (markovian jump parameters, 0.004655716716925442)
#   53           (rayleigh fading, 0.0049457515335088265)                (fuzzy model, 0.004655716716925442)
#   54                 (mimo-ofdm, 0.0049457515335088265)               (time bounded, 0.004655716716925442)
#   55     (shadowing (histology), 0.0049457515335088265)      (stochastically finite, 0.004655716716925442)
#   56                     (x.690, 0.0049457515335088265)                (finite time, 0.004655716716925442)
#   57               (coefficient, 0.0049457515335088265)              (paper studies, 0.004655716716925442)
#   58      (constraint algorithm, 0.0049457515335088265)             (optimal finite, 0.004655716716925442)
#   59             (bit error rate, 0.004945751533508826)         (designed algorithm, 0.004655716716925442)
#   60         (quality of service, 0.004945751533508826)      (krasovskii functional, 0.004655716716925442)
#   61    (time passive controller, 0.004868599470521395)          (numerical example, 0.004655716716925442)
#   62   (proposed design approach, 0.004868599470521395)       (sufficient condition, 0.004655716716925442)
#   63  (markovian jump parameters, 0.004868599470521394)       (appropriate lyapunov, 0.004655716716925442)
#   64                (fuzzy model, 0.004868599470521394)   (admissible uncertainties, 0.004655716716925442)
#   65               (time bounded, 0.004868599470521394)      (bounded uncertainties, 0.004655716716925442)
#   66      (stochastically finite, 0.004868599470521394)   (uncertain nonlinear mjss, 0.004655716716925442)
#   67                (finite time, 0.004868599470521394)    (time passive controller, 0.004655716716925441)
#   68              (paper studies, 0.004868599470521394)   (proposed design approach, 0.004655716716925441)
#   69             (optimal finite, 0.004868599470521394)        (collective behavior, 0.004653682318469454)
#   70         (designed algorithm, 0.004868599470521394)         (swarm intelligence, 0.004653682318469454)
#   71      (krasovskii functional, 0.004868599470521394)                       (mimo, 0.004613898398162214)
#   72          (numerical example, 0.004868599470521394)                  (mimo-ofdm, 0.004613898398162214)
#   73       (sufficient condition, 0.004868599470521394)      (shadowing (histology), 0.004613898398162214)
#   74       (appropriate lyapunov, 0.004868599470521394)                      (x.690, 0.004613898398162214)
#   75   (admissible uncertainties, 0.004868599470521394)                (coefficient, 0.004613898398162214)
#   76      (bounded uncertainties, 0.004868599470521394)       (constraint algorithm, 0.004613898398162214)
#   77   (uncertain nonlinear mjss, 0.004868599470521394)             (bit error rate, 0.004613898398162214)
#   78  (metaheuristic search (ms), 0.004861852687472144)         (quality of service, 0.004613898398162214)
#   79  (neighborhood search (ns) operator, 0.00486185...  (point of view (computer hardware company), 0....
#   80             (alex krizhevsky, 0.00483988033103177)     (multitier architecture, 0.004613898398162213)
#   81  (convolutional neural network, 0.0048208015805...            (rayleigh fading, 0.004613898398162213)
#   82   (brain storm optimization, 0.004705882352941178)           (natural language, 0.004524886877828055)
#   83  (solutions getting clustered, 0.00470588235294...             (knowledge base, 0.004524886877828055)
#   84        (promising algorithm, 0.004705882352941178)                  (fuzzy set, 0.004524886877828055)
#   85      (brainstorming process, 0.004705882352941178)      (group decision making, 0.004524886877828055)
#   86        (collective behavior, 0.004705882352941178)            (convex function, 0.004524886877828055)
#   87         (swarm intelligence, 0.004705882352941178)  (empirical risk minimization, 0.00452488687782...
#   88           (natural language, 0.004705882352941177)         (image segmentation, 0.004524886877828055)
#   89             (knowledge base, 0.004705882352941177)                 (user using, 0.004524886877828055)
#   90                  (fuzzy set, 0.004705882352941177)  (objective optimisation problems, 0.0045248868...
#   91      (group decision making, 0.004705882352941177)  (operator networks environment, 0.004524886877...
#   92            (convex function, 0.004705882352941177)            (risk evaluation, 0.004524886877828055)
#   93  (empirical risk minimization, 0.00470588235294...   (criteria decision making, 0.004524886877828055)
#   94         (image segmentation, 0.004705882352941177)             (facto standard, 0.004524886877828055)
#   95  (objective optimisation problems, 0.0047058823...          (currently support, 0.004524886877828055)
#   96  (operator networks environment, 0.004705882352...  (cell-to-cell communication, 0.004524886877828...
#   97            (risk evaluation, 0.004705882352941177)                 (chemotaxis, 0.004524886877828055)
#   98   (criteria decision making, 0.004705882352941177)            (logical dynamic, 0.004524886877828055)
#   99             (facto standard, 0.004705882352941177)        (theoretical results, 0.004524886877828055)
#  100          (currently support, 0.004705882352941177)         (sentiment analysis, 0.004524886877828055)

# %% [markdown]
# ## Year 2015

# %%
#View tables for year 2015
tables_metrics_view(2015)
# Out:
# Year: 2015
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1    (artificial neural network, 0.2150286358102626)   (artificial neural network, 0.17973856209150327)
#    2   (mathematical optimization, 0.11147762872655706)            (nonlinear system, 0.11437908496732027)
#    3  (particle swarm optimization, 0.08569732082268...                   (algorithm, 0.10130718954248366)
#    4                   (algorithm, 0.08040947035507434)          (numerical analysis, 0.08169934640522876)
#    5                       (???? , 0.06659127129942263)    (mathematical optimization, 0.0784313725490196)
#    6                      (??????? , 0.052759027108111)                  (simulation, 0.07516339869281045)
#    7         (numerical analysis, 0.045000466407759274)        (optimization problem, 0.06209150326797386)
#    8                     (????? , 0.044949442678468704)  (particle swarm optimization, 0.05882352941176...
#    9                 (simulation, 0.042405782524804876)                      (???? , 0.058823529411764705)
#   10            (nonlinear system, 0.04183091027996445)            (lyapunov fractal, 0.05228758169934641)
#   11     (support vector machine, 0.034381967723337084)       (benchmark (computing), 0.04575163398692811)
#   12            (machine learning, 0.03243171682769315)  (principal component analysis, 0.0424836601307...
#   13             (neural networks, 0.02878388513875495)              (neural networks, 0.0392156862745098)
#   14                     (?????? , 0.02500803600128576)           (ar auto regressive, 0.0392156862745098)
#   15           (lyapunov fractal, 0.021541327669181706)    (structural break modeling, 0.0392156862745098)
#   16                 (experiment, 0.017390582055622585)  (emd empirical mode decomposition, 0.039215686...
#   17  (memristor-based neural networks, 0.0166934533...         (ga genetic algorithm, 0.0392156862745098)
#   18                   (imagenet, 0.016629165327333117)           (bt bayesian theory, 0.0392156862745098)
#   19      (benchmark (computing), 0.011699503959889312)  (pca principal component analysis, 0.039215686...
#   20              (normal brains, 0.010911103967998832)  (empirical mode decomposition, 0.0392156862745...
#   21               (mri scanning, 0.010911103967998832)  (weibull distribution function, 0.039215686274...
#   22                       (??? , 0.010532130643027458)  (arima auto regressive integrated moving avera...
#   23  (extreme learning machine , 0.010263525506874536)  (auto regressive integrated moving average, 0....
#   24  (convolutional neural network, 0.0101947518533...      (unscented kalman filter, 0.0392156862745098)
#   25        (optimization problem, 0.00964631418819743)                     (feedback, 0.0392156862745098)
#   26           (fractional-order, 0.008421729347476696)    (recurrent neural network, 0.03594771241830066)
#   27         (swarm intelligence, 0.008400300010714668)                 (yuval tassa, 0.03594771241830066)
#   28  (principal component analysis, 0.0073240115718...             (emanuel todorov, 0.03594771241830066)
#   29           (extract features, 0.006750241080038543)           (satinder p. singh, 0.03594771241830066)
#   30                  (iteration, 0.005314406766748556)                    (tom erez, 0.03594771241830066)
#   31   (recurrent neural network, 0.004551132400414833)                 (honglak lee, 0.03594771241830066)
#   32       (fuzzy control system, 0.004221579342119361)                       (robot, 0.03594771241830066)
#   33          (genetic algorithm, 0.004221579342119361)                (trust region, 0.03594771241830066)
#   34               (optimization, 0.004221579342119361)               (sergey levine, 0.03594771241830066)
#   35     (long short-term memory, 0.004221579342119361)                  (experiment, 0.03594771241830066)
#   36      (unsupervised learning, 0.004221579342119361)             (optimal control, 0.03594771241830066)
#   37            (computer vision, 0.004221579342119361)                (doina precup, 0.03594771241830066)
#   38   (neural network simulation, 0.00390758287430736)              (formal system, 0.032679738562091505)
#   39                   (database, 0.003340629984512223)                (fuzzy logic, 0.032679738562091505)
#   40                  (feedback, 0.0032035024211392303)                  (iteration, 0.032679738562091505)
#   41           (optimal control, 0.0029603046276927914)     (support vector machine, 0.032679738562091505)
#   42        (computer simulation, 0.002786698703086474)                   (database, 0.032679738562091505)
#   43  (hamilton–jacobi–bellman equation, 0.001475950...    (approximation algorithm, 0.032679738562091505)
#   44             (deep learning, 0.0013292736645356383)              (normal brains, 0.032679738562091505)
#   45   (approximation algorithm, 0.0013129658485098508)               (mri scanning, 0.032679738562091505)
#   46       (supervised learning, 0.0011305165660678348)  (neural network simulation, 0.032679738562091505)
#   47  (block cipher mode of operation, 0.00077117569...  (artificial bee colony algorithm, 0.0294117647...
#   48          (feature learning, 0.0006321484270696741)                (performance, 0.029411764705882353)
#   49               (interaction, 0.0005614212650913542)  (hamilton–jacobi–bellman equation, 0.029411764...
#   50       (dynamic programming, 0.0004450717861982994)     (low-power broadcasting, 0.029411764705882353)
#   51                     (theory, 0.000415729133183328)           (channel capacity, 0.029411764705882353)
#   52   (reinforcement learning, 0.00022198398765419015)     (long short-term memory, 0.029411764705882353)
#   53  (artificial bee colony algorithm, 0.0001503625...      (unsupervised learning, 0.029411764705882353)
#   54   (http public key pinning, 6.428801028608164e-05)         (multi-agent system, 0.029411764705882353)
#   55     (procedural generation, 4.285867352405443e-05)            (coexist (image), 0.029411764705882353)
#   56           (mr brain images, 3.571556127004535e-05)  (power semiconductor device, 0.029411764705882...
#   57        (social inequality, 3.4286938819243554e-05)  (interference (communication), 0.0294117647058...
#   58             (formal system, 3.428693881924354e-05)           (autonomous robot, 0.029411764705882353)
#   59               (fuzzy logic, 3.428693881924354e-05)                   (??????? , 0.029411764705882353)
#   60                 (big data, 2.1429336762027214e-05)                 (compaq lte, 0.029411764705882353)
#   61                (mapreduce, 2.1429336762027214e-05)  (convolutional neural network, 0.0261437908496...
#   62  (linear matrix inequality, 4.285867352405443e-06)          (genetic algorithm, 0.026143790849673203)
#   63                                 (performance, 0.0)              (regione lazio, 0.026143790849673203)
#   64                             (convex function, 0.0)                (social ties, 0.026143790849673203)
#   65                         (importance sampling, 0.0)  (enterprise social network, 0.026143790849673203)
#   66                       (binding proteins play, 0.0)          (topic discussions, 0.026143790849673203)
#   67                                  (throughput, 0.0)      (specialized companies, 0.026143790849673203)
#   68                           (maxima and minima, 0.0)      (international network, 0.026143790849673203)
#   69                             (system dynamics, 0.0)            (paper describes, 0.026143790849673203)
#   70                         (activation function, 0.0)              (central italy, 0.026143790849673203)
#   71                          (energy consumption, 0.0)           (machine learning, 0.026143790849673203)
#   72                                  (long short, 0.0)                (autoencoder, 0.026143790849673203)
#   73                         (sentiment analysis , 0.0)            (noise reduction, 0.026143790849673203)
#   74                               (loss function, 0.0)          (novelty detection, 0.026143790849673203)
#   75                  (feedforward neural network, 0.0)         (swarm intelligence, 0.026143790849673203)
#   76                          (well-posed problem, 0.0)  (block cipher mode of operation, 0.02614379084...
#   77                         (convex optimization, 0.0)               (frontal lobe, 0.026143790849673203)
#   78                                 (filter bank, 0.0)     (inferior frontal gyrus, 0.026143790849673203)
#   79                             (unit commitment, 0.0)             (insula of reil, 0.026143790849673203)
#   80                               (regione lazio, 0.0)     (epilepsy temporal lobe, 0.026143790849673203)
#   81                                 (social ties, 0.0)      (parahippocampal gyrus, 0.026143790849673203)
#   82                   (enterprise social network, 0.0)           (precentral gyrus, 0.026143790849673203)
#   83                           (topic discussions, 0.0)  (lateral occipitotemporal gyrus, 0.02614379084...
#   84                       (specialized companies, 0.0)        (alzheimer's disease, 0.026143790849673203)
#   85                       (international network, 0.0)            (mr brain images, 0.026143790849673203)
#   86                             (paper describes, 0.0)            (output feedback, 0.026143790849673203)
#   87                               (central italy, 0.0)                  (observers, 0.026143790849673203)
#   88                            (anatomy regional, 0.0)           (adaptive systems, 0.026143790849673203)
#   89                                 (requirement, 0.0)          (nonlinear systems, 0.026143790849673203)
#   90                                    (converge, 0.0)           (digital services, 0.026143790849673203)
#   91                              (control theory, 0.0)     (acoustic cryptanalysis, 0.026143790849673203)
#   92                                 (controllers, 0.0)                     (lobule, 0.026143790849673203)
#   93                         (apparatus including, 0.0)           (extract features, 0.026143790849673203)
#   94                             (methods systems, 0.0)                   (imagenet, 0.022875816993464054)
#   95                               (storage media, 0.0)     (reinforcement learning, 0.022875816993464054)
#   96                              (control system, 0.0)                     (theory, 0.022875816993464054)
#   97                            (bellman equation, 0.0)      (artificial bee colony, 0.022875816993464054)
#   98                       (anomalous experiences, 0.0)                     (????? , 0.022875816993464054)
#   99                             (virtual reality, 0.0)       (crucially importance, 0.022875816993464054)
#  100                             (learning model , 0.0)           (medical analysis, 0.022875816993464054)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (artificial neural network, 0.024968207529603582)   (artificial neural network, 0.02970252573394531)
#    2           (nonlinear system, 0.014808812905031792)                    (??????? , 0.01888884337446329)
#    3                  (algorithm, 0.013899975899706176)                      (???? , 0.017202020374224775)
#    4                   (??????? , 0.012134462866965635)           (nonlinear system, 0.016620171090345588)
#    5         (numerical analysis, 0.011848398151204495)                  (algorithm, 0.015401397471193172)
#    6  (mathematical optimization, 0.011492531523815255)         (numerical analysis, 0.012874630894112329)
#    7        (optimization problem, 0.00937366551085253)  (mathematical optimization, 0.012132668202849325)
#    8     (support vector machine, 0.009135183106507428)           (lyapunov fractal, 0.009116319624526551)
#    9                      (???? , 0.008828832460850566)                     (????? , 0.008477552884705771)
#   10                 (simulation, 0.008247450897282904)        (optimization problem, 0.00836915676071521)
#   11          (lyapunov fractal, 0.0076471021947529345)                  (simulation, 0.00762709256551583)
#   12      (benchmark (computing), 0.007202373932150739)      (support vector machine, 0.00720030983652397)
#   13                (experiment, 0.0070756002266546955)                     (?????? , 0.00690195203345381)
#   14            (neural networks, 0.006466227528036592)      (benchmark (computing), 0.006692113824810139)
#   15                    (????? , 0.0062707533871993945)                 (experiment, 0.006395090596429801)
#   16               (normal brains, 0.00546436591039303)   (recurrent neural network, 0.006262233053082222)
#   17                (mri scanning, 0.00546436591039303)  (particle swarm optimization, 0.00624118242848...
#   18  (convolutional neural network, 0.0053119626248...            (optimal control, 0.006029916021466623)
#   19                  (iteration, 0.005208164432645321)            (neural networks, 0.005965417956104738)
#   20           (machine learning, 0.005196557056970019)  (convolutional neural network, 0.0055662036231...
#   21      (procedural generation, 0.005103373207668814)                     (robot, 0.0055023977770974845)
#   22                   (database, 0.005044615768102894)                (yuval tassa, 0.005502397777097484)
#   23                   (imagenet, 0.005032115257744318)            (emanuel todorov, 0.005502397777097484)
#   24  (neural network simulation, 0.004967520638235422)          (satinder p. singh, 0.005502397777097484)
#   25            (optimal control, 0.004936124961711243)                   (tom erez, 0.005502397777097484)
#   26     (long short-term memory, 0.004846522673861081)                (honglak lee, 0.005502397777097484)
#   27     (unsupervised learning, 0.0048465226738610805)               (trust region, 0.005502397777097484)
#   28                   (feedback, 0.004842807627936414)              (sergey levine, 0.005502397777097484)
#   29   (recurrent neural network, 0.004817944239685158)               (doina precup, 0.005502397777097483)
#   30         (swarm intelligence, 0.004786479074230329)              (normal brains, 0.005359259463375593)
#   31                      (robot, 0.004619504002817792)               (mri scanning, 0.005359259463375593)
#   32               (doina precup, 0.004619504002817792)                   (imagenet, 0.005062054685983069)
#   33                (yuval tassa, 0.004619504002817791)           (machine learning, 0.005056633115561419)
#   34            (emanuel todorov, 0.004619504002817791)                  (mapreduce, 0.004898066614255365)
#   35          (satinder p. singh, 0.004619504002817791)                   (big data, 0.004898066614255364)
#   36                   (tom erez, 0.004619504002817791)     (procedural generation, 0.0047774271079025765)
#   37                (honglak lee, 0.004619504002817791)                   (feedback, 0.004631034932865451)
#   38               (trust region, 0.004619504002817791)  (neural network simulation, 0.004457305160805726)
#   39              (sergey levine, 0.004619504002817791)     (long short-term memory, 0.004426575403502005)
#   40         (genetic algorithm, 0.0045262285483942035)              (computer vision, 0.0042493663895728)
#   41  (hamilton–jacobi–bellman equation, 0.004513446...      (unsupervised learning, 0.004245251190784052)
#   42                     (theory, 0.004464200338318381)                   (database, 0.004134736679703087)
#   43  (artificial bee colony algorithm, 0.0043964826...   (approximation algorithm, 0.0041230179931193225)
#   44           (extract features, 0.004314760754311335)                      (??? , 0.0041211141986924925)
#   45  (particle swarm optimization, 0.00429386399907...                  (iteration, 0.004037728073505009)
#   46  (memristor-based neural networks, 0.0042760609...           (extract features, 0.003994220841772913)
#   47            (mr brain images, 0.004252173630179007)            (mr brain images, 0.003993214064314147)
#   48                  (mapreduce, 0.004194335548029292)                      (hadoop, 0.00397274124726652)
#   49                   (big data, 0.004194335548029291)  (artificial bee colony algorithm, 0.0039241194...
#   50              (formal system, 0.004189723954032775)  (principal component analysis, 0.0038846316989...
#   51                (fuzzy logic, 0.004189723954032774)             (formal system, 0.0038414244988993233)
#   52           (fractional-order, 0.004127439864911603)               (fuzzy logic, 0.0038414244988993233)
#   53               (autoencoder, 0.0040422033206961045)                (autoencoder, 0.003682810658966236)
#   54           (noise reduction, 0.0040422033206961045)            (noise reduction, 0.003682810658966236)
#   55         (novelty detection, 0.0040422033206961045)          (novelty detection, 0.003682810658966236)
#   56    (acoustic cryptanalysis, 0.0040422033206961045)     (acoustic cryptanalysis, 0.003682810658966236)
#   57   (approximation algorithm, 0.0038874663940951007)   (http public key pinning, 0.0036521144501215673)
#   58    (http public key pinning, 0.003797704763433935)           (fractional-order, 0.003603375438350395)
#   59      (crucially importance, 0.0037139321003504503)         (social inequality, 0.0033866050150996806)
#   60          (medical analysis, 0.0037139321003504503)        (dynamic programming, 0.003342388631562069)
#   61  (novel automatic classification, 0.00371393210...          (genetic algorithm, 0.003324939182859145)
#   62   (accurate classification, 0.0037139321003504503)  (block cipher mode of operation, 0.00328284617...
#   63     (artificial bee colony, 0.0036780146846453958)        (ar auto regressive, 0.0032760609816302124)
#   64           (feature learning, 0.003654203771841542)  (structural break modeling, 0.0032760609816302...
#   65  (extreme learning machine , 0.0036266155918008...  (emd empirical mode decomposition, 0.003276060...
#   66           (cross reactions, 0.0035840635978028885)      (ga genetic algorithm, 0.0032760609816302124)
#   67  (computer assisted diagnosis, 0.00358406359780...        (bt bayesian theory, 0.0032760609816302124)
#   68           (wavelet analysis, 0.003584063597802888)  (pca principal component analysis, 0.003276060...
#   69  (magnetic resonance imaging, 0.003584063597802...  (empirical mode decomposition, 0.0032760609816...
#   70       (computer simulation, 0.0035377440366051727)  (weibull distribution function, 0.003276060981...
#   71               (performance, 0.0034932000144034694)  (arima auto regressive integrated moving avera...
#   72    (low-power broadcasting, 0.0034932000144034694)  (auto regressive integrated moving average, 0....
#   73          (channel capacity, 0.0034932000144034694)   (unscented kalman filter, 0.0032760609816302124)
#   74  (power semiconductor device, 0.003493200014403...        (swarm intelligence, 0.0032617490819379755)
#   75          (autonomous robot, 0.0034932000144034694)        (importance sampling, 0.003257328990228013)
#   76         (multi-agent system, 0.003493200014403469)      (binding proteins play, 0.003257328990228013)
#   77            (coexist (image), 0.003493200014403469)         (energy consumption, 0.003257328990228013)
#   78  (interference (communication), 0.0034932000144...                 (long short, 0.003257328990228013)
#   79                 (compaq lte, 0.003493200014403469)        (sentiment analysis , 0.003257328990228013)
#   80             (regione lazio, 0.0034788658897199525)      (anomalous experiences, 0.003257328990228013)
#   81               (social ties, 0.0034788658897199525)            (virtual reality, 0.003257328990228013)
#   82  (enterprise social network, 0.0034788658897199...            (pattern mining , 0.003257328990228013)
#   83         (topic discussions, 0.0034788658897199525)                 (heuristics, 0.003257328990228013)
#   84     (specialized companies, 0.0034788658897199525)  (memristor-based neural networks , 0.003257328...
#   85     (international network, 0.0034788658897199525)            (tsallis entropy, 0.003257328990228013)
#   86           (paper describes, 0.0034788658897199525)    (multilevel thresholding, 0.003257328990228013)
#   87             (central italy, 0.0034788658897199525)              (failure cause, 0.003257328990228013)
#   88              (frontal lobe, 0.0034788658897199525)         (recommender system, 0.003257328990228013)
#   89    (inferior frontal gyrus, 0.0034788658897199525)    (interference mitigation, 0.003257328990228013)
#   90            (insula of reil, 0.0034788658897199525)              (bibliometrics, 0.003257328990228013)
#   91    (epilepsy temporal lobe, 0.0034788658897199525)                   (metadata, 0.003257328990228013)
#   92     (parahippocampal gyrus, 0.0034788658897199525)           (area under curve, 0.003257328990228013)
#   93          (precentral gyrus, 0.0034788658897199525)                 (extraction, 0.003257328990228013)
#   94  (lateral occipitotemporal gyrus, 0.00347886588...        (machine translation, 0.003257328990228013)
#   95       (alzheimer's disease, 0.0034788658897199525)             (paper presents, 0.003257328990228013)
#   96          (digital services, 0.0034788658897199525)            (spoken dialogue, 0.003257328990228013)
#   97                    (lobule, 0.0034788658897199525)  (natural language processing, 0.00325732899022...
#   98   (bidirectional long short, 0.003478865889719952)               (stock market, 0.003257328990228013)
#   99          (speech utterances, 0.003478865889719952)  (artificial neural networks, 0.003257328990228...
#  100            (art performance, 0.003478865889719952)                   (training, 0.003257328990228013)

# %% [markdown]
# ## Year 2016

# %%
#View tables for year 2016
tables_metrics_view(2016)
# Out:
# Year: 2016
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1   (artificial neural network, 0.18088480247504138)    (artificial neural network, 0.2537878787878788)
#    2                    (algorithm, 0.1127972850457462)                   (algorithm, 0.17045454545454547)
#    3     (markov decision process, 0.08399585205668857)   (mathematical optimization, 0.12878787878787878)
#    4   (mathematical optimization, 0.08366304503237497)            (nonlinear system, 0.10227272727272728)
#    5                  (experiment, 0.05488670596712487)                  (simulation, 0.09848484848484848)
#    6                    (converge, 0.04199335413859759)           (numerical analysis, 0.0946969696969697)
#    7            (nonlinear system, 0.03191326395551202)     (markov decision process, 0.09090909090909091)
#    8                  (simulation, 0.03132989058731848)     (approximation algorithm, 0.08333333333333334)
#    9                  (iteration, 0.028006996450494835)            (lyapunov fractal, 0.08333333333333334)
#   10          (numerical analysis, 0.02599667642956318)      (reinforcement learning, 0.07196969696969698)
#   11    (approximation algorithm, 0.019457055732258016)                  (experiment, 0.06818181818181818)
#   12                  (data mining, 0.0181401192808037)               (decision list, 0.06818181818181818)
#   13                 (computation, 0.01672333205109096)        (experimental results, 0.06818181818181818)
#   14  (interference (communication), 0.0166498636555...                 (daily basis, 0.06818181818181818)
#   15           (machine learning, 0.015760496867028434)     (diagnostic test results, 0.06818181818181818)
#   16       (fuzzy control system, 0.012723564218552127)              (costs involved, 0.06818181818181818)
#   17            (bellman equation, 0.01258939763269809)          (maximizes outcomes, 0.06818181818181818)
#   18     (reinforcement learning, 0.010932689467518025)              (granting bails, 0.06818181818181818)
#   19  (convolutional neural network, 0.0106104571834...          (potential benefits, 0.06818181818181818)
#   20                 (throughput, 0.010254637631063487)     (minimizes overall costs, 0.06818181818181818)
#   21               (deep learning, 0.00957140784221525)             (novel objective, 0.06818181818181818)
#   22              (sparse matrix, 0.007913280179112941)    (search space effectively, 0.06818181818181818)
#   23      (end-to-end principle, 0.0076590904037371925)      (upper confidence bound, 0.06818181818181818)
#   24           (lyapunov fractal, 0.007140030763790579)     (effective interpretable, 0.06818181818181818)
#   25       (dynamic programming, 0.0067576554224233355)  (leverages customized checks, 0.06818181818181...
#   26      (benchmark (computing), 0.005844781925550711)             (decision makers, 0.06818181818181818)
#   27          (social inequality, 0.005716247720420816)  (asthma patients demonstrate, 0.06818181818181...
#   28  (neural network simulation, 0.005441845745466422)        (maps characteristics, 0.06818181818181818)
#   29                   (big data, 0.005156123977416754)     (recommending treatments, 0.06818181818181818)
#   30  (particle swarm optimization, 0.00515612397741...                    (converge, 0.06439393939393939)
#   31     (support vector machine, 0.005156123977416753)   (neural network simulation, 0.06060606060606061)
#   32            (personalization, 0.005156123977416753)                 (data mining, 0.05681818181818182)
#   33                  (memristor, 0.005156123977416753)            (bellman equation, 0.05303030303030303)
#   34  (particle swarm optimization , 0.0051561239774...       (benchmark (computing), 0.04924242424242424)
#   35  (natural language processing, 0.00515612397741...                       (atari, 0.04924242424242424)
#   36               (apache spark, 0.004511505604661499)              (deep learning, 0.045454545454545456)
#   37         (learning disorders, 0.004177870235633236)                   (big data, 0.045454545454545456)
#   38        (global optimization, 0.004166675494592568)        (global optimization, 0.045454545454545456)
#   39                       (code, 0.004166675494592568)                       (code, 0.045454545454545456)
#   40            (language model, 0.0025379369035562764)            (optimal control, 0.045454545454545456)
#   41                  (test set, 0.0018647270485882379)  (hamilton–jacobi–bellman equation, 0.045454545...
#   42       (interval arithmetic, 0.0017267967146985471)          (marc g. bellemare, 0.045454545454545456)
#   43                  (feedback, 0.0014885501447893434)                (will dabney, 0.045454545454545456)
#   44  (recurrent neural network, 0.0012727982717857082)               (mark rowland, 0.045454545454545456)
#   45                     (atari, 0.0008599826803248863)             (volodymyr mnih, 0.045454545454545456)
#   46  (stochastic gradient descent, 0.00074267275945...             (demis hassabis, 0.045454545454545456)
#   47     (long short-term memory, 0.000688615625955006)                 (rémi munos, 0.045454545454545456)
#   48            (optimal control, 0.000542620310523834)           (hado van hasselt, 0.045454545454545456)
#   49  (scale multimedia retrieval, 0.000374467104505...                   (ben parr, 0.045454545454545456)
#   50  (biological neural networks, 0.000343450637263...               (apache spark, 0.045454545454545456)
#   51           (control theory, 0.00022742776804304622)          (koray kavukcuoglu, 0.045454545454545456)
#   52              (fuzzy logic, 0.00020300636875127023)            (machine learning, 0.04166666666666667)
#   53      (semantic similarity, 0.00020163613319506857)                   (iteration, 0.04166666666666667)
#   54  (hamilton–jacobi–bellman equation, 0.000194707...         (dynamic programming, 0.04166666666666667)
#   55          (structured data, 0.00017283097131005876)                 (requirement, 0.04166666666666667)
#   56           (mnist database, 0.00012290202404270845)  (interference (communication), 0.0416666666666...
#   57  (linear matrix inequality, 9.450836447034172e-05)            (search algorithm, 0.04166666666666667)
#   58           (neural networks, 9.450836447034172e-05)          (brute-force search, 0.04166666666666667)
#   59                (vocabulary, 6.721204439835617e-05)            (iterative method, 0.04166666666666667)
#   60         (criteria decision, 5.761032377001959e-05)       (computer data storage, 0.04166666666666667)
#   61                (hysteresis, 4.128739870184737e-05)        (open-source software, 0.04166666666666667)
#   62                            (bayesian network, 0.0)           (apriori algorithm, 0.04166666666666667)
#   63                         (black bag operation, 0.0)                   (mapreduce, 0.04166666666666667)
#   64                                      (neuron, 0.0)           (social inequality, 0.04166666666666667)
#   65            (biogeography-based optimization , 0.0)                 (fuzzy logic, 0.03787878787878788)
#   66                                 (coefficient, 0.0)             (cognitive radio, 0.03409090909090909)
#   67                   (dropout (neural networks), 0.0)  (particle swarm optimization , 0.0340909090909...
#   68                       (variational principle, 0.0)             (adaptive coding, 0.03409090909090909)
#   69                            (computer science, 0.0)  (ibm systems network architecture, 0.034090909...
#   70                                      (sensor, 0.0)       (centralized computing, 0.03409090909090909)
#   71                            (object detection, 0.0)   (channel state information, 0.03409090909090909)
#   72                     (mapping ambiguous terms, 0.0)    (one-class classification, 0.03409090909090909)
#   73                       (entity disambiguation, 0.0)                 (computation, 0.03409090909090909)
#   74                               (language text, 0.0)              (frequency band, 0.03409090909090909)
#   75                              (knowledge base, 0.0)         (learning disorders, 0.030303030303030304)
#   76              (resource description framework, 0.0)              (formal system, 0.030303030303030304)
#   77                          (paper investigates, 0.0)             (control theory, 0.030303030303030304)
#   78                              (opinion mining, 0.0)              (optimization , 0.030303030303030304)
#   79                                   (fuzzy set, 0.0)                 (benchmark , 0.030303030303030304)
#   80                                (optimization, 0.0)         (genetic algorithm , 0.030303030303030304)
#   81                                 (autoencoder, 0.0)  (exploit (computer security), 0.03030303030303...
#   82                                      (weight, 0.0)             (control system, 0.030303030303030304)
#   83                             (embedded system, 0.0)           (adaptive systems, 0.030303030303030304)
#   84                               (usb on-the-go, 0.0)          (nonlinear systems, 0.030303030303030304)
#   85                  (feedforward neural network, 0.0)            (structured data, 0.026515151515151516)
#   86                                 (requirement, 0.0)       (fuzzy control system, 0.026515151515151516)
#   87                                 (time delays, 0.0)  (scale multimedia retrieval, 0.026515151515151...
#   88                           (sample complexity, 0.0)                   (feedback, 0.026515151515151516)
#   89                                    (training, 0.0)  (biological neural networks, 0.026515151515151...
#   90                          (time-varying delay, 0.0)    (mapping ambiguous terms, 0.022727272727272728)
#   91                             (cognitive radio, 0.0)      (entity disambiguation, 0.022727272727272728)
#   92                          (multi-agent system, 0.0)              (language text, 0.022727272727272728)
#   93                            (search algorithm, 0.0)             (knowledge base, 0.022727272727272728)
#   94                          (brute-force search, 0.0)  (resource description framework, 0.02272727272...
#   95                            (iterative method, 0.0)   (linear matrix inequality, 0.022727272727272728)
#   96                       (computer data storage, 0.0)            (neural networks, 0.022727272727272728)
#   97                        (open-source software, 0.0)  (distribution (mathematics), 0.022727272727272...
#   98                           (apriori algorithm, 0.0)        (apparatus including, 0.022727272727272728)
#   99                                   (mapreduce, 0.0)            (methods systems, 0.022727272727272728)
#  100                                  (subnetwork, 0.0)                 (scale data, 0.022727272727272728)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1  (artificial neural network, 0.030776951722675736)    (artificial neural network, 0.0476310695388353)
#    2  (mathematical optimization, 0.019253157275877005)                   (algorithm, 0.02439674973425414)
#    3                   (algorithm, 0.01645283963846324)            (nonlinear system, 0.01856052594894154)
#    4                 (simulation, 0.010510503926135636)   (mathematical optimization, 0.01720741546028665)
#    5           (nonlinear system, 0.009559254858721326)           (lyapunov fractal, 0.015507664142473265)
#    6     (reinforcement learning, 0.008791169984306235)                 (simulation, 0.015447828104336626)
#    7                 (experiment, 0.008556952339618578)          (numerical analysis, 0.01173335242780944)
#    8     (approximation algorithm, 0.00841361205474658)    (approximation algorithm, 0.009647840592577292)
#    9           (numerical analysis, 0.0083648260871716)  (neural network simulation, 0.008440737230477653)
#   10  (neural network simulation, 0.007916371673836457)           (machine learning, 0.008267428850275958)
#   11          (lyapunov fractal, 0.0076757193024569285)              (deep learning, 0.008247643443211359)
#   12                   (converge, 0.007592941888444286)     (reinforcement learning, 0.008086916415876744)
#   13                (data mining, 0.007128074287957205)            (optimal control, 0.007708542115915764)
#   14  (scale multimedia retrieval, 0.006958947219305...                (experiment, 0.0076272753937624655)
#   15                (computation, 0.006791561268539869)          (social inequality, 0.007113753402604306)
#   16      (benchmark (computing), 0.006494185300107196)  (hamilton–jacobi–bellman equation, 0.007100894...
#   17   (markov decision process, 0.0064835623462323935)  (scale multimedia retrieval, 0.006877319436270...
#   18          (bellman equation, 0.0061917180576221515)                (data mining, 0.006314456934932012)
#   19        (global optimization, 0.006072221524992236)                  (converge, 0.0062533128240931405)
#   20                       (code, 0.006072221524992236)      (benchmark (computing), 0.006072700707465152)
#   21              (deep learning, 0.005979898978568005)                (computation, 0.005471718558700602)
#   22           (machine learning, 0.005946357517591986)         (criteria decision, 0.0054110179991453495)
#   23                  (iteration, 0.005923510007300621)                   (big data, 0.005338735601195543)
#   24          (social inequality, 0.005767171759125581)          (bellman equation, 0.0053319623318777145)
#   25          (criteria decision, 0.005756263815105336)               (apache spark, 0.005311742623817563)
#   26       (semantic similarity, 0.0057450441882139335)        (semantic similarity, 0.005215827914133782)
#   27                      (atari, 0.005664007250993897)    (markov decision process, 0.005077477913433451)
#   28  (hamilton–jacobi–bellman equation, 0.005595827...            (structured data, 0.004967259265546479)
#   29                   (big data, 0.005529559449097847)                       (code, 0.004727324119263739)
#   30           (marc g. bellemare, 0.00539118247327788)        (global optimization, 0.004727324119263738)
#   31                 (will dabney, 0.00539118247327788)               (requirement, 0.0047198932238308195)
#   32                (mark rowland, 0.00539118247327788)          (search algorithm, 0.0047198932238308195)
#   33              (volodymyr mnih, 0.00539118247327788)        (brute-force search, 0.0047198932238308195)
#   34              (demis hassabis, 0.00539118247327788)          (iterative method, 0.0047198932238308195)
#   35                  (rémi munos, 0.00539118247327788)     (computer data storage, 0.0047198932238308195)
#   36            (hado van hasselt, 0.00539118247327788)      (open-source software, 0.0047198932238308195)
#   37                    (ben parr, 0.00539118247327788)         (apriori algorithm, 0.0047198932238308195)
#   38           (koray kavukcuoglu, 0.00539118247327788)                 (mapreduce, 0.0047198932238308195)
#   39               (apache spark, 0.005224808232162471)            (neural networks, 0.004581681365574596)
#   40            (structured data, 0.005166104918425567)            (image retrieval, 0.004555933630356572)
#   41  (particle swarm optimization , 0.0051162014982...               (hash coding, 0.0045559336303565715)
#   42        (learning disorders, 0.0050939283108808195)  (separate quantization step, 0.004555933630356...
#   43                (requirement, 0.004723251811095056)                (data pairs, 0.0045559336303565715)
#   44           (search algorithm, 0.004723251811095056)                     (atari, 0.0043571465744603926)
#   45         (brute-force search, 0.004723251811095056)                   (iteration, 0.00421982474753947)
#   46           (iterative method, 0.004723251811095056)        (dynamic programming, 0.004216630797360768)
#   47      (computer data storage, 0.004723251811095056)  (interference (communication), 0.0042153688391...
#   48       (open-source software, 0.004723251811095056)  (convolutional neural network, 0.0042060113799...
#   49          (apriori algorithm, 0.004723251811095056)        (learning disorders, 0.0041673260023778426)
#   50                  (mapreduce, 0.004723251811095056)   (phase congruency concept, 0.004027648047824057)
#   51  (convolutional neural network, 0.0046542459617...             (signal conveys, 0.004027648047824056)
#   52  (separate quantization step, 0.004586945210678...   (adversary (cryptography), 0.004018715243257545)
#   53                (hash coding, 0.004586945210678161)                   (training, 0.004018715243257544)
#   54                 (data pairs, 0.004586945210678161)    (mapping ambiguous terms, 0.004008702522399543)
#   55            (image retrieval, 0.004586945210678161)      (entity disambiguation, 0.004008702522399543)
#   56        (dynamic programming, 0.004446747326696703)              (language text, 0.004008702522399543)
#   57                (fuzzy logic, 0.004378225914703441)             (knowledge base, 0.004008702522399543)
#   58            (optimal control, 0.004367758397704858)  (resource description framework, 0.00400870252...
#   59              (optimization , 0.004237843992085328)          (textual documents, 0.004008702522399543)
#   60                 (benchmark , 0.004237843992085328)          (criterion weights, 0.003983790628072363)
#   61         (genetic algorithm , 0.004237843992085328)           (criterion values, 0.003983790628072363)
#   62  (exploit (computer security), 0.00423784399208...  (search space effectively, 0.0039010410166793034)
#   63                 (throughput, 0.004201449326375358)    (upper confidence bound, 0.0039010410166793034)
#   64  (resource description framework, 0.00416917656...   (effective interpretable, 0.0039010410166793034)
#   65    (mapping ambiguous terms, 0.004169176561108057)  (leverages customized checks, 0.00390104101667...
#   66      (entity disambiguation, 0.004169176561108057)           (decision makers, 0.0039010410166793034)
#   67              (language text, 0.004169176561108057)  (asthma patients demonstrate, 0.00390104101667...
#   68             (knowledge base, 0.004169176561108057)      (maps characteristics, 0.0039010410166793034)
#   69          (textual documents, 0.004169176561108057)   (recommending treatments, 0.0039010410166793034)
#   70       (fuzzy control system, 0.004159766305165297)              (decision list, 0.003901041016679303)
#   71     (upper confidence bound, 0.004128887941677368)       (experimental results, 0.003901041016679303)
#   72    (effective interpretable, 0.004128887941677368)                (daily basis, 0.003901041016679303)
#   73  (leverages customized checks, 0.00412888794167...    (diagnostic test results, 0.003901041016679303)
#   74            (decision makers, 0.004128887941677368)             (costs involved, 0.003901041016679303)
#   75  (asthma patients demonstrate, 0.00412888794167...         (maximizes outcomes, 0.003901041016679303)
#   76       (maps characteristics, 0.004128887941677368)             (granting bails, 0.003901041016679303)
#   77    (recommending treatments, 0.004128887941677368)         (potential benefits, 0.003901041016679303)
#   78             (decision list, 0.0041288879416773675)    (minimizes overall costs, 0.003901041016679303)
#   79      (experimental results, 0.0041288879416773675)            (novel objective, 0.003901041016679303)
#   80               (daily basis, 0.0041288879416773675)      (fuzzy control system, 0.0038878598183518407)
#   81   (diagnostic test results, 0.0041288879416773675)  (particle swarm optimization , 0.0038784891887...
#   82            (costs involved, 0.0041288879416773675)  (dense vector representations, 0.0037735849056...
#   83        (maximizes outcomes, 0.0041288879416773675)     (distributional models, 0.0037735849056603783)
#   84            (granting bails, 0.0041288879416773675)    (semantic web ecosystem, 0.0037735849056603783)
#   85        (potential benefits, 0.0041288879416773675)    (contextual information, 0.0037735849056603783)
#   86   (minimizes overall costs, 0.0041288879416773675)            (human readable, 0.0037735849056603783)
#   87           (novel objective, 0.0041288879416773675)           (easily embedded, 0.0037735849056603783)
#   88  (search space effectively, 0.0041288879416773675)        (apparatus including, 0.003773584905660378)
#   89  (dense vector representations, 0.0039246467817...            (methods systems, 0.003773584905660378)
#   90       (distributional models, 0.00392464678178964)                 (scale data, 0.003773584905660378)
#   91      (semantic web ecosystem, 0.00392464678178964)     (various linguisticxa0…, 0.003773584905660378)
#   92      (contextual information, 0.00392464678178964)             (mental illness, 0.003773584905660378)
#   93              (human readable, 0.00392464678178964)  (based counseling conversations, 0.00377358490...
#   94             (easily embedded, 0.00392464678178964)           (labeled outcomes, 0.003773584905660378)
#   95           (object detection, 0.003924646781789639)       (effective treatments, 0.003773584905660378)
#   96         (paper investigates, 0.003924646781789639)  (methods includes receiving, 0.003773584905660...
#   97             (opinion mining, 0.003924646781789639)               (deep network, 0.003773584905660378)
#   98              (agent systems, 0.003924646781789639)           (input comprising, 0.003773584905660378)
#   99             (online classes, 0.003924646781789639)              (storage media, 0.003773584905660378)
#  100        (apparatus including, 0.003924646781789639)           (programs encoded, 0.003773584905660378)

# %% [markdown]
# ## Year 2017

# %%
#View tables for year 2017
tables_metrics_view(2017)
# Out:
# Year: 2017
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1   (artificial neural network, 0.12398011904617694)   (artificial neural network, 0.22905027932960895)
#    2     (mathematical optimization, 0.089578199783559)   (mathematical optimization, 0.15083798882681565)
#    3                   (algorithm, 0.07561384840126385)                   (simulation, 0.1229050279329609)
#    4                  (simulation, 0.05335108480300412)                   (algorithm, 0.11731843575418995)
#    5             (machine learning, 0.0360094574519281)    (neural network simulation, 0.0893854748603352)
#    6                  (throughput, 0.02403597552876186)            (lyapunov fractal, 0.08379888268156425)
#    7            (cluster analysis, 0.02300539287876124)            (cluster analysis, 0.08379888268156425)
#    8                 (experiment, 0.015679551545572434)           (social inequality, 0.08379888268156425)
#    9            (cognitive radio, 0.012240286234385788)          (swarm intelligence, 0.07262569832402235)
#   10       (adversarial examples, 0.012240286234385788)                  (experiment, 0.07262569832402235)
#   11          (firefly algorithm, 0.012177515535747911)                   (throughput, 0.0670391061452514)
#   12     (semiconductor industry, 0.010917634329163985)             (nonlinear system, 0.0670391061452514)
#   13            (lyapunov fractal, 0.00981113492412218)           (numerical analysis, 0.0670391061452514)
#   14   (neural network simulation, 0.00851364963787285)         (jensen's inequality, 0.06145251396648045)
#   15         (swarm intelligence, 0.007142782415834955)      (semiconductor industry, 0.06145251396648045)
#   16  (particle swarm optimization, 0.00636236486011...                (approximation, 0.0558659217877095)
#   17            (cloud computing, 0.006151528466511832)               (control theory, 0.0558659217877095)
#   18     (reinforcement learning, 0.006151528466511832)        (data synchronization, 0.05027932960893855)
#   19          (nonlinear system, 0.0059143953716022735)  (sawtooth (cellular automaton), 0.050279329608...
#   20              (approximation, 0.004500947512421334)  (sampling - surgical action, 0.05027932960893855)
#   21        (numerical analysis, 0.0028718341897050075)                   (input lag, 0.05027932960893855)
#   22          (triangular matrix, 0.002596963948590536)  (sampling (signal processing), 0.0502793296089...
#   23  (convolutional neural network, 0.0024761546072...           (triangular matrix, 0.05027932960893855)
#   24             (deep learning, 0.0024256391402207723)        (benchmark (computing), 0.0446927374301676)
#   25             (sparse matrix, 0.0022806687171761557)  (particle swarm optimization, 0.0446927374301676)
#   26  (natural language processing, 0.00182722514653...            (firefly algorithm, 0.0446927374301676)
#   27           (computer vision, 0.0018272251465396912)            (machine learning, 0.03910614525139665)
#   28               (computation, 0.0017042742860331206)                    (feedback, 0.03910614525139665)
#   29            (control theory, 0.0015852347951879182)     (recurrent neural network, 0.0335195530726257)
#   30         (social inequality, 0.0012439060113405727)                (deep learning, 0.0335195530726257)
#   31           (link prediction, 0.0006277069863787583)               (network packet, 0.0335195530726257)
#   32                  (feedback, 0.0004994321532913946)                (sparse matrix, 0.0335195530726257)
#   33     (benchmark (computing), 0.0003905732359690051)                    (heuristic, 0.0335195530726257)
#   34           (markov process, 0.00031385349318937915)          (swarm intelligence , 0.0335195530726257)
#   35             (art baselines, 0.0001883120959136275)    (wireless sensor networks , 0.0335195530726257)
#   36              (sugeno fuzzy, 0.0001883120959136275)                    (inference, 0.0335195530726257)
#   37              (affine model, 0.0001883120959136275)  (firefly (cache coherence protocol), 0.0335195...
#   38        (carefully reviewed, 0.0001883120959136275)        (premature convergence, 0.0335195530726257)
#   39  (recurrent neural network, 0.00015692674659468...          (statistical cluster, 0.0335195530726257)
#   40       (jensen's inequality, 0.0001537882116627958)                      (routing, 0.0335195530726257)
#   41                   (sensor, 0.00014646496348837696)                 (computation, 0.02793296089385475)
#   42  (generative adversarial networks, 0.0001255413...    (linear matrix inequality, 0.02793296089385475)
#   43         (generative model, 0.00012554139727575167)                    (converge, 0.02793296089385475)
#   44          (genetic algorithm, 9.67714937333919e-05)                (sugeno fuzzy, 0.02793296089385475)
#   45            (time complexity, 7.06170359676103e-05)             (link prediction, 0.02793296089385475)
#   46         (hopfield network, 2.0923566212625278e-05)  (convolutional neural network, 0.0279329608938...
#   47                           (related questions, 0.0)  (natural language processing, 0.02793296089385...
#   48                                   (step high, 0.0)             (computer vision, 0.02793296089385475)
#   49                        (data synchronization, 0.0)                (affine model, 0.02793296089385475)
#   50               (sawtooth (cellular automaton), 0.0)                (art baselines, 0.0223463687150838)
#   51                  (sampling - surgical action, 0.0)                       (sensor, 0.0223463687150838)
#   52                                   (input lag, 0.0)      (approximation algorithm, 0.0223463687150838)
#   53                    (linear matrix inequality, 0.0)                  (binary code, 0.0223463687150838)
#   54                (sampling (signal processing), 0.0)              (cognitive radio, 0.0223463687150838)
#   55                (human language understanding, 0.0)             (hopfield network, 0.0223463687150838)
#   56                                    (imagenet, 0.0)         (adversarial examples, 0.0223463687150838)
#   57                                   (recursion, 0.0)               (markov process, 0.0223463687150838)
#   58                              (network packet, 0.0)           (carefully reviewed, 0.0223463687150838)
#   59                                    (converge, 0.0)                   (recursion, 0.01675977653631285)
#   60                        (geometric operations, 0.0)              (paper proposes, 0.01675977653631285)
#   61                           (initial condition, 0.0)             (nonlinear plant, 0.01675977653631285)
#   62                                  (polynomial, 0.0)         (application relying, 0.01675977653631285)
#   63                              (paper proposes, 0.0)           (dynamic artifacts, 0.01675977653631285)
#   64                             (nonlinear plant, 0.0)   (semantic web technologies, 0.01675977653631285)
#   65                              (shape features, 0.0)           (genetic algorithm, 0.01675977653631285)
#   66                        (radio access network, 0.0)             (useful criteria, 0.01675977653631285)
#   67                         (high- and low-level, 0.0)        (derived analytically, 0.01675977653631285)
#   68                     (approximation algorithm, 0.0)        (intermittent control, 0.01675977653631285)
#   69                         (application relying, 0.0)                     (encoder, 0.01675977653631285)
#   70                           (dynamic artifacts, 0.0)            (book constitutes, 0.01675977653631285)
#   71                   (semantic web technologies, 0.0)      (topical sections named, 0.01675977653631285)
#   72                                 (binary code, 0.0)        (refereed proceedings, 0.01675977653631285)
#   73                            (samuel j leffler, 0.0)                 (controllers, 0.01675977653631285)
#   74                            (knowledge graphs, 0.0)          (agent architecture, 0.01675977653631285)
#   75                      (factorization machines, 0.0)                 (game engine, 0.01675977653631285)
#   76                        (discriminative model, 0.0)        (server message block, 0.01675977653631285)
#   77                            (anatomy regional, 0.0)   (association rule learning, 0.01675977653631285)
#   78                           (skeleton sequence, 0.0)  (interference (communication), 0.0167597765363...
#   79                             (useful criteria, 0.0)               (neural coding, 0.01675977653631285)
#   80                        (derived analytically, 0.0)  (global exponential stability, 0.0167597765363...
#   81                        (intermittent control, 0.0)                 (convolution, 0.01675977653631285)
#   82                                     (encoder, 0.0)       (diverse ranking model, 0.01675977653631285)
#   83                            (book constitutes, 0.0)  (search result diversification, 0.016759776536...
#   84                      (topical sections named, 0.0)                 (autoencoder, 0.01675977653631285)
#   85                        (refereed proceedings, 0.0)    (parametric uncertainties, 0.01675977653631285)
#   86                            (gradient descent, 0.0)              (single channel, 0.01675977653631285)
#   87                                 (controllers, 0.0)      (target assignment pick, 0.01675977653631285)
#   88                              (control system, 0.0)  (automatic speech recognition, 0.0167597765363...
#   89                          (agent architecture, 0.0)              (baxter (robot), 0.01675977653631285)
#   90                                 (game engine, 0.0)                 (microblogs , 0.01675977653631285)
#   91                        (server message block, 0.0)         (sentiment analysis , 0.01675977653631285)
#   92               (exponential family embeddings, 0.0)            (frame semantics , 0.01675977653631285)
#   93                             (word embeddings, 0.0)      (scheduling (computing), 0.01675977653631285)
#   94                   (association rule learning, 0.0)  (sensitivity and specificity, 0.01675977653631...
#   95                (interference (communication), 0.0)          (critical operation, 0.01675977653631285)
#   96                               (neural coding, 0.0)  (aperiodically intermittent control, 0.0167597...
#   97                (global exponential stability, 0.0)                 (interaction, 0.01675977653631285)
#   98                                 (convolution, 0.0)            (spectral leakage, 0.01675977653631285)
#   99                                   (heuristic, 0.0)    (significantly outperform, 0.01675977653631285)
#  100               (outline of object recognition, 0.0)   (strategy elegantly solves, 0.01675977653631285)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1   (artificial neural network, 0.02944856008187813)  (artificial neural network, 0.039058407260380665)
#    2   (mathematical optimization, 0.02311930106497762)  (mathematical optimization, 0.028863584443819767)
#    3                  (algorithm, 0.020659677610066592)                  (algorithm, 0.025187093182456818)
#    4                 (simulation, 0.017039754976185862)                 (simulation, 0.021256519446333548)
#    5            (link prediction, 0.015875860894046436)            (link prediction, 0.015725095392545126)
#    6           (cluster analysis, 0.013309721683484748)  (neural network simulation, 0.015597487902786806)
#    7                 (throughput, 0.011354575417898187)            (cluster analysis, 0.01429546456061907)
#    8          (swarm intelligence, 0.01133479958768192)          (numerical analysis, 0.01382253520015752)
#    9                 (experiment, 0.010900270845477986)           (lyapunov fractal, 0.013688721858169483)
#   10  (neural network simulation, 0.010788985540289748)          (social inequality, 0.013475754573221052)
#   11           (lyapunov fractal, 0.010256948686268018)           (nonlinear system, 0.012846603370325501)
#   12            (nonlinear system, 0.01003566190744715)                 (experiment, 0.011526186959057888)
#   13     (semiconductor industry, 0.009854317640593604)            (machine learning, 0.01134644610948407)
#   14          (social inequality, 0.009485558136823254)                 (throughput, 0.010385282759770078)
#   15           (machine learning, 0.009231820369848237)          (swarm intelligence, 0.00958887907043657)
#   16              (approximation, 0.008574033929971097)         (carefully reviewed, 0.008801846114972717)
#   17       (adversarial examples, 0.008357123095408907)           (generative model, 0.008774542245753263)
#   18          (firefly algorithm, 0.008210728909117636)     (semiconductor industry, 0.008697122750800645)
#   19              (art baselines, 0.007965672852518499)  (particle swarm optimization, 0.00819373038099...
#   20         (carefully reviewed, 0.007965672852518497)               (sugeno fuzzy, 0.008058667472882626)
#   21             (control theory, 0.007860064000449073)               (affine model, 0.008058667472882626)
#   22              (sparse matrix, 0.007767887849973472)          (triangular matrix, 0.007986772512225728)
#   23               (sugeno fuzzy, 0.007755997458008413)             (control theory, 0.007955148833367814)
#   24               (affine model, 0.007755997458008413)              (art baselines, 0.007890441497781595)
#   25         (numerical analysis, 0.007737234891336784)      (benchmark (computing), 0.007816130944779906)
#   26        (jensen's inequality, 0.007701853753775231)       (adversarial examples, 0.006878013652910723)
#   27          (triangular matrix, 0.007674870089787449)             (markov process, 0.006552424862884007)
#   28  (particle swarm optimization, 0.00755959592560...                  (heuristic, 0.006227135425083904)
#   29  (generative adversarial networks, 0.0072812429...                  (inference, 0.006227135425083904)
#   30           (generative model, 0.007281242927846443)        (statistical cluster, 0.006227135425083904)
#   31      (benchmark (computing), 0.006974537977381636)  (natural language processing, 0.00622074472445...
#   32       (data synchronization, 0.006929647988419376)            (computer vision, 0.006220744724458313)
#   33  (sawtooth (cellular automaton), 0.006929647988...              (approximation, 0.006150635892435006)
#   34  (sampling - surgical action, 0.006929647988419...                   (feedback, 0.006130001569605401)
#   35                  (input lag, 0.006929647988419376)  (convolutional neural network, 0.0060815562814...
#   36  (sampling (signal processing), 0.0069296479884...              (network packet, 0.00598607861396279)
#   37             (markov process, 0.006821859332870115)         (swarm intelligence , 0.00598607861396279)
#   38            (cognitive radio, 0.006430358738912778)   (wireless sensor networks , 0.00598607861396279)
#   39                   (feedback, 0.006027529987300935)                     (routing, 0.00598607861396279)
#   40           (book constitutes, 0.005847655903963691)          (firefly algorithm, 0.005944697027001258)
#   41     (topical sections named, 0.005847655903963691)        (jensen's inequality, 0.005905280957689574)
#   42       (refereed proceedings, 0.005847655903963691)       (discriminative model, 0.005805573939260232)
#   43      (diverse ranking model, 0.005847655903963691)      (diverse ranking model, 0.005792428042652142)
#   44  (search result diversification, 0.005847655903...  (search result diversification, 0.005792428042...
#   45   (significantly outperform, 0.005847655903963691)   (significantly outperform, 0.005792428042652142)
#   46  (firefly (cache coherence protocol), 0.0057371...              (deep learning, 0.005658898174440939)
#   47     (premature convergence, 0.0057371046931156515)          (related questions, 0.005555555555555556)
#   48                  (heuristic, 0.005709281400790521)                  (step high, 0.005555555555555556)
#   49                  (inference, 0.005709281400790521)  (human language understanding, 0.0055555555555...
#   50        (statistical cluster, 0.005709281400790521)                   (imagenet, 0.005555555555555556)
#   51          (related questions, 0.005608524957936062)       (geometric operations, 0.005555555555555556)
#   52                  (step high, 0.005608524957936062)             (shape features, 0.005555555555555556)
#   53  (human language understanding, 0.0056085249579...       (radio access network, 0.005555555555555556)
#   54                   (imagenet, 0.005608524957936062)        (application relying, 0.005555555555555556)
#   55             (shape features, 0.005608524957936062)          (dynamic artifacts, 0.005555555555555556)
#   56       (radio access network, 0.005608524957936062)  (semantic web technologies, 0.005555555555555556)
#   57           (knowledge graphs, 0.005608524957936062)           (knowledge graphs, 0.005555555555555556)
#   58     (factorization machines, 0.005608524957936062)     (factorization machines, 0.005555555555555556)
#   59          (skeleton sequence, 0.005608524957936062)          (skeleton sequence, 0.005555555555555556)
#   60  (exponential family embeddings, 0.005608524957...            (useful criteria, 0.005555555555555556)
#   61            (word embeddings, 0.005608524957936062)       (derived analytically, 0.005555555555555556)
#   62          (statistical model, 0.005608524957936062)       (intermittent control, 0.005555555555555556)
#   63       (experimental results, 0.005608524957936062)         (agent architecture, 0.005555555555555556)
#   64       (deep neural networks, 0.005608524957936062)                (game engine, 0.005555555555555556)
#   65  (algorithm design and analysis, 0.005608524957...       (server message block, 0.005555555555555556)
#   66  (electronic communications, 0.005608524957936062)  (exponential family embeddings, 0.005555555555...
#   67             (paper presents, 0.005608524957936062)            (word embeddings, 0.005555555555555556)
#   68              (level process, 0.005608524957936062)          (statistical model, 0.005555555555555556)
#   69  (word sense disambiguation, 0.005608524957936062)             (single channel, 0.005555555555555556)
#   70             (mnist database, 0.005608524957936062)     (target assignment pick, 0.005555555555555556)
#   71            (extracted based, 0.005608524957936062)  (automatic speech recognition, 0.0055555555555...
#   72   (mobile network operators, 0.005608524957936062)       (experimental results, 0.005555555555555556)
#   73             (search engines, 0.005608524957936062)       (deep neural networks, 0.005555555555555556)
#   74  (order feature interactions, 0.005608524957936...  (algorithm design and analysis, 0.005555555555...
#   75       (temporal information, 0.005608524957936062)  (electronic communications, 0.005555555555555556)
#   76          (powerful approach, 0.005608524957936062)             (paper presents, 0.005555555555555556)
#   77                       (stan, 0.005608524957936062)                (microblogs , 0.005555555555555556)
#   78              (mnist cifar10, 0.005608524957936062)        (sentiment analysis , 0.005555555555555556)
#   79      (prediction algorithms, 0.005608524957936062)           (frame semantics , 0.005555555555555556)
#   80  (noncanonical communication, 0.005608524957936...              (level process, 0.005555555555555556)
#   81                   (http url, 0.005608524957936062)  (word sense disambiguation, 0.005555555555555556)
#   82       (application relying, 0.0056085249579360605)             (mnist database, 0.005555555555555556)
#   83         (dynamic artifacts, 0.0056085249579360605)         (utilize arithmetic, 0.005555555555555556)
#   84  (semantic web technologies, 0.0056085249579360...            (extracted based, 0.005555555555555556)
#   85           (useful criteria, 0.0056085249579360605)   (mobile network operators, 0.005555555555555556)
#   86      (derived analytically, 0.0056085249579360605)         (critical operation, 0.005555555555555556)
#   87      (intermittent control, 0.0056085249579360605)             (search engines, 0.005555555555555556)
#   88        (agent architecture, 0.0056085249579360605)  (order feature interactions, 0.005555555555555...
#   89               (game engine, 0.0056085249579360605)       (temporal information, 0.005555555555555556)
#   90      (server message block, 0.0056085249579360605)  (aperiodically intermittent control, 0.0055555...
#   91            (single channel, 0.0056085249579360605)                (interaction, 0.005555555555555556)
#   92    (target assignment pick, 0.0056085249579360605)          (powerful approach, 0.005555555555555556)
#   93  (automatic speech recognition, 0.0056085249579...                       (stan, 0.005555555555555556)
#   94               (microblogs , 0.0056085249579360605)  (strategy elegantly solves, 0.005555555555555556)
#   95       (sentiment analysis , 0.0056085249579360605)              (mnist cifar10, 0.005555555555555556)
#   96          (frame semantics , 0.0056085249579360605)      (prediction algorithms, 0.005555555555555556)
#   97        (critical operation, 0.0056085249579360605)  (noncanonical communication, 0.005555555555555...
#   98  (aperiodically intermittent control, 0.0056085...                   (http url, 0.005555555555555556)
#   99               (interaction, 0.0056085249579360605)                  (babelnet , 0.005555555555555556)
#  100  (strategy elegantly solves, 0.0056085249579360...  (generative adversarial networks, 0.0053055371...

# %% [markdown]
# ## Year 2018

# %%
#View tables for year 2018
tables_metrics_view(2018)
# Out:
# Year: 2018
#
# Rank                                   Node Betweenness                                  Degree Centrality
#    1   (artificial neural network, 0.08236257882285192)   (artificial neural network, 0.17171717171717174)
#    2   (mathematical optimization, 0.05706444604555304)   (mathematical optimization, 0.10606060606060606)
#    3                 (simulation, 0.048352249241931364)                  (simulation, 0.09595959595959597)
#    4               (deep learning, 0.03778663311427503)          (numerical analysis, 0.09090909090909091)
#    5            (machine learning, 0.03270622738396927)        (adversarial examples, 0.08080808080808081)
#    6         (numerical analysis, 0.029963768886287594)            (lyapunov fractal, 0.07575757575757576)
#    7                  (algorithm, 0.021292919850834015)           (social inequality, 0.07070707070707072)
#    8  (interference (communication), 0.0136732906304...                   (algorithm, 0.06565656565656566)
#    9       (adversarial examples, 0.012664718248474593)            (nonlinear system, 0.05555555555555556)
#   10           (lyapunov fractal, 0.011960009360861723)       (benchmark (computing), 0.05555555555555556)
#   11    (telecommunications link, 0.009332078167415716)            (machine learning, 0.05555555555555556)
#   12       (experimental results, 0.009178075167922885)     (machine learning models, 0.05555555555555556)
#   13          (social inequality, 0.007548475384192965)                    (converge, 0.05555555555555556)
#   14           (nonlinear system, 0.006533254381775425)  (interference (communication), 0.0555555555555...
#   15       (deep neural networks, 0.006460544531610522)               (vision models, 0.05555555555555556)
#   16  (particle swarm optimization, 0.00574526995846...            (known parameters, 0.05555555555555556)
#   17      (benchmark (computing), 0.005689795087580045)  (transfer adversarial examples, 0.055555555555...
#   18                 (experiment, 0.005326653042389084)               (open question, 0.05555555555555556)
#   19          (anomaly detection, 0.004614674665436087)  (leveraging recent techniques, 0.0555555555555...
#   20     (differential evolution, 0.004614674665436087)          (unknown parameters, 0.05555555555555556)
#   21                  (numerous, 0.0042395862170195526)            (similar mistakes, 0.05555555555555556)
#   22        (smart battery system, 0.00350996583929074)               (make mistakes, 0.05555555555555556)
#   23                   (converge, 0.003149876154029361)                  (school bus, 0.05555555555555556)
#   24              (deep networks, 0.002845716043685587)               (small changes, 0.05555555555555556)
#   25      (training distribution, 0.002845716043685587)                    (numerous, 0.05050505050505051)
#   26             (loss function, 0.0016871641237123471)     (telecommunications link, 0.05050505050505051)
#   27      (optimization problem, 0.0016871641237123471)            (time complexity, 0.045454545454545456)
#   28           (time complexity, 0.0015998290109965239)              (loss function, 0.045454545454545456)
#   29           (cognitive radio, 0.0011222808138667238)              (deep learning, 0.045454545454545456)
#   30    (reinforcement learning, 0.0011222808138667238)       (optimization problem, 0.045454545454545456)
#   31  (neural network simulation, 0.0008460236886632...            (anatomical layer, 0.04040404040404041)
#   32  (linear matrix inequality, 0.0003895948519852534)       (biologic preservation, 0.04040404040404041)
#   33          (iterative method, 8.545693824881643e-05)            (data compression, 0.04040404040404041)
#   34                (multi-user, 8.545693824881643e-05)  (prime-factor fft algorithm, 0.04040404040404041)
#   35            (optimization , 2.5637081474644928e-05)  (predictive failure analysis, 0.04040404040404...
#   36      (swarm intelligence , 2.5637081474644928e-05)            (iterative method, 0.04040404040404041)
#   37                      (semiconductor industry, 0.0)               (deep networks, 0.04040404040404041)
#   38                              (spin structure, 0.0)       (training distribution, 0.04040404040404041)
#   39                     (analyze orbital effects, 0.0)        (smart battery system, 0.04040404040404041)
#   40                        (plane magnetic field, 0.0)                  (multi-user, 0.04040404040404041)
#   41                             (conduction band, 0.0)    (linear matrix inequality, 0.03535353535353536)
#   42                    (dimensional electron gas, 0.0)   (neural network simulation, 0.03535353535353536)
#   43                          (cluster consensus , 0.0)        (deep neural networks, 0.03535353535353536)
#   44                           (leader-following , 0.0)                        (mimo, 0.03535353535353536)
#   45                     (machine learning models, 0.0)  (convolutional neural network, 0.0353535353535...
#   46                       (numerical simulations, 0.0)      (analysis of algorithms, 0.03535353535353536)
#   47                            (anatomical layer, 0.0)      (multitier architecture, 0.03535353535353536)
#   48                       (biologic preservation, 0.0)   (closed-circuit television, 0.03535353535353536)
#   49                            (data compression, 0.0)             (embedded system, 0.03535353535353536)
#   50                  (prime-factor fft algorithm, 0.0)              (frequency band, 0.03535353535353536)
#   51                 (predictive failure analysis, 0.0)  (computational complexity theory, 0.0353535353...
#   52                (particle swarm optimization , 0.0)  (particle swarm optimization, 0.03030303030303...
#   53                        (end-to-end principle, 0.0)  (memristor-based switching networks , 0.030303...
#   54                             (radio frequency, 0.0)                  (memristor, 0.030303030303030304)
#   55                            (spectral density, 0.0)           (simple baselines, 0.030303030303030304)
#   56                (many-objective optimization , 0.0)        (supervised learning, 0.030303030303030304)
#   57                          (nonlinear dynamics, 0.0)   (standard benchmark tasks, 0.030303030303030304)
#   58                                    (new data, 0.0)         (powerful framework, 0.030303030303030304)
#   59                 (driven programming paradigm, 0.0)  (leveraging unlabeled data, 0.030303030303030304)
#   60                          (critical scenarios, 0.0)  (correctness (computer science), 0.03030303030...
#   61                               (training data, 0.0)  (recently proven successful, 0.030303030303030...
#   62                        (temporal concurrency, 0.0)             (spin structure, 0.025252525252525256)
#   63                        (semantically related, 0.0)    (analyze orbital effects, 0.025252525252525256)
#   64                          (knowledge transfer, 0.0)       (plane magnetic field, 0.025252525252525256)
#   65                         (fixed-point theorem, 0.0)            (conduction band, 0.025252525252525256)
#   66                      (scheduling (computing), 0.0)   (dimensional electron gas, 0.025252525252525256)
#   67                           (temporal boundary, 0.0)                   (new data, 0.025252525252525256)
#   68                                (action class, 0.0)  (driven programming paradigm, 0.02525252525252...
#   69                              (addressing tal, 0.0)         (critical scenarios, 0.025252525252525256)
#   70                             (untrimmed video, 0.0)              (training data, 0.025252525252525256)
#   71                (temporal action localization, 0.0)          (temporal boundary, 0.025252525252525256)
#   72               (cross-validation (statistics), 0.0)               (action class, 0.025252525252525256)
#   73                         (computer simulation, 0.0)             (addressing tal, 0.025252525252525256)
#   74                             (neural networks, 0.0)            (untrimmed video, 0.025252525252525256)
#   75                             (system dynamics, 0.0)  (temporal action localization, 0.0252525252525...
#   76                               (data manifold, 0.0)            (cognitive radio, 0.025252525252525256)
#   77                               (vision models, 0.0)   (perturbatively calculate, 0.025252525252525256)
#   78                                      (92c20 , 0.0)     (reinforcement learning, 0.025252525252525256)
#   79                                      (34c27 , 0.0)     (crafted neuron network, 0.025252525252525256)
#   80                                      (37b25 , 0.0)         (level ground truth, 0.025252525252525256)
#   81                            (hopfield network, 0.0)            (system dynamics, 0.020202020202020204)
#   82                  (biological neural networks, 0.0)                     (92c20 , 0.020202020202020204)
#   83                   (user interaction features, 0.0)                     (34c27 , 0.020202020202020204)
#   84                              (modal approach, 0.0)                     (37b25 , 0.020202020202020204)
#   85         (memristor-based switching networks , 0.0)             (network packet, 0.020202020202020204)
#   86                                   (memristor, 0.0)             (bit error rate, 0.020202020202020204)
#   87                            (known parameters, 0.0)               (people today, 0.020202020202020204)
#   88               (transfer adversarial examples, 0.0)   (businesses communicating, 0.020202020202020204)
#   89                               (open question, 0.0)              (vast majority, 0.020202020202020204)
#   90                (leveraging recent techniques, 0.0)            (emails received, 0.020202020202020204)
#   91                          (unknown parameters, 0.0)  (adversarial examples phenomenon, 0.0202020202...
#   92                            (similar mistakes, 0.0)               (domain shift, 0.020202020202020204)
#   93                               (make mistakes, 0.0)                        (pid, 0.020202020202020204)
#   94                                  (school bus, 0.0)           (emails originate, 0.020202020202020204)
#   95                         (global optimization, 0.0)       (model generalization, 0.020202020202020204)
#   96                                    (impulse , 0.0)            (radio frequency, 0.015151515151515152)
#   97                     (evolutionary algorithms, 0.0)           (spectral density, 0.015151515151515152)
#   98                            (adversarial risk, 0.0)        (fixed-point theorem, 0.015151515151515152)
#   99                            (track activities, 0.0)     (scheduling (computing), 0.015151515151515152)
#  100                                 (widely used, 0.0)        (computer simulation, 0.015151515151515152)
#
#
#
# Rank                         Pagerank_fraction_weigthed                           Pagerank_number_weighted
#    1   (artificial neural network, 0.02097377808006479)  (artificial neural network, 0.027787601224672744)
#    2  (mathematical optimization, 0.016156581015735787)  (mathematical optimization, 0.021079819112539647)
#    3         (numerical analysis, 0.014183705557731099)                 (simulation, 0.015952455577310978)
#    4                  (simulation, 0.01252459861029686)         (numerical analysis, 0.015072053742499422)
#    5           (machine learning, 0.011810413286053737)           (lyapunov fractal, 0.014771435261078223)
#    6          (social inequality, 0.010491215847369865)                  (algorithm, 0.013807655674386276)
#    7                  (algorithm, 0.010023829032822382)          (social inequality, 0.011709552409371337)
#    8        (adversarial examples, 0.00957328206322975)           (machine learning, 0.009926575330785576)
#    9           (lyapunov fractal, 0.009461295061148338)               (deep learning, 0.00895735651258262)
#   10              (deep learning, 0.009329357771893561)           (nonlinear system, 0.008402138093542153)
#   11                   (numerous, 0.008099887935653485)  (interference (communication), 0.0079986113459...
#   12                   (converge, 0.007862404377955956)                   (numerous, 0.007893387143658311)
#   13     (benchmark (computing), 0.0076089145180569025)       (adversarial examples, 0.007711890384334034)
#   14            (nonlinear system, 0.00747859961962076)  (neural network simulation, 0.007485032610871704)
#   15    (telecommunications link, 0.007263658741722259)                   (converge, 0.007356713603990737)
#   16  (interference (communication), 0.0072612869819...               (deep networks, 0.00733524212999654)
#   17             (deep networks, 0.0071847665492518345)       (training distribution, 0.00733524212999654)
#   18     (training distribution, 0.0071847665492518345)       (optimization problem, 0.006921791436931348)
#   19  (particle swarm optimization, 0.00652079665057...  (particle swarm optimization, 0.00661355999142...
#   20            (time complexity, 0.006397302893459531)      (benchmark (computing), 0.006475720973604895)
#   21       (optimization problem, 0.006345693245205543)              (loss function, 0.006458154046247631)
#   22              (loss function, 0.006345693245205542)            (cognitive radio, 0.006381215156217004)
#   23       (smart battery system, 0.006021534200646494)    (telecommunications link, 0.006345105960689958)
#   24           (iterative method, 0.006019308741441294)         (swarm intelligence , 0.00629842781465545)
#   25                 (multi-user, 0.006019308741441294)             (optimization , 0.0062984278146554495)
#   26               (optimization , 0.00601091741661728)   (linear matrix inequality, 0.006233832802879105)
#   27        (swarm intelligence , 0.006010917416617279)       (experimental results, 0.006163648020613337)
#   28      (experimental results, 0.0057744099940122565)           (anatomical layer, 0.005995412120296837)
#   29    (linear matrix inequality, 0.00559727827920218)      (biologic preservation, 0.005995412120296837)
#   30   (machine learning models, 0.0055898078928726495)           (data compression, 0.005995412120296837)
#   31             (vision models, 0.0055898078928726495)  (prime-factor fft algorithm, 0.005995412120296...
#   32          (known parameters, 0.0055898078928726495)  (predictive failure analysis, 0.00599541212029...
#   33  (transfer adversarial examples, 0.005589807892...           (iterative method, 0.005924811828804527)
#   34             (open question, 0.0055898078928726495)                 (multi-user, 0.005924811828804527)
#   35  (leveraging recent techniques, 0.0055898078928...  (adversarial examples phenomenon, 0.0055468770...
#   36        (unknown parameters, 0.0055898078928726495)              (domain shift, 0.0055468770618169305)
#   37          (similar mistakes, 0.0055898078928726495)      (model generalization, 0.0055468770618169305)
#   38             (make mistakes, 0.0055898078928726495)    (machine learning models, 0.005473882966726818)
#   39                (school bus, 0.0055898078928726495)              (vision models, 0.005473882966726818)
#   40             (small changes, 0.0055898078928726495)           (known parameters, 0.005473882966726818)
#   41           (anatomical layer, 0.005578791951238514)  (transfer adversarial examples, 0.005473882966...
#   42      (biologic preservation, 0.005578791951238514)              (open question, 0.005473882966726818)
#   43           (data compression, 0.005578791951238514)  (leveraging recent techniques, 0.0054738829667...
#   44  (prime-factor fft algorithm, 0.005578791951238...         (unknown parameters, 0.005473882966726818)
#   45  (predictive failure analysis, 0.00557879195123...           (similar mistakes, 0.005473882966726818)
#   46       (deep neural networks, 0.005417554041549046)              (make mistakes, 0.005473882966726818)
#   47   (neural network simulation, 0.00531819168752305)                 (school bus, 0.005473882966726817)
#   48                   (new data, 0.005304059119945683)              (small changes, 0.005473882966726817)
#   49  (driven programming paradigm, 0.00530405911994...  (memristor-based switching networks , 0.005449...
#   50         (critical scenarios, 0.005304059119945683)                  (memristor, 0.005449695934023566)
#   51              (training data, 0.005304059119945683)  (correctness (computer science), 0.00544969593...
#   52     (crafted neuron network, 0.005304059119945683)              (network packet, 0.00542052661705419)
#   53     (reinforcement learning, 0.005278325068881073)     (reinforcement learning, 0.005385837944663319)
#   54                      (mimo, 0.0052578789162403446)                   (new data, 0.005328654687885202)
#   55    (multitier architecture, 0.0052578789162403446)  (driven programming paradigm, 0.00532865468788...
#   56            (frequency band, 0.0052578789162403446)         (critical scenarios, 0.005328654687885202)
#   57    (analysis of algorithms, 0.0052403957644070655)              (training data, 0.005328654687885202)
#   58  (closed-circuit television, 0.0052403957644070...     (crafted neuron network, 0.005328654687885202)
#   59           (embedded system, 0.0052403957644070655)      (deep neural networks, 0.0052976284439628495)
#   60  (computational complexity theory, 0.0052403957...               (people today, 0.005025125628140705)
#   61  (memristor-based switching networks , 0.005101...   (businesses communicating, 0.005025125628140705)
#   62                  (memristor, 0.005101387643033159)              (vast majority, 0.005025125628140705)
#   63  (correctness (computer science), 0.00510138764...            (emails received, 0.005025125628140705)
#   64             (spin structure, 0.005090353779587683)           (emails originate, 0.005025125628140705)
#   65    (analyze orbital effects, 0.005090353779587683)             (spin structure, 0.005025125628140704)
#   66       (plane magnetic field, 0.005090353779587683)    (analyze orbital effects, 0.005025125628140704)
#   67            (conduction band, 0.005090353779587683)       (plane magnetic field, 0.005025125628140704)
#   68   (dimensional electron gas, 0.005090353779587683)            (conduction band, 0.005025125628140704)
#   69          (temporal boundary, 0.005090353779587683)   (dimensional electron gas, 0.005025125628140704)
#   70               (action class, 0.005090353779587683)         (cluster consensus , 0.005025125628140704)
#   71             (addressing tal, 0.005090353779587683)          (leader-following , 0.005025125628140704)
#   72            (untrimmed video, 0.005090353779587683)      (numerical simulations, 0.005025125628140704)
#   73  (temporal action localization, 0.0050903537795...  (many-objective optimization , 0.0050251256281...
#   74   (perturbatively calculate, 0.005090353779587683)         (nonlinear dynamics, 0.005025125628140704)
#   75         (level ground truth, 0.005090353779587683)       (temporal concurrency, 0.005025125628140704)
#   76        (cluster consensus , 0.0050903537795876815)       (semantically related, 0.005025125628140704)
#   77         (leader-following , 0.0050903537795876815)         (knowledge transfer, 0.005025125628140704)
#   78     (numerical simulations, 0.0050903537795876815)          (temporal boundary, 0.005025125628140704)
#   79  (many-objective optimization , 0.0050903537795...               (action class, 0.005025125628140704)
#   80        (nonlinear dynamics, 0.0050903537795876815)             (addressing tal, 0.005025125628140704)
#   81        (knowledge transfer, 0.0050903537795876815)            (untrimmed video, 0.005025125628140704)
#   82  (cross-validation (statistics), 0.005090353779...  (temporal action localization, 0.0050251256281...
#   83  (user interaction features, 0.0050903537795876...  (cross-validation (statistics), 0.005025125628...
#   84            (modal approach, 0.0050903537795876815)  (user interaction features, 0.005025125628140704)
#   85       (global optimization, 0.0050903537795876815)             (modal approach, 0.005025125628140704)
#   86          (adversarial risk, 0.0050903537795876815)        (global optimization, 0.005025125628140704)
#   87          (track activities, 0.0050903537795876815)           (adversarial risk, 0.005025125628140704)
#   88               (widely used, 0.0050903537795876815)           (track activities, 0.005025125628140704)
#   89          (secure by design, 0.0050903537795876815)                (widely used, 0.005025125628140704)
#   90        (internet of things, 0.0050903537795876815)           (secure by design, 0.005025125628140704)
#   91      (fundamental problems, 0.0050903537795876815)         (internet of things, 0.005025125628140704)
#   92       (multi-agent systems, 0.0050903537795876815)       (fundamental problems, 0.005025125628140704)
#   93                (wikipedia , 0.0050903537795876815)        (multi-agent systems, 0.005025125628140704)
#   94              (binary image, 0.0050903537795876815)                 (wikipedia , 0.005025125628140704)
#   95        (latency challenges, 0.0050903537795876815)               (binary image, 0.005025125628140704)
#   96           (real-time clock, 0.0050903537795876815)         (latency challenges, 0.005025125628140704)
#   97        (promising solution, 0.0050903537795876815)            (real-time clock, 0.005025125628140704)
#   98  (frechet inception distance, 0.005090353779587...         (promising solution, 0.005025125628140704)
#   99  (recurrent neural network, 0.0050903537795876815)  (frechet inception distance, 0.005025125628140...
#  100                   (benefit, 0.0050903537795876815)   (recurrent neural network, 0.005025125628140704)

# %% [markdown]
# The reflections on each metric are differentiated according to the size of the graph and the structure of the connected components and are reported in the report.
